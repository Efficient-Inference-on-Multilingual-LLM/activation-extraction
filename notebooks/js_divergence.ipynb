# %%
import os
import sys

# Change to parent directory
os.chdir('..')
# Add current directory to path
sys.path.append('.')

# %%
import pandas as pd
import numpy as np
from src.utils.const import LANGCODE2LANGNAME, LANGNAME2LANGCODE, MODEL2HIDDEN_SIZE, MODEL2NUM_LAYERS, EXP2_CONFIG
import glob
import torch
from tqdm import tqdm

# %%
model_name = 'gemma-3-4b-it' # 1152 size for 1b, 2560 for 4b
model_to_num_layers = {
    'gemma-3-1b-it': 26,
	'gemma-3-4b-it': 34,
    'gemma-3-270m-it': 18,
    'gemma-2-9b-it': 42
}
model_to_hidden_size = {
	'gemma-3-1b-it': 1152,
	'gemma-3-4b-it': 2560,
	'gemma-3-270m-it': 640,
	'gemma-2-9b-it': 3584
}
num_layers = model_to_num_layers[model_name]
extraction_mode = 'raw'
token_position = 'last_token'
languages = glob.glob('outputs/topic_classification/gemma-3-4b-it/raw/*')
languages = sorted([lang.split('/')[-1] for lang in languages])
text_ids = glob.glob('outputs/topic_classification/gemma-3-4b-it/raw/ace_Latn/*')
text_ids = [text_id.split('/')[-1].split('.')[0] for text_id in text_ids]

# %%
# # Extract language codes from the comment and add eng_Latn
# languages = [
# 	'vie_Latn',  # Vietnamese
# 	'ind_Latn',  # Indonesian
# 	'tha_Thai',  # Thai
# 	'zsm_Latn',  # Malay
# 	'mya_Mymr',  # Burmese -> 0 problem
# 	'tgl_Latn',  # Tagalog
# 	'khm_Khmr',  # Khmer
# 	'ceb_Latn',  # Cebuano
# 	'lao_Laoo',  # Lao
# 	'jav_Latn',  # Javanese
# 	'war_Latn',  # Waray
# 	'sun_Latn',  # Sundanese
# 	'ilo_Latn',  # Ilocano
# 	'tam_Taml',  # Tamil
# 	'zho_Hans',  # Chinese
# 	'eng_Latn'   # English
# ]

languages = []
for family, langs in EXP2_CONFIG['languages'].items():
	languages.extend(langs)

languages = [LANGNAME2LANGCODE[lang] for lang in languages]
languages
# Out:
# ['eng_Latn',
#  'deu_Latn',
#  'spa_Latn',
#  'fra_Latn',
#  'arb_Arab',
#  'heb_Hebr',
#  'rus_Cyrl',
#  'slk_Latn',
#  'tha_Thai',
#  'lao_Laoo',
#  'khm_Khmr',
#  'vie_Latn',
#  'swh_Latn',
#  'xho_Latn',
#  'zul_Latn',
#  'urd_Arab',
#  'hin_Deva',
#  'kan_Knda',
#  'tel_Telu',
#  'jpn_Jpan',
#  'kor_Hang',
#  'tur_Latn',
#  'azb_Arab',
#  'azj_Latn',
#  'tgl_Latn',
#  'ceb_Latn',
#  'ilo_Latn',
#  'war_Latn',
#  'yue_Hant',
#  'zho_Hans',
#  'ind_Latn',
#  'zsm_Latn',
#  'min_Latn',
#  'min_Arab',
#  'bjn_Latn',
#  'bjn_Arab',
#  'jav_Latn',
#  'sun_Latn']

# %%
# Check if a GPU is available and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Initialize empty torch tensor to hold all activations [text_id, layer_id, language, hidden_size]
activation_per_lang = torch.zeros((len(text_ids), num_layers + 1, len(languages), MODEL2HIDDEN_SIZE[model_name])).to(device)
print(f'Activation tensor shape: {activation_per_lang.shape}')

# Reshape to [text_id * language, layer_id, hidden_size]
activation_per_lang = activation_per_lang.view(-1, num_layers + 1, MODEL2HIDDEN_SIZE[model_name])
print(f'Reshaped activation tensor shape: {activation_per_lang.shape}')

# Initialize empty torch tensor to hold all labels [text_id, language]
labels = torch.zeros((len(text_ids) * len(languages),), dtype=torch.long).to(device)
print(f'Labels tensor shape: {labels.shape}')
# Out:
# Activation tensor shape: torch.Size([204, 35, 38, 2560])
# Reshaped activation tensor shape: torch.Size([7752, 35, 2560])
# Labels tensor shape: torch.Size([7752])

# %%
activation_per_lang.shape
# Out:
# torch.Size([7752, 35, 2560])

# %%
# # Load activations for all languages
# id2langcode = {idx: lang for idx, lang in enumerate(languages)}
# langcode2id = {lang: idx for idx, lang in enumerate(languages)}
# text_idx = 0
# for lang_idx, lang in tqdm(enumerate(languages), total=len(languages), desc='Loading activations for all languages'):
# 	for layer_id in range(-1, num_layers):
# 		if layer_id == -1:
# 			paths = sorted(glob.glob(f'outputs/topic_classification/{model_name}/{extraction_mode}/{lang}/*/{token_position}/layer_embed_tokens.pt'))
# 		else:
# 			paths = sorted(glob.glob(f'outputs/topic_classification/{model_name}/{extraction_mode}/{lang}/*/{token_position}/layer_{layer_id}.pt'))
# 		if len(paths) != len(text_ids):
# 			print(f"Warning: Expected {len(text_ids)} files for language '{lang}' at layer {layer_id}, but found {len(paths)} files.")
# 			break
# 		for path in paths:
# 			activation = torch.load(path)
# 			activation_per_lang[text_idx, layer_id + 1, lang_idx, :] = activation.to('cuda')
# 			text_idx += 1
# 		text_idx = 0

# %%
# Load activations for all languages
text_idx = 0
id2langcode = {idx: lang for idx, lang in enumerate(languages)}
langcode2id = {lang: idx for idx, lang in enumerate(languages)}

for lang_idx, lang in tqdm(enumerate(languages), total=len(languages), desc='Loading activations for all languages'):
	for layer_id in range(-1, num_layers):
		if layer_id == -1:
			paths = sorted(glob.glob(f'outputs/topic_classification/{model_name}/{extraction_mode}/{lang}/*/{token_position}/layer_embed_tokens.pt'))
		else:
			paths = sorted(glob.glob(f'outputs/topic_classification/{model_name}/{extraction_mode}/{lang}/*/{token_position}/layer_{layer_id}.pt'))
		if len(paths) != len(text_ids):
			print(f"Warning: Expected {len(text_ids)} files for language '{lang}' at layer {layer_id}, but found {len(paths)} files.")
			break
		for text_idx_inner, path in enumerate(paths):
			activation = torch.load(path)
			# Calculate the flat index for the reshaped tensor
			flat_idx = text_idx_inner * len(languages) + lang_idx
			activation_per_lang[flat_idx, layer_id + 1, :] = activation.to(device)
			# Populate labels with language_id (only need to do this once per text-language pair)
			if layer_id == -1:
				labels[flat_idx] = lang_idx
# Out:
# Loading activations for all languages: 100%|██████████| 38/38 [02:04<00:00,  3.28s/it]

# %%
activation_per_lang.shape
# Out:
# torch.Size([7752, 35, 2560])

# %%
labels.shape
# Out:
# torch.Size([7752])

# %%
activation_per_lang[:, layer_id + 1, :].shape
# Out:
# torch.Size([7752, 2560])

# %% [markdown]
# ### JS Div

# %%
import torch
import torch.nn.functional as F

def js_divergence_pytorch(p, q, reduction='sum'):
    """
    Calculates the Jensen-Shannon Divergence between two probability distributions
    using PyTorch.
    
    Args:
        p (torch.Tensor): The first probability distribution.
        q (torch.Tensor): The second probability distribution.
        reduction (str): Specifies the reduction to apply to the output: 
                         'none' | 'batchmean' | 'sum' | 'mean'.
                         Default: 'sum'.
    """
    # Calculate the midpoint distribution
    m = 0.5 * (p + q)
    
    # Calculate the KL divergences. F.kl_div expects log-probabilities for the input.
    # The target (second argument) should be probabilities.
    kl_p_m = F.kl_div(m.log(), p, reduction=reduction)
    kl_q_m = F.kl_div(m.log(), q, reduction=reduction)
    
    # Calculate the JS Divergence
    jsd = 0.5 * (kl_p_m + kl_q_m)
    
    return jsd



# You can also compute it for a batch of distributions
p_batch = torch.tensor([[0.1, 0.9], [0.8, 0.2]], device=device)
q_batch = torch.tensor([[0.2, 0.8], [0.7, 0.3]], device=device)

# 'batchmean' averages the divergence over the batch dimension
jsd_batch = js_divergence_pytorch(p_batch, q_batch, reduction='batchmean')
print(f"JS Divergence for batch (PyTorch, GPU): {jsd_batch.item():.4f}")

# %%
# 4. Calculate the silhouette score on the GPU
# The function takes the data and the predicted labels as input.
js_matrix = torch.zeros((num_layers + 1, len(languages), len(languages))).to(device)
for layer_id in tqdm(range(-1, num_layers)):
	# Calculate pairwise silhouette scores per language
	for lang_idx1 in range(len(languages)):
		for lang_idx2 in range(len(languages)):
			if lang_idx1 != lang_idx2:
				# Take all index of labels that have value lang_idx1 and lang_idx2
				indexes_lang1 = (labels == lang_idx1).nonzero(as_tuple=True)[0]
				indexes_lang2 = (labels == lang_idx2).nonzero(as_tuple=True)[0]

				# Take activations for those indexes
				activations_lang1 = activation_per_lang[indexes_lang1, layer_id + 1, :]
				activations_lang2 = activation_per_lang[indexes_lang2, layer_id + 1, :]
				labels_lang1 = labels[indexes_lang1]
				labels_lang2 = labels[indexes_lang2]

				# Calculate JS Div between the two sets of activations
				score = js_divergence_pytorch(activations_lang1, activations_lang2, reduction='batchmean')
				
				# Store score in matrix
				js_matrix[layer_id + 1, lang_idx1, lang_idx2] = score

# %%
js_matrix[1, :, :]

# %%
# Get top k minimum distance values in each layer with their language pair identifiers

# Set k as a variable
k = 50  # You can change this value as needed

# Initialize lists to store results
all_min_distances = []
all_min_distance_pairs = []

# For each layer, find the top k minimum distances and corresponding language pairs
for layer_id in range(-1, num_layers):
	layer_distances = js_matrix[layer_id + 1]
	
	# Create a mask to exclude diagonal elements and upper triangle (to avoid duplicates)
	mask = torch.tril(torch.ones_like(layer_distances, dtype=torch.bool), diagonal=-1)
	
	# Get all distances excluding diagonal and upper triangle, then flatten
	lower_triangle_distances = layer_distances[mask]
	
	# Get top k minimum distances
	topk_min_values, topk_indices = torch.topk(lower_triangle_distances, k=k, largest=False)
	
	# Convert flat indices back to 2D coordinates
	layer_min_distances = []
	layer_min_pairs = []
	
	# Get indices of lower triangle elements
	lower_i, lower_j = torch.where(mask)
	
	for idx in range(k):
		flat_idx = topk_indices[idx].item()
		lang_i_idx = lower_i[flat_idx].item()
		lang_j_idx = lower_j[flat_idx].item()
		
		layer_min_distances.append(topk_min_values[idx].item())
		layer_min_pairs.append((languages[lang_i_idx], languages[lang_j_idx]))
	
	all_min_distances.append(layer_min_distances)
	all_min_distance_pairs.append(layer_min_pairs)

# Create a detailed DataFrame
detailed_results = []
for layer_id in range(-1, num_layers):
	for rank in range(k):
		lang1, lang2 = all_min_distance_pairs[layer_id + 1][rank]
		detailed_results.append({
			'Layer': layer_id,
			'Rank': rank + 1,
			'Min_Distance': all_min_distances[layer_id + 1][rank],
			'Language_Pair': f"{LANGCODE2LANGNAME[lang1]} ({lang1}) - {LANGCODE2LANGNAME[lang2]} ({lang2})"
		})

results_df = pd.DataFrame(detailed_results)

print(f"Top {k} minimum distances per layer:")
print(results_df.to_string(index=False))

# Also print a summary view grouped by layer
print("\nSummary by layer:")
for layer_id in range(-1, num_layers):
	print(f"\nLayer {layer_id:2d}:")
	for rank in range(k):
		lang1, lang2 = all_min_distance_pairs[layer_id + 1][rank]
		distance = all_min_distances[layer_id + 1][rank]
		print(f"  {rank+1}. {distance:.6f} - {LANGCODE2LANGNAME[lang1]} ({lang1}) & {LANGCODE2LANGNAME[lang2]} ({lang2})")

# %% [markdown]
# ### Wasserstein

# %%
import numpy as np
from scipy.stats import wasserstein_distance

# These arrays represent the *values* at which the probability masses are located.
# Think of these as the positions of the "dirt piles".
values_p = np.array([0, 1, 3])
values_q = np.array([5, 6, 8])

# These arrays represent the *weights* or probabilities at each value.
# They must sum to 1.
weights_p = np.array([0.2, 0.5, 0.3])
weights_q = np.array([0.2, 0.5, 0.3])

# Calculate the 1st Wasserstein distance (EMD)
# It calculates the cost to transform distribution p into distribution q
dist = wasserstein_distance(values_p, values_q)

print(f"Wasserstein Distance (SciPy): {dist:.4f}")
# The output is 5.0, because each chunk of "dirt" has to move 5 units to the right.
# (0.2 * (5-0)) + (0.5 * (6-1)) + (0.3 * (8-3)) = 1.0 + 2.5 + 1.5 = 5.0
# Out:
# Wasserstein Distance (SciPy): 5.0000

# %%
import ot
# 4. Calculate the silhouette score on the GPU
# The function takes the data and the predicted labels as input.
wasserstein_distance_matrix = torch.zeros((num_layers + 1, len(languages), len(languages))).to(device)
for layer_id in tqdm(range(-1, num_layers)):
	# Calculate pairwise silhouette scores per language
	for lang_idx1 in range(len(languages)):
		for lang_idx2 in range(len(languages)):
			if lang_idx1 != lang_idx2:
				# Take all index of labels that have value lang_idx1 and lang_idx2
				indexes_lang1 = (labels == lang_idx1).nonzero(as_tuple=True)[0]
				indexes_lang2 = (labels == lang_idx2).nonzero(as_tuple=True)[0]

				# Take activations for those indexes
				activations_lang1 = activation_per_lang[indexes_lang1, layer_id + 1, :]
				activations_lang2 = activation_per_lang[indexes_lang2, layer_id + 1, :]
				labels_lang1 = labels[indexes_lang1]
				labels_lang2 = labels[indexes_lang2]

				# Uniform weights for both distributions
				activation1_weights = torch.ones(activations_lang1.shape[0],).to(device) / activations_lang1.shape[0]
				activation2_weights = torch.ones(activations_lang2.shape[0],).to(device) / activations_lang2.shape[0]

				# Cost matrix is also computed on the GPU
				cost_matrix = ot.dist(activations_lang1, activations_lang2)

				# EMD calculation runs on the GPU
				emd_distance_gpu = ot.emd2(activation1_weights, activation2_weights, cost_matrix)
				
				# Store score in matrix
				wasserstein_distance_matrix[layer_id + 1, lang_idx1, lang_idx2] = emd_distance_gpu

				# print(f"Wasserstein Distance between {id2langcode[lang_idx1]} and {id2langcode[lang_idx2]}: {score:.4f}")

# For this well-separated data, you should see a high score (e.g., > 0.8)
# A high score indicates that the clusters are dense and well-separated.
# Out:
# 100%|██████████| 35/35 [07:07<00:00, 12.21s/it]

# %%
# Get top k minimum distance values in each layer with their language pair identifiers

# Set k as a variable
k = 50  # You can change this value as needed

# Initialize lists to store results
all_min_distances = []
all_min_distance_pairs = []

# For each layer, find the top k minimum distances and corresponding language pairs
for layer_id in range(-1, num_layers):
	layer_distances = wasserstein_distance_matrix[layer_id + 1]
	
	# Create a mask to exclude diagonal elements and upper triangle (to avoid duplicates)
	mask = torch.tril(torch.ones_like(layer_distances, dtype=torch.bool), diagonal=-1)
	
	# Get all distances excluding diagonal and upper triangle, then flatten
	lower_triangle_distances = layer_distances[mask]
	
	# Get top k minimum distances
	topk_min_values, topk_indices = torch.topk(lower_triangle_distances, k=k, largest=False)
	
	# Convert flat indices back to 2D coordinates
	layer_min_distances = []
	layer_min_pairs = []
	
	# Get indices of lower triangle elements
	lower_i, lower_j = torch.where(mask)
	
	for idx in range(k):
		flat_idx = topk_indices[idx].item()
		lang_i_idx = lower_i[flat_idx].item()
		lang_j_idx = lower_j[flat_idx].item()
		
		layer_min_distances.append(topk_min_values[idx].item())
		layer_min_pairs.append((languages[lang_i_idx], languages[lang_j_idx]))
	
	all_min_distances.append(layer_min_distances)
	all_min_distance_pairs.append(layer_min_pairs)

# Create a detailed DataFrame
detailed_results = []
for layer_id in range(-1, num_layers):
	for rank in range(k):
		lang1, lang2 = all_min_distance_pairs[layer_id + 1][rank]
		detailed_results.append({
			'Layer': layer_id,
			'Rank': rank + 1,
			'Min_Distance': all_min_distances[layer_id + 1][rank],
			'Language_Pair': f"{LANGCODE2LANGNAME[lang1]} ({lang1}) - {LANGCODE2LANGNAME[lang2]} ({lang2})"
		})

results_df = pd.DataFrame(detailed_results)

print(f"Top {k} minimum distances per layer:")
print(results_df.to_string(index=False))

# Also print a summary view grouped by layer
print("\nSummary by layer:")
for layer_id in range(-1, num_layers):
	print(f"\nLayer {layer_id:2d}:")
	for rank in range(k):
		lang1, lang2 = all_min_distance_pairs[layer_id + 1][rank]
		distance = all_min_distances[layer_id + 1][rank]
		print(f"  {rank+1}. {distance:.6f} - {LANGCODE2LANGNAME[lang1]} ({lang1}) & {LANGCODE2LANGNAME[lang2]} ({lang2})")
# Out:
# Top 50 minimum distances per layer:
#  Layer  Rank  Min_Distance                                                        Language_Pair
#     -1     1  2.929688e-03                               German (deu_Latn) - English (eng_Latn)
#     -1     2  2.929688e-03                              Spanish (spa_Latn) - English (eng_Latn)
#     -1     3  2.929688e-03                               Spanish (spa_Latn) - German (deu_Latn)
#     -1     4  2.929688e-03                               French (fra_Latn) - English (eng_Latn)
#     -1     5  2.929688e-03                                French (fra_Latn) - German (deu_Latn)
#     -1     6  2.929688e-03                               French (fra_Latn) - Spanish (spa_Latn)
#     -1     7  2.929688e-03                         MSA (Arabic) (arb_Arab) - English (eng_Latn)
#     -1     8  2.929688e-03                          MSA (Arabic) (arb_Arab) - German (deu_Latn)
#     -1     9  2.929688e-03                         MSA (Arabic) (arb_Arab) - Spanish (spa_Latn)
#     -1    10  2.929688e-03                          MSA (Arabic) (arb_Arab) - French (fra_Latn)
#     -1    11  2.929688e-03                               Hebrew (heb_Hebr) - English (eng_Latn)
#     -1    12  2.929688e-03                                Hebrew (heb_Hebr) - German (deu_Latn)
#     -1    13  2.929688e-03                               Hebrew (heb_Hebr) - Spanish (spa_Latn)
#     -1    14  2.929688e-03                                Hebrew (heb_Hebr) - French (fra_Latn)
#     -1    15  2.929688e-03                          Hebrew (heb_Hebr) - MSA (Arabic) (arb_Arab)
#     -1    16  2.929688e-03                              Russian (rus_Cyrl) - English (eng_Latn)
#     -1    17  2.929688e-03                               Russian (rus_Cyrl) - German (deu_Latn)
#     -1    18  2.929688e-03                              Russian (rus_Cyrl) - Spanish (spa_Latn)
#     -1    19  2.929688e-03                               Russian (rus_Cyrl) - French (fra_Latn)
#     -1    20  2.929688e-03                         Russian (rus_Cyrl) - MSA (Arabic) (arb_Arab)
#     -1    21  2.929688e-03                               Russian (rus_Cyrl) - Hebrew (heb_Hebr)
#     -1    22  2.929688e-03                               Slovak (slk_Latn) - English (eng_Latn)
#     -1    23  2.929688e-03                                Slovak (slk_Latn) - German (deu_Latn)
#     -1    24  2.929688e-03                               Slovak (slk_Latn) - Spanish (spa_Latn)
#     -1    25  2.929688e-03                                Slovak (slk_Latn) - French (fra_Latn)
#     -1    26  2.929688e-03                          Slovak (slk_Latn) - MSA (Arabic) (arb_Arab)
#     -1    27  2.929688e-03                                Slovak (slk_Latn) - Hebrew (heb_Hebr)
#     -1    28  2.929688e-03                               Slovak (slk_Latn) - Russian (rus_Cyrl)
#     -1    29  2.929688e-03                                 Thai (tha_Thai) - English (eng_Latn)
#     -1    30  2.929688e-03                                  Thai (tha_Thai) - German (deu_Latn)
#     -1    31  2.929688e-03                                 Thai (tha_Thai) - Spanish (spa_Latn)
#     -1    32  2.929688e-03                                  Thai (tha_Thai) - French (fra_Latn)
#     -1    33  2.929688e-03                            Thai (tha_Thai) - MSA (Arabic) (arb_Arab)
#     -1    34  2.929688e-03                                  Thai (tha_Thai) - Hebrew (heb_Hebr)
#     -1    35  2.929688e-03                                 Thai (tha_Thai) - Russian (rus_Cyrl)
#     -1    36  2.929688e-03                                  Thai (tha_Thai) - Slovak (slk_Latn)
#     -1    37  2.929688e-03                                  Lao (lao_Laoo) - English (eng_Latn)
#     -1    38  2.929688e-03                                   Lao (lao_Laoo) - German (deu_Latn)
#     -1    39  2.929688e-03                                  Lao (lao_Laoo) - Spanish (spa_Latn)
#     -1    40  2.929688e-03                                   Lao (lao_Laoo) - French (fra_Latn)
#     -1    41  2.929688e-03                             Lao (lao_Laoo) - MSA (Arabic) (arb_Arab)
#     -1    42  2.929688e-03                                   Lao (lao_Laoo) - Hebrew (heb_Hebr)
#     -1    43  2.929688e-03                                  Lao (lao_Laoo) - Russian (rus_Cyrl)
#     -1    44  2.929688e-03                                   Lao (lao_Laoo) - Slovak (slk_Latn)
#     -1    45  2.929688e-03                                     Lao (lao_Laoo) - Thai (tha_Thai)
#     -1    46  2.929688e-03                                Khmer (khm_Khmr) - English (eng_Latn)
#     -1    47  2.929688e-03                                 Khmer (khm_Khmr) - German (deu_Latn)
#     -1    48  2.929688e-03                                Khmer (khm_Khmr) - Spanish (spa_Latn)
#     -1    49  2.929688e-03                                 Khmer (khm_Khmr) - French (fra_Latn)
#     -1    50  2.929688e-03                           Khmer (khm_Khmr) - MSA (Arabic) (arb_Arab)
#      0     1  6.998376e+01  Banjar (Arabic script) (bjn_Arab) - Minangkabau (Arabic) (min_Arab)
#      0     2  7.301042e+01                                   Zulu (zul_Latn) - Xhosa (xho_Latn)
#      0     3  7.840105e+01    Banjar (Latin script) (bjn_Latn) - Minangkabau (Latin) (min_Latn)
#      0     4  8.467096e+01                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      0     5  9.005975e+01             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      0     6  9.028033e+01                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      0     7  9.729964e+01                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      0     8  9.817096e+01                           Sundanese (sun_Latn) - Javanese (jav_Latn)
#      0     9  1.064985e+02                Sundanese (sun_Latn) - Minangkabau (Latin) (min_Latn)
#      0    10  1.088627e+02                          Hebrew (heb_Hebr) - MSA (Arabic) (arb_Arab)
#      0    11  1.149219e+02                 Javanese (jav_Latn) - Minangkabau (Latin) (min_Latn)
#      0    12  1.192328e+02              Sundanese (sun_Latn) - Banjar (Latin script) (bjn_Latn)
#      0    13  1.220582e+02               Javanese (jav_Latn) - Banjar (Latin script) (bjn_Latn)
#      0    14  1.221143e+02                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      0    15  1.296131e+02                  Minangkabau (Latin) (min_Latn) - Ilocano (ilo_Latn)
#      0    16  1.318119e+02                Banjar (Latin script) (bjn_Latn) - Ilocano (ilo_Latn)
#      0    17  1.512377e+02                         Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      0    18  1.595959e+02                Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      0    19  1.597880e+02     Banjar (Arabic script) (bjn_Arab) - South Azerbaijani (azb_Arab)
#      0    20  1.634341e+02                                 Zulu (zul_Latn) - Swahili (swh_Latn)
#      0    21  1.642702e+02                              Sundanese (sun_Latn) - Xhosa (xho_Latn)
#      0    22  1.646452e+02                            Sundanese (sun_Latn) - Ilocano (ilo_Latn)
#      0    23  1.659734e+02                                Xhosa (xho_Latn) - Swahili (swh_Latn)
#      0    24  1.661970e+02                    Minangkabau (Latin) (min_Latn) - Xhosa (xho_Latn)
#      0    25  1.689838e+02       Minangkabau (Arabic) (min_Arab) - South Azerbaijani (azb_Arab)
#      0    26  1.692616e+02                               Sundanese (sun_Latn) - Zulu (zul_Latn)
#      0    27  1.694620e+02                                Ilocano (ilo_Latn) - Xhosa (xho_Latn)
#      0    28  1.696317e+02         Banjar (Latin script) (bjn_Latn) - Standard Malay (zsm_Latn)
#      0    29  1.706952e+02                            Sundanese (sun_Latn) - Swahili (swh_Latn)
#      0    30  1.751945e+02                     North Azerbaijani (azj_Latn) - Slovak (slk_Latn)
#      0    31  1.762261e+02                             Javanese (jav_Latn) - Ilocano (ilo_Latn)
#      0    32  1.790640e+02                              Cebuano (ceb_Latn) - Swahili (swh_Latn)
#      0    33  1.806091e+02                               Javanese (jav_Latn) - Xhosa (xho_Latn)
#      0    34  1.809813e+02                              Sundanese (sun_Latn) - Waray (war_Latn)
#      0    35  1.834393e+02             Banjar (Latin script) (bjn_Latn) - Indonesian (ind_Latn)
#      0    36  1.850558e+02                                Waray (war_Latn) - Swahili (swh_Latn)
#      0    37  1.856088e+02                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      0    38  1.885138e+02           Minangkabau (Latin) (min_Latn) - Standard Malay (zsm_Latn)
#      0    39  1.890490e+02                      Javanese (jav_Latn) - Standard Malay (zsm_Latn)
#      0    40  1.899081e+02                          Korean (kor_Hang) - MSA (Arabic) (arb_Arab)
#      0    41  1.900466e+02                                Javanese (jav_Latn) - Zulu (zul_Latn)
#      0    42  1.911795e+02                    North Azerbaijani (azj_Latn) - Turkish (tur_Latn)
#      0    43  1.917466e+02                              Ilocano (ilo_Latn) - Swahili (swh_Latn)
#      0    44  1.919225e+02                     Minangkabau (Latin) (min_Latn) - Zulu (zul_Latn)
#      0    45  1.945711e+02                  Banjar (Latin script) (bjn_Latn) - Xhosa (xho_Latn)
#      0    46  1.947638e+02                               Javanese (jav_Latn) - Waray (war_Latn)
#      0    47  1.951054e+02                  Minangkabau (Latin) (min_Latn) - Swahili (swh_Latn)
#      0    48  1.953205e+02                                 Ilocano (ilo_Latn) - Zulu (zul_Latn)
#      0    49  1.961014e+02                              Tagalog (tgl_Latn) - Swahili (swh_Latn)
#      0    50  1.980861e+02                                French (fra_Latn) - German (deu_Latn)
#      1     1  1.862874e+02  Banjar (Arabic script) (bjn_Arab) - Minangkabau (Arabic) (min_Arab)
#      1     2  2.188851e+02                                   Zulu (zul_Latn) - Xhosa (xho_Latn)
#      1     3  2.880208e+02    Banjar (Latin script) (bjn_Latn) - Minangkabau (Latin) (min_Latn)
#      1     4  2.905159e+02                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      1     5  2.921106e+02                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      1     6  2.931317e+02                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      1     7  2.985013e+02                           Sundanese (sun_Latn) - Javanese (jav_Latn)
#      1     8  3.248079e+02                 Javanese (jav_Latn) - Minangkabau (Latin) (min_Latn)
#      1     9  3.295518e+02                Sundanese (sun_Latn) - Minangkabau (Latin) (min_Latn)
#      1    10  3.934286e+02               Javanese (jav_Latn) - Banjar (Latin script) (bjn_Latn)
#      1    11  4.059979e+02              Sundanese (sun_Latn) - Banjar (Latin script) (bjn_Latn)
#      1    12  4.954314e+02                            Sundanese (sun_Latn) - Ilocano (ilo_Latn)
#      1    13  5.045543e+02                  Minangkabau (Latin) (min_Latn) - Ilocano (ilo_Latn)
#      1    14  5.072567e+02             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      1    15  5.118707e+02                               Telugu (tel_Telu) - Kannada (kan_Knda)
#      1    16  5.127157e+02                              Cebuano (ceb_Latn) - Swahili (swh_Latn)
#      1    17  5.191345e+02                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      1    18  5.247059e+02                             Javanese (jav_Latn) - Ilocano (ilo_Latn)
#      1    19  5.322258e+02                               Spanish (spa_Latn) - German (deu_Latn)
#      1    20  5.366716e+02                               French (fra_Latn) - Spanish (spa_Latn)
#      1    21  5.409452e+02                                French (fra_Latn) - German (deu_Latn)
#      1    22  5.559283e+02                  Banjar (Latin script) (bjn_Latn) - Waray (war_Latn)
#      1    23  5.640377e+02                          Hebrew (heb_Hebr) - MSA (Arabic) (arb_Arab)
#      1    24  5.672938e+02                                Waray (war_Latn) - Swahili (swh_Latn)
#      1    25  5.723713e+02                              Tagalog (tgl_Latn) - Swahili (swh_Latn)
#      1    26  5.805095e+02                            Indonesian (ind_Latn) - German (deu_Latn)
#      1    27  5.841532e+02                           Indonesian (ind_Latn) - Spanish (spa_Latn)
#      1    28  6.072013e+02                Banjar (Latin script) (bjn_Latn) - Ilocano (ilo_Latn)
#      1    29  6.168257e+02                        Standard Malay (zsm_Latn) - German (deu_Latn)
#      1    30  6.370659e+02                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      1    31  6.388622e+02                               Cebuano (ceb_Latn) - Slovak (slk_Latn)
#      1    32  6.389547e+02                               Swahili (swh_Latn) - Slovak (slk_Latn)
#      1    33  6.767834e+02                               Russian (rus_Cyrl) - German (deu_Latn)
#      1    34  6.818793e+02                       Standard Malay (zsm_Latn) - Spanish (spa_Latn)
#      1    35  6.868187e+02                    Minangkabau (Latin) (min_Latn) - Waray (war_Latn)
#      1    36  6.994274e+02                       Standard Malay (zsm_Latn) - Tagalog (tgl_Latn)
#      1    37  7.009822e+02                            Indonesian (ind_Latn) - French (fra_Latn)
#      1    38  7.056661e+02                            Vietnamese (vie_Latn) - German (deu_Latn)
#      1    39  7.099403e+02                        Indonesian (ind_Latn) - Vietnamese (vie_Latn)
#      1    40  7.128968e+02                           Indonesian (ind_Latn) - Tagalog (tgl_Latn)
#      1    41  7.130432e+02                              Sundanese (sun_Latn) - Waray (war_Latn)
#      1    42  7.147322e+02                                    Khmer (khm_Khmr) - Lao (lao_Laoo)
#      1    43  7.240463e+02                               Javanese (jav_Latn) - Waray (war_Latn)
#      1    44  7.263434e+02                       Standard Malay (zsm_Latn) - Cebuano (ceb_Latn)
#      1    45  7.297111e+02                    Standard Malay (zsm_Latn) - Vietnamese (vie_Latn)
#      1    46  7.403845e+02                                 Waray (war_Latn) - Slovak (slk_Latn)
#      1    47  7.444277e+02                                Slovak (slk_Latn) - German (deu_Latn)
#      1    48  7.483006e+02                       Standard Malay (zsm_Latn) - Swahili (swh_Latn)
#      1    49  7.488064e+02                               Tagalog (tgl_Latn) - German (deu_Latn)
#      1    50  7.532537e+02                        Standard Malay (zsm_Latn) - French (fra_Latn)
#      2     1  3.037513e+02                                   Zulu (zul_Latn) - Xhosa (xho_Latn)
#      2     2  3.276508e+02  Banjar (Arabic script) (bjn_Arab) - Minangkabau (Arabic) (min_Arab)
#      2     3  4.107953e+02                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      2     4  4.651881e+02                           Sundanese (sun_Latn) - Javanese (jav_Latn)
#      2     5  4.923640e+02    Banjar (Latin script) (bjn_Latn) - Minangkabau (Latin) (min_Latn)
#      2     6  5.137384e+02                Sundanese (sun_Latn) - Minangkabau (Latin) (min_Latn)
#      2     7  5.184633e+02                 Javanese (jav_Latn) - Minangkabau (Latin) (min_Latn)
#      2     8  5.226691e+02                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      2     9  5.447947e+02                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      2    10  5.791697e+02                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      2    11  5.959455e+02              Sundanese (sun_Latn) - Banjar (Latin script) (bjn_Latn)
#      2    12  6.788493e+02               Javanese (jav_Latn) - Banjar (Latin script) (bjn_Latn)
#      2    13  7.026918e+02                              Ilocano (ilo_Latn) - Cebuano (ceb_Latn)
#      2    14  7.274130e+02                               Telugu (tel_Telu) - Kannada (kan_Knda)
#      2    15  7.407500e+02                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      2    16  8.765392e+02             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      2    17  8.845883e+02                                    Khmer (khm_Khmr) - Lao (lao_Laoo)
#      2    18  9.085491e+02                               French (fra_Latn) - Spanish (spa_Latn)
#      2    19  9.102856e+02         Banjar (Latin script) (bjn_Latn) - Standard Malay (zsm_Latn)
#      2    20  1.014547e+03                            Sundanese (sun_Latn) - Ilocano (ilo_Latn)
#      2    21  1.024300e+03                  Minangkabau (Latin) (min_Latn) - Ilocano (ilo_Latn)
#      2    22  1.037974e+03                             Javanese (jav_Latn) - Ilocano (ilo_Latn)
#      2    23  1.077112e+03                    Minangkabau (Latin) (min_Latn) - Waray (war_Latn)
#      2    24  1.077864e+03                              Sundanese (sun_Latn) - Waray (war_Latn)
#      2    25  1.104193e+03                              Ilocano (ilo_Latn) - Tagalog (tgl_Latn)
#      2    26  1.111623e+03                               Javanese (jav_Latn) - Waray (war_Latn)
#      2    27  1.137781e+03                                  Telugu (tel_Telu) - Urdu (urd_Arab)
#      2    28  1.154866e+03       Minangkabau (Arabic) (min_Arab) - South Azerbaijani (azb_Arab)
#      2    29  1.174597e+03     Banjar (Arabic script) (bjn_Arab) - South Azerbaijani (azb_Arab)
#      2    30  1.213460e+03                  Banjar (Latin script) (bjn_Latn) - Waray (war_Latn)
#      2    31  1.251297e+03             Banjar (Latin script) (bjn_Latn) - Indonesian (ind_Latn)
#      2    32  1.277919e+03                Banjar (Latin script) (bjn_Latn) - Ilocano (ilo_Latn)
#      2    33  1.282486e+03                                French (fra_Latn) - German (deu_Latn)
#      2    34  1.347010e+03                  Minangkabau (Latin) (min_Latn) - Cebuano (ceb_Latn)
#      2    35  1.368465e+03                                   Hindi (hin_Deva) - Urdu (urd_Arab)
#      2    36  1.372876e+03                            Sundanese (sun_Latn) - Cebuano (ceb_Latn)
#      2    37  1.373371e+03                              Tagalog (tgl_Latn) - Swahili (swh_Latn)
#      2    38  1.381516e+03                          Hebrew (heb_Hebr) - MSA (Arabic) (arb_Arab)
#      2    39  1.398803e+03                                 Kannada (kan_Knda) - Urdu (urd_Arab)
#      2    40  1.411651e+03                               Spanish (spa_Latn) - German (deu_Latn)
#      2    41  1.418253e+03                     Sundanese (sun_Latn) - Standard Malay (zsm_Latn)
#      2    42  1.423169e+03                                Slovak (slk_Latn) - Hebrew (heb_Hebr)
#      2    43  1.424620e+03                            Vietnamese (vie_Latn) - German (deu_Latn)
#      2    44  1.425768e+03                             Javanese (jav_Latn) - Cebuano (ceb_Latn)
#      2    45  1.426705e+03           Minangkabau (Latin) (min_Latn) - Standard Malay (zsm_Latn)
#      2    46  1.433810e+03                               Cebuano (ceb_Latn) - Slovak (slk_Latn)
#      2    47  1.436789e+03                Banjar (Latin script) (bjn_Latn) - Swahili (swh_Latn)
#      2    48  1.465190e+03                               Russian (rus_Cyrl) - German (deu_Latn)
#      2    49  1.486392e+03                           Tagalog (tgl_Latn) - Vietnamese (vie_Latn)
#      2    50  1.489962e+03                      Vietnamese (vie_Latn) - MSA (Arabic) (arb_Arab)
#      3     1  4.642702e+02  Banjar (Arabic script) (bjn_Arab) - Minangkabau (Arabic) (min_Arab)
#      3     2  4.662353e+02                                   Zulu (zul_Latn) - Xhosa (xho_Latn)
#      3     3  6.433070e+02    Banjar (Latin script) (bjn_Latn) - Minangkabau (Latin) (min_Latn)
#      3     4  6.469234e+02                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      3     5  6.860582e+02                           Sundanese (sun_Latn) - Javanese (jav_Latn)
#      3     6  7.624528e+02                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      3     7  7.663481e+02                 Javanese (jav_Latn) - Minangkabau (Latin) (min_Latn)
#      3     8  8.177396e+02                Sundanese (sun_Latn) - Minangkabau (Latin) (min_Latn)
#      3     9  8.182862e+02               Javanese (jav_Latn) - Banjar (Latin script) (bjn_Latn)
#      3    10  8.656373e+02              Sundanese (sun_Latn) - Banjar (Latin script) (bjn_Latn)
#      3    11  1.004687e+03                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      3    12  1.058809e+03                               Telugu (tel_Telu) - Kannada (kan_Knda)
#      3    13  1.118681e+03             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      3    14  1.201820e+03                                    Khmer (khm_Khmr) - Lao (lao_Laoo)
#      3    15  1.254304e+03                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      3    16  1.337517e+03         Banjar (Latin script) (bjn_Latn) - Standard Malay (zsm_Latn)
#      3    17  1.537590e+03             Banjar (Latin script) (bjn_Latn) - Indonesian (ind_Latn)
#      3    18  1.626155e+03                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      3    19  1.629554e+03                                  Telugu (tel_Telu) - Urdu (urd_Arab)
#      3    20  1.684517e+03           Minangkabau (Latin) (min_Latn) - Standard Malay (zsm_Latn)
#      3    21  1.754251e+03                                   Hindi (hin_Deva) - Urdu (urd_Arab)
#      3    22  1.803357e+03                      Javanese (jav_Latn) - Standard Malay (zsm_Latn)
#      3    23  1.812218e+03                                French (fra_Latn) - German (deu_Latn)
#      3    24  1.883604e+03                                Waray (war_Latn) - Swahili (swh_Latn)
#      3    25  1.884348e+03                              Ilocano (ilo_Latn) - Swahili (swh_Latn)
#      3    26  1.899043e+03                          Hebrew (heb_Hebr) - MSA (Arabic) (arb_Arab)
#      3    27  1.914612e+03                              Ilocano (ilo_Latn) - Cebuano (ceb_Latn)
#      3    28  1.937828e+03               Minangkabau (Latin) (min_Latn) - Indonesian (ind_Latn)
#      3    29  1.944624e+03                               Russian (rus_Cyrl) - German (deu_Latn)
#      3    30  1.953050e+03                     Sundanese (sun_Latn) - Standard Malay (zsm_Latn)
#      3    31  1.976563e+03                                 Kannada (kan_Knda) - Urdu (urd_Arab)
#      3    32  2.004390e+03       Minangkabau (Arabic) (min_Arab) - South Azerbaijani (azb_Arab)
#      3    33  2.039519e+03     Banjar (Arabic script) (bjn_Arab) - South Azerbaijani (azb_Arab)
#      3    34  2.045997e+03                               Russian (rus_Cyrl) - French (fra_Latn)
#      3    35  2.067836e+03                          Javanese (jav_Latn) - Indonesian (ind_Latn)
#      3    36  2.136366e+03                          Slovak (slk_Latn) - MSA (Arabic) (arb_Arab)
#      3    37  2.150411e+03                         Russian (rus_Cyrl) - MSA (Arabic) (arb_Arab)
#      3    38  2.206061e+03                     Minangkabau (Arabic) (min_Arab) - Lao (lao_Laoo)
#      3    39  2.241625e+03                         Swahili (swh_Latn) - MSA (Arabic) (arb_Arab)
#      3    40  2.245416e+03                              Cebuano (ceb_Latn) - Swahili (swh_Latn)
#      3    41  2.277970e+03                                Slovak (slk_Latn) - Hebrew (heb_Hebr)
#      3    42  2.278649e+03                            Indonesian (ind_Latn) - French (fra_Latn)
#      3    43  2.279236e+03                         Sundanese (sun_Latn) - Indonesian (ind_Latn)
#      3    44  2.287415e+03                   Banjar (Arabic script) (bjn_Arab) - Lao (lao_Laoo)
#      3    45  2.305809e+03                        Standard Malay (zsm_Latn) - French (fra_Latn)
#      3    46  2.360706e+03                               Swahili (swh_Latn) - Slovak (slk_Latn)
#      3    47  2.375257e+03                            Indonesian (ind_Latn) - German (deu_Latn)
#      3    48  2.424625e+03                               Slovak (slk_Latn) - Russian (rus_Cyrl)
#      3    49  2.452556e+03                        Standard Malay (zsm_Latn) - German (deu_Latn)
#      3    50  2.455655e+03                                 Telugu (tel_Telu) - Hindi (hin_Deva)
#      4     1  8.955662e+02                                   Zulu (zul_Latn) - Xhosa (xho_Latn)
#      4     2  9.464044e+02  Banjar (Arabic script) (bjn_Arab) - Minangkabau (Arabic) (min_Arab)
#      4     3  1.116824e+03                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      4     4  1.254130e+03                           Sundanese (sun_Latn) - Javanese (jav_Latn)
#      4     5  1.371831e+03    Banjar (Latin script) (bjn_Latn) - Minangkabau (Latin) (min_Latn)
#      4     6  1.410049e+03                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      4     7  1.564662e+03               Javanese (jav_Latn) - Banjar (Latin script) (bjn_Latn)
#      4     8  1.619267e+03              Sundanese (sun_Latn) - Banjar (Latin script) (bjn_Latn)
#      4     9  1.736762e+03                 Javanese (jav_Latn) - Minangkabau (Latin) (min_Latn)
#      4    10  1.757059e+03                Sundanese (sun_Latn) - Minangkabau (Latin) (min_Latn)
#      4    11  1.799721e+03             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      4    12  1.879027e+03                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      4    13  2.117071e+03                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      4    14  2.236061e+03                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      4    15  2.283909e+03         Banjar (Latin script) (bjn_Latn) - Standard Malay (zsm_Latn)
#      4    16  2.398007e+03                              Ilocano (ilo_Latn) - Cebuano (ceb_Latn)
#      4    17  2.418319e+03                              Ilocano (ilo_Latn) - Tagalog (tgl_Latn)
#      4    18  2.678883e+03                              Tagalog (tgl_Latn) - Swahili (swh_Latn)
#      4    19  2.687221e+03                              Ilocano (ilo_Latn) - Swahili (swh_Latn)
#      4    20  2.709306e+03             Banjar (Latin script) (bjn_Latn) - Indonesian (ind_Latn)
#      4    21  2.721723e+03                      Javanese (jav_Latn) - Standard Malay (zsm_Latn)
#      4    22  2.795218e+03                                Waray (war_Latn) - Swahili (swh_Latn)
#      4    23  2.855897e+03                     Sundanese (sun_Latn) - Standard Malay (zsm_Latn)
#      4    24  2.901630e+03                              Cebuano (ceb_Latn) - Swahili (swh_Latn)
#      4    25  2.914792e+03                               Telugu (tel_Telu) - Kannada (kan_Knda)
#      4    26  2.982772e+03                            Sundanese (sun_Latn) - Ilocano (ilo_Latn)
#      4    27  3.029564e+03                             Javanese (jav_Latn) - Ilocano (ilo_Latn)
#      4    28  3.106956e+03                    Minangkabau (Latin) (min_Latn) - Waray (war_Latn)
#      4    29  3.129755e+03           Minangkabau (Latin) (min_Latn) - Standard Malay (zsm_Latn)
#      4    30  3.177645e+03                          Javanese (jav_Latn) - Indonesian (ind_Latn)
#      4    31  3.260804e+03                                  Thai (tha_Thai) - Hebrew (heb_Hebr)
#      4    32  3.283302e+03                                   Hindi (hin_Deva) - Urdu (urd_Arab)
#      4    33  3.305383e+03                         Tagalog (tgl_Latn) - MSA (Arabic) (arb_Arab)
#      4    34  3.307789e+03                         Sundanese (sun_Latn) - Indonesian (ind_Latn)
#      4    35  3.333958e+03                  Banjar (Latin script) (bjn_Latn) - Waray (war_Latn)
#      4    36  3.379441e+03                               Russian (rus_Cyrl) - French (fra_Latn)
#      4    37  3.401637e+03                                 Kannada (kan_Knda) - Urdu (urd_Arab)
#      4    38  3.413240e+03                        Standard Malay (zsm_Latn) - German (deu_Latn)
#      4    39  3.432049e+03                            Indonesian (ind_Latn) - German (deu_Latn)
#      4    40  3.451588e+03                              Sundanese (sun_Latn) - Waray (war_Latn)
#      4    41  3.476851e+03                            Sundanese (sun_Latn) - Swahili (swh_Latn)
#      4    42  3.513169e+03                               Javanese (jav_Latn) - Waray (war_Latn)
#      4    43  3.513976e+03                Banjar (Latin script) (bjn_Latn) - Ilocano (ilo_Latn)
#      4    44  3.537500e+03                             Javanese (jav_Latn) - Swahili (swh_Latn)
#      4    45  3.561998e+03                                Cebuano (ceb_Latn) - Xhosa (xho_Latn)
#      4    46  3.571770e+03                Banjar (Latin script) (bjn_Latn) - Swahili (swh_Latn)
#      4    47  3.584130e+03                               Tagalog (tgl_Latn) - German (deu_Latn)
#      4    48  3.622204e+03                  Minangkabau (Latin) (min_Latn) - Ilocano (ilo_Latn)
#      4    49  3.637941e+03                         Swahili (swh_Latn) - MSA (Arabic) (arb_Arab)
#      4    50  3.645485e+03               Minangkabau (Latin) (min_Latn) - Indonesian (ind_Latn)
#      5     1  1.661284e+03                                   Zulu (zul_Latn) - Xhosa (xho_Latn)
#      5     2  1.692098e+03  Banjar (Arabic script) (bjn_Arab) - Minangkabau (Arabic) (min_Arab)
#      5     3  2.174990e+03                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      5     4  2.503530e+03                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      5     5  2.565569e+03                           Sundanese (sun_Latn) - Javanese (jav_Latn)
#      5     6  2.615897e+03    Banjar (Latin script) (bjn_Latn) - Minangkabau (Latin) (min_Latn)
#      5     7  2.659922e+03                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      5     8  2.908466e+03                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      5     9  3.153583e+03               Javanese (jav_Latn) - Banjar (Latin script) (bjn_Latn)
#      5    10  3.221216e+03                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      5    11  3.267353e+03                 Javanese (jav_Latn) - Minangkabau (Latin) (min_Latn)
#      5    12  3.380951e+03                               Telugu (tel_Telu) - Kannada (kan_Knda)
#      5    13  3.495485e+03                               French (fra_Latn) - Spanish (spa_Latn)
#      5    14  3.521221e+03              Sundanese (sun_Latn) - Banjar (Latin script) (bjn_Latn)
#      5    15  3.664476e+03             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      5    16  3.666407e+03                              Ilocano (ilo_Latn) - Cebuano (ceb_Latn)
#      5    17  3.702392e+03                Sundanese (sun_Latn) - Minangkabau (Latin) (min_Latn)
#      5    18  3.974937e+03                                   Hindi (hin_Deva) - Urdu (urd_Arab)
#      5    19  4.043951e+03                                  Telugu (tel_Telu) - Urdu (urd_Arab)
#      5    20  4.366853e+03                               Russian (rus_Cyrl) - German (deu_Latn)
#      5    21  4.740480e+03                               Spanish (spa_Latn) - German (deu_Latn)
#      5    22  4.761642e+03                                French (fra_Latn) - German (deu_Latn)
#      5    23  4.775069e+03                            Sundanese (sun_Latn) - Ilocano (ilo_Latn)
#      5    24  4.805010e+03             Banjar (Latin script) (bjn_Latn) - Indonesian (ind_Latn)
#      5    25  4.873833e+03                         Russian (rus_Cyrl) - MSA (Arabic) (arb_Arab)
#      5    26  4.884074e+03                              Ilocano (ilo_Latn) - Tagalog (tgl_Latn)
#      5    27  4.955932e+03         Banjar (Latin script) (bjn_Latn) - Standard Malay (zsm_Latn)
#      5    28  5.097485e+03                      Javanese (jav_Latn) - Standard Malay (zsm_Latn)
#      5    29  5.113902e+03                          MSA (Arabic) (arb_Arab) - German (deu_Latn)
#      5    30  5.153206e+03                             Javanese (jav_Latn) - Ilocano (ilo_Latn)
#      5    31  5.154290e+03                                    Khmer (khm_Khmr) - Lao (lao_Laoo)
#      5    32  5.185927e+03                              Sundanese (sun_Latn) - Waray (war_Latn)
#      5    33  5.193662e+03                     Sundanese (sun_Latn) - Standard Malay (zsm_Latn)
#      5    34  5.229221e+03                               Russian (rus_Cyrl) - French (fra_Latn)
#      5    35  5.349123e+03                          Javanese (jav_Latn) - Indonesian (ind_Latn)
#      5    36  5.441044e+03                  Minangkabau (Latin) (min_Latn) - Swahili (swh_Latn)
#      5    37  5.454755e+03                              Russian (rus_Cyrl) - Spanish (spa_Latn)
#      5    38  5.576799e+03                               Javanese (jav_Latn) - Waray (war_Latn)
#      5    39  5.611540e+03                Banjar (Latin script) (bjn_Latn) - Swahili (swh_Latn)
#      5    40  5.627064e+03                         Sundanese (sun_Latn) - Indonesian (ind_Latn)
#      5    41  5.846794e+03                                 Kannada (kan_Knda) - Urdu (urd_Arab)
#      5    42  5.902976e+03                Banjar (Latin script) (bjn_Latn) - Ilocano (ilo_Latn)
#      5    43  5.918790e+03                                 Telugu (tel_Telu) - Hindi (hin_Deva)
#      5    44  5.966730e+03               Minangkabau (Latin) (min_Latn) - Indonesian (ind_Latn)
#      5    45  6.022108e+03                              Tagalog (tgl_Latn) - Swahili (swh_Latn)
#      5    46  6.037147e+03                  Minangkabau (Latin) (min_Latn) - Ilocano (ilo_Latn)
#      5    47  6.039221e+03                              Ilocano (ilo_Latn) - Swahili (swh_Latn)
#      5    48  6.050995e+03                             Javanese (jav_Latn) - Swahili (swh_Latn)
#      5    49  6.058877e+03          North Azerbaijani (azj_Latn) - South Azerbaijani (azb_Arab)
#      5    50  6.074079e+03                     Minangkabau (Arabic) (min_Arab) - Lao (lao_Laoo)
#      6     1  4.018098e+03  Banjar (Arabic script) (bjn_Arab) - Minangkabau (Arabic) (min_Arab)
#      6     2  4.811927e+03                                   Zulu (zul_Latn) - Xhosa (xho_Latn)
#      6     3  6.486907e+03                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      6     4  7.264706e+03                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      6     5  7.489500e+03    Banjar (Latin script) (bjn_Latn) - Minangkabau (Latin) (min_Latn)
#      6     6  7.599255e+03                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      6     7  7.950540e+03                           Sundanese (sun_Latn) - Javanese (jav_Latn)
#      6     8  7.965485e+03                                    Khmer (khm_Khmr) - Lao (lao_Laoo)
#      6     9  8.708765e+03                 Javanese (jav_Latn) - Minangkabau (Latin) (min_Latn)
#      6    10  9.536779e+03               Javanese (jav_Latn) - Banjar (Latin script) (bjn_Latn)
#      6    11  9.570941e+03                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      6    12  9.813284e+03                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      6    13  9.888235e+03                               French (fra_Latn) - Spanish (spa_Latn)
#      6    14  1.033619e+04                                French (fra_Latn) - German (deu_Latn)
#      6    15  1.037062e+04                              Ilocano (ilo_Latn) - Cebuano (ceb_Latn)
#      6    16  1.102142e+04                                  Telugu (tel_Telu) - Urdu (urd_Arab)
#      6    17  1.107297e+04                Sundanese (sun_Latn) - Minangkabau (Latin) (min_Latn)
#      6    18  1.109122e+04             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      6    19  1.150319e+04                               Spanish (spa_Latn) - German (deu_Latn)
#      6    20  1.160673e+04                               Telugu (tel_Telu) - Kannada (kan_Knda)
#      6    21  1.240487e+04                               Russian (rus_Cyrl) - German (deu_Latn)
#      6    22  1.242629e+04                     Sundanese (sun_Latn) - Standard Malay (zsm_Latn)
#      6    23  1.252250e+04                         Sundanese (sun_Latn) - Indonesian (ind_Latn)
#      6    24  1.253284e+04              Sundanese (sun_Latn) - Banjar (Latin script) (bjn_Latn)
#      6    25  1.266493e+04                              Ilocano (ilo_Latn) - Tagalog (tgl_Latn)
#      6    26  1.291782e+04                      Javanese (jav_Latn) - Standard Malay (zsm_Latn)
#      6    27  1.300879e+04                            Thai (tha_Thai) - MSA (Arabic) (arb_Arab)
#      6    28  1.310099e+04                              Cebuano (ceb_Latn) - Swahili (swh_Latn)
#      6    29  1.329039e+04                               Russian (rus_Cyrl) - French (fra_Latn)
#      6    30  1.333941e+04                          Javanese (jav_Latn) - Indonesian (ind_Latn)
#      6    31  1.349111e+04                                Slovak (slk_Latn) - German (deu_Latn)
#      6    32  1.356001e+04                               Javanese (jav_Latn) - Waray (war_Latn)
#      6    33  1.372560e+04                                Kannada (kan_Knda) - Hindi (hin_Deva)
#      6    34  1.372603e+04                                     Lao (lao_Laoo) - Thai (tha_Thai)
#      6    35  1.375374e+04                    Minangkabau (Latin) (min_Latn) - Waray (war_Latn)
#      6    36  1.383655e+04                    North Azerbaijani (azj_Latn) - Turkish (tur_Latn)
#      6    37  1.386089e+04                              Tagalog (tgl_Latn) - Swahili (swh_Latn)
#      6    38  1.456066e+04                             Javanese (jav_Latn) - Cebuano (ceb_Latn)
#      6    39  1.465004e+04                  Banjar (Latin script) (bjn_Latn) - Waray (war_Latn)
#      6    40  1.465635e+04                                   Khmer (khm_Khmr) - Thai (tha_Thai)
#      6    41  1.475042e+04                                Waray (war_Latn) - Swahili (swh_Latn)
#      6    42  1.482064e+04                              Ilocano (ilo_Latn) - Swahili (swh_Latn)
#      6    43  1.485272e+04                               Slovak (slk_Latn) - Russian (rus_Cyrl)
#      6    44  1.488483e+04                                 Kannada (kan_Knda) - Urdu (urd_Arab)
#      6    45  1.501734e+04                         Swahili (swh_Latn) - MSA (Arabic) (arb_Arab)
#      6    46  1.504933e+04                           Indonesian (ind_Latn) - Spanish (spa_Latn)
#      6    47  1.504997e+04                   Minangkabau (Arabic) (min_Arab) - Khmer (khm_Khmr)
#      6    48  1.515660e+04                              Russian (rus_Cyrl) - Spanish (spa_Latn)
#      6    49  1.534425e+04                  Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#      6    50  1.536582e+04                               Tagalog (tgl_Latn) - German (deu_Latn)
#      7     1  5.049432e+03  Banjar (Arabic script) (bjn_Arab) - Minangkabau (Arabic) (min_Arab)
#      7     2  6.198422e+03                                   Zulu (zul_Latn) - Xhosa (xho_Latn)
#      7     3  8.174647e+03                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      7     4  9.371480e+03                               Telugu (tel_Telu) - Kannada (kan_Knda)
#      7     5  9.680402e+03                           Sundanese (sun_Latn) - Javanese (jav_Latn)
#      7     6  9.795167e+03                                    Khmer (khm_Khmr) - Lao (lao_Laoo)
#      7     7  1.029120e+04                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      7     8  1.076433e+04                 Javanese (jav_Latn) - Minangkabau (Latin) (min_Latn)
#      7     9  1.132880e+04                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      7    10  1.147487e+04              Sundanese (sun_Latn) - Banjar (Latin script) (bjn_Latn)
#      7    11  1.170282e+04                Sundanese (sun_Latn) - Minangkabau (Latin) (min_Latn)
#      7    12  1.240573e+04    Banjar (Latin script) (bjn_Latn) - Minangkabau (Latin) (min_Latn)
#      7    13  1.310541e+04               Javanese (jav_Latn) - Banjar (Latin script) (bjn_Latn)
#      7    14  1.351847e+04                                French (fra_Latn) - German (deu_Latn)
#      7    15  1.381489e+04                                   Hindi (hin_Deva) - Urdu (urd_Arab)
#      7    16  1.450853e+04                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      7    17  1.534703e+04                              Korean (kor_Hang) - Japanese (jpn_Jpan)
#      7    18  1.598657e+04                          Javanese (jav_Latn) - Indonesian (ind_Latn)
#      7    19  1.606571e+04                            Thai (tha_Thai) - MSA (Arabic) (arb_Arab)
#      7    20  1.636839e+04                          MSA (Arabic) (arb_Arab) - German (deu_Latn)
#      7    21  1.644621e+04                          MSA (Arabic) (arb_Arab) - French (fra_Latn)
#      7    22  1.652262e+04               Minangkabau (Latin) (min_Latn) - Indonesian (ind_Latn)
#      7    23  1.666788e+04                               Russian (rus_Cyrl) - German (deu_Latn)
#      7    24  1.669325e+04                               Russian (rus_Cyrl) - French (fra_Latn)
#      7    25  1.702564e+04                                Slovak (slk_Latn) - German (deu_Latn)
#      7    26  1.719979e+04                         Russian (rus_Cyrl) - MSA (Arabic) (arb_Arab)
#      7    27  1.727221e+04                      Javanese (jav_Latn) - Standard Malay (zsm_Latn)
#      7    28  1.736388e+04                                     Lao (lao_Laoo) - Thai (tha_Thai)
#      7    29  1.773854e+04           Minangkabau (Latin) (min_Latn) - Standard Malay (zsm_Latn)
#      7    30  1.776119e+04                             Javanese (jav_Latn) - Swahili (swh_Latn)
#      7    31  1.790659e+04                                  Telugu (tel_Telu) - Urdu (urd_Arab)
#      7    32  1.800394e+04                       Standard Malay (zsm_Latn) - Swahili (swh_Latn)
#      7    33  1.818199e+04                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      7    34  1.879276e+04                              Ilocano (ilo_Latn) - Cebuano (ceb_Latn)
#      7    35  1.880269e+04                         Sundanese (sun_Latn) - Indonesian (ind_Latn)
#      7    36  1.914132e+04       Minangkabau (Arabic) (min_Arab) - South Azerbaijani (azb_Arab)
#      7    37  1.941444e+04                              Ilocano (ilo_Latn) - Tagalog (tgl_Latn)
#      7    38  1.947766e+04                                   Khmer (khm_Khmr) - Thai (tha_Thai)
#      7    39  1.962193e+04                               Slovak (slk_Latn) - Russian (rus_Cyrl)
#      7    40  1.965731e+04                  Minangkabau (Latin) (min_Latn) - Swahili (swh_Latn)
#      7    41  1.968930e+04                               French (fra_Latn) - Spanish (spa_Latn)
#      7    42  1.970419e+04                          Slovak (slk_Latn) - MSA (Arabic) (arb_Arab)
#      7    43  2.001983e+04                                  Zulu (zul_Latn) - Hebrew (heb_Hebr)
#      7    44  2.006210e+04                   Minangkabau (Arabic) (min_Arab) - Waray (war_Latn)
#      7    45  2.025602e+04            Chinese (Simplified) (zho_Hans) - MSA (Arabic) (arb_Arab)
#      7    46  2.039575e+04                 Banjar (Arabic script) (bjn_Arab) - Waray (war_Latn)
#      7    47  2.059479e+04                                 Xhosa (xho_Latn) - Hebrew (heb_Hebr)
#      7    48  2.067078e+04     Banjar (Arabic script) (bjn_Arab) - South Azerbaijani (azb_Arab)
#      7    49  2.074712e+04                     North Azerbaijani (azj_Latn) - Slovak (slk_Latn)
#      7    50  2.080235e+04                           Indonesian (ind_Latn) - Swahili (swh_Latn)
#      8     1  9.838118e+03  Banjar (Arabic script) (bjn_Arab) - Minangkabau (Arabic) (min_Arab)
#      8     2  1.098763e+04                                   Zulu (zul_Latn) - Xhosa (xho_Latn)
#      8     3  1.213063e+04                               Telugu (tel_Telu) - Kannada (kan_Knda)
#      8     4  1.462929e+04                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      8     5  1.557626e+04             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      8     6  1.595892e+04                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      8     7  1.680357e+04                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      8     8  1.823849e+04                           Sundanese (sun_Latn) - Javanese (jav_Latn)
#      8     9  1.863412e+04                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      8    10  1.897073e+04                Sundanese (sun_Latn) - Minangkabau (Latin) (min_Latn)
#      8    11  2.216696e+04                               Russian (rus_Cyrl) - German (deu_Latn)
#      8    12  2.219459e+04                 Javanese (jav_Latn) - Minangkabau (Latin) (min_Latn)
#      8    13  2.226043e+04                                  Telugu (tel_Telu) - Urdu (urd_Arab)
#      8    14  2.375102e+04              Sundanese (sun_Latn) - Banjar (Latin script) (bjn_Latn)
#      8    15  2.376702e+04                            Indonesian (ind_Latn) - French (fra_Latn)
#      8    16  2.389408e+04                              Cebuano (ceb_Latn) - Swahili (swh_Latn)
#      8    17  2.392131e+04                             Javanese (jav_Latn) - Swahili (swh_Latn)
#      8    18  2.430073e+04         Banjar (Latin script) (bjn_Latn) - Standard Malay (zsm_Latn)
#      8    19  2.454784e+04                                Waray (war_Latn) - Swahili (swh_Latn)
#      8    20  2.463092e+04                        Standard Malay (zsm_Latn) - French (fra_Latn)
#      8    21  2.465843e+04             Banjar (Latin script) (bjn_Latn) - Indonesian (ind_Latn)
#      8    22  2.485829e+04                               Javanese (jav_Latn) - Waray (war_Latn)
#      8    23  2.494226e+04                     Sundanese (sun_Latn) - Standard Malay (zsm_Latn)
#      8    24  2.517779e+04                              Ilocano (ilo_Latn) - Cebuano (ceb_Latn)
#      8    25  2.526208e+04                               Slovak (slk_Latn) - Russian (rus_Cyrl)
#      8    26  2.527090e+04                              Tagalog (tgl_Latn) - Swahili (swh_Latn)
#      8    27  2.541559e+04                            Thai (tha_Thai) - MSA (Arabic) (arb_Arab)
#      8    28  2.559459e+04                                French (fra_Latn) - German (deu_Latn)
#      8    29  2.560559e+04    Banjar (Latin script) (bjn_Latn) - Minangkabau (Latin) (min_Latn)
#      8    30  2.647643e+04                                 Kannada (kan_Knda) - Urdu (urd_Arab)
#      8    31  2.652829e+04                               Tagalog (tgl_Latn) - Slovak (slk_Latn)
#      8    32  2.681222e+04          North Azerbaijani (azj_Latn) - South Azerbaijani (azb_Arab)
#      8    33  2.688210e+04                             Javanese (jav_Latn) - Cebuano (ceb_Latn)
#      8    34  2.722477e+04                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      8    35  2.746484e+04                        Standard Malay (zsm_Latn) - German (deu_Latn)
#      8    36  2.749484e+04                               Swahili (swh_Latn) - Slovak (slk_Latn)
#      8    37  2.751837e+04                          Yue Chinese (yue_Hant) - Russian (rus_Cyrl)
#      8    38  2.791149e+04                 Chinese (Simplified) (zho_Hans) - Russian (rus_Cyrl)
#      8    39  2.810539e+04                      North Azerbaijani (azj_Latn) - Hindi (hin_Deva)
#      8    40  2.831331e+04                               French (fra_Latn) - Spanish (spa_Latn)
#      8    41  2.845477e+04                  Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#      8    42  2.861739e+04                             Javanese (jav_Latn) - Tagalog (tgl_Latn)
#      8    43  2.866163e+04                                    Xhosa (xho_Latn) - Lao (lao_Laoo)
#      8    44  2.879461e+04                               Cebuano (ceb_Latn) - Slovak (slk_Latn)
#      8    45  2.882012e+04                           Yue Chinese (yue_Hant) - Korean (kor_Hang)
#      8    46  2.891839e+04                               Turkish (tur_Latn) - Slovak (slk_Latn)
#      8    47  2.903961e+04                       North Azerbaijani (azj_Latn) - Zulu (zul_Latn)
#      8    48  2.916818e+04                                  Zulu (zul_Latn) - Hebrew (heb_Hebr)
# ...
#   21. 156066672.000000 - Yue Chinese (yue_Hant) & Japanese (jpn_Jpan)
#   22. 156312800.000000 - Javanese (jav_Latn) & Banjar (Latin script) (bjn_Latn)
#   23. 159124976.000000 - Telugu (tel_Telu) & Lao (lao_Laoo)
#   24. 161600816.000000 - Telugu (tel_Telu) & Khmer (khm_Khmr)
#   25. 162738080.000000 - Chinese (Simplified) (zho_Hans) & Korean (kor_Hang)
#   26. 165936368.000000 - Korean (kor_Hang) & Telugu (tel_Telu)
#   27. 167074880.000000 - Yue Chinese (yue_Hant) & Korean (kor_Hang)
#   28. 168271936.000000 - Javanese (jav_Latn) & Minangkabau (Latin) (min_Latn)
#   29. 170047760.000000 - Chinese (Simplified) (zho_Hans) & Thai (tha_Thai)
#   30. 174175776.000000 - Lao (lao_Laoo) & Thai (tha_Thai)
#   31. 174507248.000000 - Yue Chinese (yue_Hant) & Thai (tha_Thai)
#   32. 175194784.000000 - Kannada (kan_Knda) & Hindi (hin_Deva)
#   33. 175658032.000000 - Japanese (jpn_Jpan) & Hindi (hin_Deva)
#   34. 178099936.000000 - Khmer (khm_Khmr) & Thai (tha_Thai)
#   35. 181698208.000000 - Sundanese (sun_Latn) & Banjar (Latin script) (bjn_Latn)
#   36. 182090912.000000 - Waray (war_Latn) & Ilocano (ilo_Latn)
#   37. 183619360.000000 - Korean (kor_Hang) & Thai (tha_Thai)
#   38. 188896048.000000 - Kannada (kan_Knda) & Urdu (urd_Arab)
#   39. 192797232.000000 - Banjar (Latin script) (bjn_Latn) & Minangkabau (Arabic) (min_Arab)
#   40. 195978528.000000 - Japanese (jpn_Jpan) & Khmer (khm_Khmr)
#   41. 197497008.000000 - Japanese (jpn_Jpan) & Thai (tha_Thai)
#   42. 198299728.000000 - Japanese (jpn_Jpan) & Lao (lao_Laoo)
#   43. 199342576.000000 - Hindi (hin_Deva) & Lao (lao_Laoo)
#   44. 199401888.000000 - Hindi (hin_Deva) & Khmer (khm_Khmr)
#   45. 200323200.000000 - Hindi (hin_Deva) & Thai (tha_Thai)
#   46. 200461968.000000 - Banjar (Arabic script) (bjn_Arab) & Banjar (Latin script) (bjn_Latn)
#   47. 202505760.000000 - Japanese (jpn_Jpan) & Telugu (tel_Telu)
#   48. 203029936.000000 - Minangkabau (Arabic) (min_Arab) & South Azerbaijani (azb_Arab)
#   49. 211198432.000000 - Chinese (Simplified) (zho_Hans) & Russian (rus_Cyrl)
#   50. 211939664.000000 - South Azerbaijani (azb_Arab) & Telugu (tel_Telu)
#
# Layer 30:
#   1. 32634750.000000 - Khmer (khm_Khmr) & Lao (lao_Laoo)
#   2. 36762632.000000 - Banjar (Arabic script) (bjn_Arab) & Minangkabau (Arabic) (min_Arab)
#   3. 49225780.000000 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   4. 51051072.000000 - Zulu (zul_Latn) & Xhosa (xho_Latn)
#   5. 106191688.000000 - Kannada (kan_Knda) & Lao (lao_Laoo)
#   6. 106345152.000000 - Waray (war_Latn) & Cebuano (ceb_Latn)
#   7. 113412424.000000 - Kannada (kan_Knda) & Khmer (khm_Khmr)
#   8. 116321616.000000 - Banjar (Latin script) (bjn_Latn) & Minangkabau (Latin) (min_Latn)
#   9. 118979896.000000 - Telugu (tel_Telu) & Kannada (kan_Knda)
#   10. 124728200.000000 - Telugu (tel_Telu) & Hindi (hin_Deva)
#   11. 147544416.000000 - Korean (kor_Hang) & Japanese (jpn_Jpan)
#   12. 154622656.000000 - Hindi (hin_Deva) & Urdu (urd_Arab)
#   13. 164008592.000000 - Chinese (Simplified) (zho_Hans) & Japanese (jpn_Jpan)
#   14. 168337968.000000 - Telugu (tel_Telu) & Urdu (urd_Arab)
#   15. 169375600.000000 - Yue Chinese (yue_Hant) & Hindi (hin_Deva)
#   16. 171657344.000000 - Yue Chinese (yue_Hant) & Japanese (jpn_Jpan)
#   17. 177190464.000000 - Sundanese (sun_Latn) & Minangkabau (Latin) (min_Latn)
#   18. 180958544.000000 - Chinese (Simplified) (zho_Hans) & Hindi (hin_Deva)
#   19. 182339312.000000 - Korean (kor_Hang) & Hindi (hin_Deva)
#   20. 184084720.000000 - Standard Malay (zsm_Latn) & Indonesian (ind_Latn)
#   21. 190732336.000000 - Javanese (jav_Latn) & Banjar (Latin script) (bjn_Latn)
#   22. 191387728.000000 - Yue Chinese (yue_Hant) & Thai (tha_Thai)
#   23. 192052976.000000 - Chinese (Simplified) (zho_Hans) & Thai (tha_Thai)
#   24. 197053968.000000 - Yue Chinese (yue_Hant) & Korean (kor_Hang)
#   25. 201423136.000000 - Sundanese (sun_Latn) & Javanese (jav_Latn)
#   26. 204257920.000000 - Japanese (jpn_Jpan) & Hindi (hin_Deva)
#   27. 204344464.000000 - Korean (kor_Hang) & Telugu (tel_Telu)
#   28. 208372992.000000 - Chinese (Simplified) (zho_Hans) & Korean (kor_Hang)
#   29. 209604192.000000 - Javanese (jav_Latn) & Minangkabau (Latin) (min_Latn)
#   30. 210928336.000000 - Korean (kor_Hang) & Thai (tha_Thai)
#   31. 214310624.000000 - Kannada (kan_Knda) & Hindi (hin_Deva)
#   32. 216856048.000000 - Telugu (tel_Telu) & Lao (lao_Laoo)
#   33. 218364688.000000 - Japanese (jpn_Jpan) & Thai (tha_Thai)
#   34. 219224896.000000 - Hindi (hin_Deva) & Thai (tha_Thai)
#   35. 220199024.000000 - Waray (war_Latn) & Ilocano (ilo_Latn)
#   36. 222740752.000000 - Lao (lao_Laoo) & Thai (tha_Thai)
#   37. 223481856.000000 - Banjar (Latin script) (bjn_Latn) & Minangkabau (Arabic) (min_Arab)
#   38. 227480944.000000 - Japanese (jpn_Jpan) & Telugu (tel_Telu)
#   39. 228777008.000000 - Telugu (tel_Telu) & Khmer (khm_Khmr)
#   40. 229624160.000000 - Chinese (Simplified) (zho_Hans) & Lao (lao_Laoo)
#   41. 229711488.000000 - Sundanese (sun_Latn) & Banjar (Latin script) (bjn_Latn)
#   42. 232933808.000000 - Banjar (Arabic script) (bjn_Arab) & Banjar (Latin script) (bjn_Latn)
#   43. 234502176.000000 - Chinese (Simplified) (zho_Hans) & Khmer (khm_Khmr)
#   44. 240020800.000000 - Khmer (khm_Khmr) & Thai (tha_Thai)
#   45. 240186720.000000 - Minangkabau (Arabic) (min_Arab) & Hindi (hin_Deva)
#   46. 244119920.000000 - Japanese (jpn_Jpan) & Lao (lao_Laoo)
#   47. 244448896.000000 - Chinese (Simplified) (zho_Hans) & Telugu (tel_Telu)
#   48. 246575360.000000 - Yue Chinese (yue_Hant) & Telugu (tel_Telu)
#   49. 248492800.000000 - Minangkabau (Arabic) (min_Arab) & South Azerbaijani (azb_Arab)
#   50. 249942384.000000 - Hindi (hin_Deva) & Russian (rus_Cyrl)
#
# Layer 31:
#   1. 42562580.000000 - Khmer (khm_Khmr) & Lao (lao_Laoo)
#   2. 54960852.000000 - Banjar (Arabic script) (bjn_Arab) & Minangkabau (Arabic) (min_Arab)
#   3. 65547308.000000 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   4. 70153208.000000 - Zulu (zul_Latn) & Xhosa (xho_Latn)
#   5. 130347408.000000 - Waray (war_Latn) & Cebuano (ceb_Latn)
#   6. 138482336.000000 - Banjar (Latin script) (bjn_Latn) & Minangkabau (Latin) (min_Latn)
#   7. 151458400.000000 - Kannada (kan_Knda) & Lao (lao_Laoo)
#   8. 163145856.000000 - Kannada (kan_Knda) & Khmer (khm_Khmr)
#   9. 163722592.000000 - Telugu (tel_Telu) & Kannada (kan_Knda)
#   10. 189287136.000000 - Telugu (tel_Telu) & Hindi (hin_Deva)
#   11. 210287616.000000 - Korean (kor_Hang) & Japanese (jpn_Jpan)
#   12. 219781184.000000 - Sundanese (sun_Latn) & Minangkabau (Latin) (min_Latn)
#   13. 223441696.000000 - Chinese (Simplified) (zho_Hans) & Japanese (jpn_Jpan)
#   14. 229885600.000000 - Yue Chinese (yue_Hant) & Japanese (jpn_Jpan)
#   15. 230113360.000000 - Standard Malay (zsm_Latn) & Indonesian (ind_Latn)
#   16. 233855424.000000 - Javanese (jav_Latn) & Banjar (Latin script) (bjn_Latn)
#   17. 238017040.000000 - Yue Chinese (yue_Hant) & Thai (tha_Thai)
#   18. 238026256.000000 - Chinese (Simplified) (zho_Hans) & Thai (tha_Thai)
#   19. 242401312.000000 - Sundanese (sun_Latn) & Javanese (jav_Latn)
#   20. 242671808.000000 - Yue Chinese (yue_Hant) & Hindi (hin_Deva)
#   21. 249400928.000000 - Lao (lao_Laoo) & Thai (tha_Thai)
#   22. 251459680.000000 - Hindi (hin_Deva) & Urdu (urd_Arab)
#   23. 252167104.000000 - Telugu (tel_Telu) & Urdu (urd_Arab)
#   24. 252412144.000000 - Kannada (kan_Knda) & Hindi (hin_Deva)
#   25. 255681456.000000 - Javanese (jav_Latn) & Minangkabau (Latin) (min_Latn)
#   26. 257838640.000000 - Korean (kor_Hang) & Hindi (hin_Deva)
#   27. 263906240.000000 - Chinese (Simplified) (zho_Hans) & Hindi (hin_Deva)
#   28. 264890832.000000 - Chinese (Simplified) (zho_Hans) & Lao (lao_Laoo)
#   29. 270423072.000000 - Chinese (Simplified) (zho_Hans) & Khmer (khm_Khmr)
#   30. 271486880.000000 - Khmer (khm_Khmr) & Thai (tha_Thai)
#   31. 271489472.000000 - Japanese (jpn_Jpan) & Thai (tha_Thai)
#   32. 274252608.000000 - Sundanese (sun_Latn) & Banjar (Latin script) (bjn_Latn)
#   33. 275663040.000000 - Waray (war_Latn) & Ilocano (ilo_Latn)
#   34. 284672288.000000 - Yue Chinese (yue_Hant) & Korean (kor_Hang)
#   35. 284721504.000000 - Korean (kor_Hang) & Telugu (tel_Telu)
#   36. 286974368.000000 - Korean (kor_Hang) & Thai (tha_Thai)
#   37. 291958816.000000 - Japanese (jpn_Jpan) & Hindi (hin_Deva)
#   38. 292432000.000000 - Yue Chinese (yue_Hant) & Lao (lao_Laoo)
#   39. 292637504.000000 - Japanese (jpn_Jpan) & Lao (lao_Laoo)
#   40. 293191104.000000 - Hindi (hin_Deva) & Thai (tha_Thai)
#   41. 302436672.000000 - Japanese (jpn_Jpan) & Khmer (khm_Khmr)
#   42. 307226496.000000 - Chinese (Simplified) (zho_Hans) & Korean (kor_Hang)
#   43. 313812704.000000 - Yue Chinese (yue_Hant) & Khmer (khm_Khmr)
#   44. 318273376.000000 - Japanese (jpn_Jpan) & Kannada (kan_Knda)
#   45. 319533536.000000 - Chinese (Simplified) (zho_Hans) & Kannada (kan_Knda)
#   46. 325206496.000000 - Telugu (tel_Telu) & Lao (lao_Laoo)
#   47. 325533248.000000 - Banjar (Latin script) (bjn_Latn) & Indonesian (ind_Latn)
#   48. 332161792.000000 - Kannada (kan_Knda) & Urdu (urd_Arab)
#   49. 334680768.000000 - Banjar (Latin script) (bjn_Latn) & Minangkabau (Arabic) (min_Arab)
#   50. 342217824.000000 - Telugu (tel_Telu) & Khmer (khm_Khmr)
#
# Layer 32:
#   1. 52541564.000000 - Khmer (khm_Khmr) & Lao (lao_Laoo)
#   2. 66867036.000000 - Banjar (Arabic script) (bjn_Arab) & Minangkabau (Arabic) (min_Arab)
#   3. 77576072.000000 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   4. 92941224.000000 - Zulu (zul_Latn) & Xhosa (xho_Latn)
#   5. 157562032.000000 - Banjar (Latin script) (bjn_Latn) & Minangkabau (Latin) (min_Latn)
#   6. 167282656.000000 - Waray (war_Latn) & Cebuano (ceb_Latn)
#   7. 199793664.000000 - Kannada (kan_Knda) & Lao (lao_Laoo)
#   8. 221143024.000000 - Kannada (kan_Knda) & Khmer (khm_Khmr)
#   9. 276166048.000000 - Sundanese (sun_Latn) & Javanese (jav_Latn)
#   10. 279524224.000000 - Standard Malay (zsm_Latn) & Indonesian (ind_Latn)
#   11. 281657600.000000 - Chinese (Simplified) (zho_Hans) & Japanese (jpn_Jpan)
#   12. 281902464.000000 - Sundanese (sun_Latn) & Minangkabau (Latin) (min_Latn)
#   13. 288538304.000000 - Yue Chinese (yue_Hant) & Japanese (jpn_Jpan)
#   14. 293573792.000000 - Javanese (jav_Latn) & Banjar (Latin script) (bjn_Latn)
#   15. 295440128.000000 - Telugu (tel_Telu) & Kannada (kan_Knda)
#   16. 296168224.000000 - Kannada (kan_Knda) & Hindi (hin_Deva)
#   17. 300826336.000000 - Javanese (jav_Latn) & Minangkabau (Latin) (min_Latn)
#   18. 301023648.000000 - Yue Chinese (yue_Hant) & Thai (tha_Thai)
#   19. 301213696.000000 - Chinese (Simplified) (zho_Hans) & Thai (tha_Thai)
#   20. 304677888.000000 - Telugu (tel_Telu) & Hindi (hin_Deva)
#   21. 314798176.000000 - Chinese (Simplified) (zho_Hans) & Lao (lao_Laoo)
#   22. 319393856.000000 - Korean (kor_Hang) & Japanese (jpn_Jpan)
#   23. 322364288.000000 - Lao (lao_Laoo) & Thai (tha_Thai)
#   24. 323478464.000000 - Waray (war_Latn) & Ilocano (ilo_Latn)
#   25. 326615456.000000 - Chinese (Simplified) (zho_Hans) & Khmer (khm_Khmr)
#   26. 344692544.000000 - Telugu (tel_Telu) & Urdu (urd_Arab)
#   27. 345864480.000000 - Japanese (jpn_Jpan) & Thai (tha_Thai)
#   28. 346036992.000000 - Yue Chinese (yue_Hant) & Lao (lao_Laoo)
#   29. 354203744.000000 - Sundanese (sun_Latn) & Banjar (Latin script) (bjn_Latn)
#   30. 355254496.000000 - Yue Chinese (yue_Hant) & Hindi (hin_Deva)
#   31. 361851904.000000 - Khmer (khm_Khmr) & Thai (tha_Thai)
#   32. 364311968.000000 - Japanese (jpn_Jpan) & Lao (lao_Laoo)
#   33. 370443104.000000 - Korean (kor_Hang) & Telugu (tel_Telu)
#   34. 370896960.000000 - Korean (kor_Hang) & Thai (tha_Thai)
#   35. 372636256.000000 - Banjar (Latin script) (bjn_Latn) & Indonesian (ind_Latn)
#   36. 378756928.000000 - Chinese (Simplified) (zho_Hans) & Hindi (hin_Deva)
#   37. 379520224.000000 - Yue Chinese (yue_Hant) & Khmer (khm_Khmr)
#   38. 381798848.000000 - Japanese (jpn_Jpan) & Khmer (khm_Khmr)
#   39. 391340512.000000 - Hindi (hin_Deva) & Thai (tha_Thai)
#   40. 397310464.000000 - Chinese (Simplified) (zho_Hans) & Kannada (kan_Knda)
#   41. 408395424.000000 - Japanese (jpn_Jpan) & Kannada (kan_Knda)
#   42. 409884224.000000 - Yue Chinese (yue_Hant) & Korean (kor_Hang)
#   43. 414085504.000000 - Banjar (Latin script) (bjn_Latn) & Standard Malay (zsm_Latn)
#   44. 416643552.000000 - Korean (kor_Hang) & Hindi (hin_Deva)
#   45. 417126688.000000 - Hindi (hin_Deva) & Urdu (urd_Arab)
#   46. 423105024.000000 - Yue Chinese (yue_Hant) & Kannada (kan_Knda)
#   47. 429271104.000000 - Hebrew (heb_Hebr) & MSA (Arabic) (arb_Arab)
#   48. 429523168.000000 - Kannada (kan_Knda) & Thai (tha_Thai)
#   49. 433688960.000000 - Hindi (hin_Deva) & Lao (lao_Laoo)
#   50. 437799552.000000 - Japanese (jpn_Jpan) & Hindi (hin_Deva)
#
# Layer 33:
#   1. 96147120.000000 - Banjar (Arabic script) (bjn_Arab) & Minangkabau (Arabic) (min_Arab)
#   2. 138230224.000000 - Zulu (zul_Latn) & Xhosa (xho_Latn)
#   3. 156178272.000000 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   4. 157696016.000000 - Khmer (khm_Khmr) & Lao (lao_Laoo)
#   5. 197983424.000000 - Banjar (Latin script) (bjn_Latn) & Minangkabau (Latin) (min_Latn)
#   6. 218428368.000000 - Waray (war_Latn) & Cebuano (ceb_Latn)
#   7. 320907904.000000 - Sundanese (sun_Latn) & Javanese (jav_Latn)
#   8. 329347360.000000 - Standard Malay (zsm_Latn) & Indonesian (ind_Latn)
#   9. 356460576.000000 - Kannada (kan_Knda) & Lao (lao_Laoo)
#   10. 357265632.000000 - Sundanese (sun_Latn) & Minangkabau (Latin) (min_Latn)
#   11. 369822432.000000 - Chinese (Simplified) (zho_Hans) & Japanese (jpn_Jpan)
#   12. 374927392.000000 - Chinese (Simplified) (zho_Hans) & Thai (tha_Thai)
#   13. 390899808.000000 - Waray (war_Latn) & Ilocano (ilo_Latn)
#   14. 396202336.000000 - Yue Chinese (yue_Hant) & Thai (tha_Thai)
#   15. 403228416.000000 - Yue Chinese (yue_Hant) & Japanese (jpn_Jpan)
#   16. 426968544.000000 - Japanese (jpn_Jpan) & Thai (tha_Thai)
#   17. 437998080.000000 - Sundanese (sun_Latn) & Banjar (Latin script) (bjn_Latn)
#   18. 447132064.000000 - Javanese (jav_Latn) & Minangkabau (Latin) (min_Latn)
#   19. 460273472.000000 - Banjar (Latin script) (bjn_Latn) & Indonesian (ind_Latn)
#   20. 480336544.000000 - Javanese (jav_Latn) & Banjar (Latin script) (bjn_Latn)
#   21. 507864928.000000 - Banjar (Latin script) (bjn_Latn) & Standard Malay (zsm_Latn)
#   22. 511531232.000000 - Kannada (kan_Knda) & Khmer (khm_Khmr)
#   23. 523238016.000000 - Hebrew (heb_Hebr) & MSA (Arabic) (arb_Arab)
#   24. 527596864.000000 - Korean (kor_Hang) & Japanese (jpn_Jpan)
#   25. 528158496.000000 - Lao (lao_Laoo) & Thai (tha_Thai)
#   26. 542419712.000000 - Yue Chinese (yue_Hant) & Korean (kor_Hang)
#   27. 545271872.000000 - Kannada (kan_Knda) & Thai (tha_Thai)
#   28. 546121408.000000 - Minangkabau (Latin) (min_Latn) & Indonesian (ind_Latn)
#   29. 548310592.000000 - Korean (kor_Hang) & Thai (tha_Thai)
#   30. 562162176.000000 - Vietnamese (vie_Latn) & Thai (tha_Thai)
#   31. 564745792.000000 - Chinese (Simplified) (zho_Hans) & Lao (lao_Laoo)
#   32. 566401408.000000 - Minangkabau (Latin) (min_Latn) & Standard Malay (zsm_Latn)
#   33. 566625344.000000 - Telugu (tel_Telu) & Hindi (hin_Deva)
#   34. 586684480.000000 - Chinese (Simplified) (zho_Hans) & Kannada (kan_Knda)
#   35. 587125632.000000 - Thai (tha_Thai) & Hebrew (heb_Hebr)
#   36. 598014016.000000 - Korean (kor_Hang) & Russian (rus_Cyrl)
#   37. 598319040.000000 - Chinese (Simplified) (zho_Hans) & French (fra_Latn)
#   38. 600691648.000000 - French (fra_Latn) & Spanish (spa_Latn)
#   39. 611939584.000000 - Japanese (jpn_Jpan) & Kannada (kan_Knda)
#   40. 616151104.000000 - Japanese (jpn_Jpan) & Lao (lao_Laoo)
#   41. 617554816.000000 - Ilocano (ilo_Latn) & Cebuano (ceb_Latn)
#   42. 618857216.000000 - Korean (kor_Hang) & Telugu (tel_Telu)
#   43. 625957696.000000 - Yue Chinese (yue_Hant) & Spanish (spa_Latn)
#   44. 626513408.000000 - Chinese (Simplified) (zho_Hans) & German (deu_Latn)
#   45. 630535168.000000 - Yue Chinese (yue_Hant) & German (deu_Latn)
#   46. 634323136.000000 - Yue Chinese (yue_Hant) & Kannada (kan_Knda)
#   47. 634820544.000000 - Chinese (Simplified) (zho_Hans) & Vietnamese (vie_Latn)
#   48. 639267392.000000 - Chinese (Simplified) (zho_Hans) & Spanish (spa_Latn)
#   49. 641998400.000000 - Russian (rus_Cyrl) & Hebrew (heb_Hebr)
#   50. 643360768.000000 - Thai (tha_Thai) & German (deu_Latn)

# %%
# Calculate mean and std deviation of the distances for each layer
layer_means = wasserstein_distance_matrix.mean(dim=(1, 2)).cpu().numpy()
layer_stds = wasserstein_distance_matrix.std(dim=(1, 2)).cpu().numpy()

# Create a DataFrame to display the statistics
layer_stats_df = pd.DataFrame({
	'Layer': range(-1, num_layers),
	'Mean_Distance': layer_means,
	'Std_Distance': layer_stds
})

print("Layer-wise Distance Statistics:")
print(layer_stats_df.to_string(index=False))
# Out:
# Layer-wise Distance Statistics:
#  Layer  Mean_Distance  Std_Distance
#     -1   2.852590e-03  4.691254e-04
#      0   6.386620e+02  5.423558e+02
#      1   1.813951e+03  1.223371e+03
#      2   3.709408e+03  2.356150e+03
#      3   5.247855e+03  2.999606e+03
#      4   1.030571e+04  7.206918e+03
#      5   1.445517e+04  9.123320e+03
#      6   3.149641e+04  2.058406e+04
#      7   5.193120e+04  3.755681e+04
#      8   1.039401e+05  1.072516e+05
#      9   1.236785e+05  1.112519e+05
#     10   5.913339e+05  7.385030e+05
#     11   1.273864e+06  1.538876e+06
#     12   1.227095e+06  1.536666e+06
#     13   9.167796e+05  9.011554e+05
#     14   1.501129e+06  1.844294e+06
#     15   2.085146e+06  2.176387e+06
#     16   3.144592e+06  3.231702e+06
#     17   7.488772e+06  6.520528e+06
#     18   9.458525e+06  7.799436e+06
#     19   1.195854e+07  8.861363e+06
#     20   1.440090e+07  9.155014e+06
#     21   1.890945e+07  1.163127e+07
#     22   2.342922e+07  1.380477e+07
#     23   3.219347e+07  2.115258e+07
#     24   6.297903e+07  2.924195e+07
#     25   9.665171e+07  3.340346e+07
#     26   1.484494e+08  4.907002e+07
#     27   2.181966e+08  7.525252e+07
#     28   3.010736e+08  1.075522e+08
#     29   3.907108e+08  1.497065e+08
#     30   4.736694e+08  1.797160e+08
#     31   6.274035e+08  2.350922e+08
#     32   7.872050e+08  2.917215e+08
#     33   1.277308e+09  8.138214e+08

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
# Create subplots for dendrograms across all layers
fig, axes = plt.subplots(nrows=9, ncols=5, figsize=(25, 80))
fig.suptitle('Hierarchical Clustering Dendrograms Across All Layers', fontsize=16)

# Flatten axes for easier indexing
axes = axes.flatten()

for layer_id in range(-1, num_layers):
	ax_idx = layer_id + 1
	
	# Perform clustering for this layer
	linked = linkage(wasserstein_distance_matrix[layer_id + 1].cpu().numpy(), 'complete')
	
	# Create dendrogram in the corresponding subplot
	dendrogram(linked, 
			   labels=[LANGCODE2LANGNAME[lang] for lang in languages], 
			   orientation='right',
			   ax=axes[ax_idx])
	
	axes[ax_idx].set_title(f"Layer {layer_id}", fontsize=12)
	axes[ax_idx].tick_params(axis='y', labelsize=8)
	axes[ax_idx].tick_params(axis='x', labelsize=8)

plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# Create subplots for dendrograms across all layers
fig, axes = plt.subplots(nrows=9, ncols=5, figsize=(25, 80))
fig.suptitle('Hierarchical Clustering Dendrograms Across All Layers', fontsize=16)

# Flatten axes for easier indexing
axes = axes.flatten()

# First pass: find the maximum distance across all layers
max_distance = 0
linkage_results = []
for layer_id in range(-1, num_layers):
	linked = linkage(wasserstein_distance_matrix[layer_id + 1].cpu().numpy(), 'complete')
	linkage_results.append(linked)
	max_distance = max(max_distance, linked[:, 2].max())

# Second pass: create dendrograms with consistent scale
for layer_id in range(-1, num_layers):
	ax_idx = layer_id + 1
	
	# Create dendrogram in the corresponding subplot
	dendrogram(linkage_results[ax_idx], 
			   labels=[LANGCODE2LANGNAME[lang] for lang in languages], 
			   orientation='right',
			   ax=axes[ax_idx])
	
	axes[ax_idx].set_title(f"Layer {layer_id}", fontsize=12)
	axes[ax_idx].tick_params(axis='y', labelsize=8)
	axes[ax_idx].tick_params(axis='x', labelsize=8)
	# axes[ax_idx].set_xlim([0, max_distance])  # Set consistent x-axis limits

plt.tight_layout()
plt.show()
