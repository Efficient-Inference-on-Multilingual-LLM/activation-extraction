# %%
import pandas as pd
import numpy as np
import torch
import glob
from tqdm import tqdm
import os
import sys

# Change to parent directory
os.chdir('..')
# Add current directory to path
sys.path.append('.')

# Now import
from src.utils.const import LANGCODE2LANGNAME, LANGNAME2LANGCODE, EXP2_CONFIG

# %%
model_name = 'gemma-3-4b-it' # 1152 size for 1b, 2560 for 4b
model_to_num_layers = {
    'gemma-3-1b-it': 26,
	'gemma-3-4b-it': 34,
    'gemma-3-270m-it': 18,
    'gemma-2-9b-it': 42
}
model_to_hidden_size = {
	'gemma-3-1b-it': 1152,
	'gemma-3-4b-it': 2560,
	'gemma-3-270m-it': 640,
	'gemma-2-9b-it': 3584
}
num_layers = model_to_num_layers[model_name]
extraction_mode = 'raw'
token_position = 'last_token'
languages = glob.glob('outputs/topic_classification/gemma-3-4b-it/raw/*')
languages = sorted([lang.split('/')[-1] for lang in languages])
text_ids = glob.glob('outputs/topic_classification/gemma-3-4b-it/raw/ace_Latn/*')
text_ids = [text_id.split('/')[-1].split('.')[0] for text_id in text_ids]

# %%
# # Extract language codes from the comment and add eng_Latn
# languages = [
# 	'vie_Latn',  # Vietnamese
# 	'ind_Latn',  # Indonesian
# 	'tha_Thai',  # Thai
# 	'zsm_Latn',  # Malay
# 	'mya_Mymr',  # Burmese -> 0 problem
# 	'tgl_Latn',  # Tagalog
# 	'khm_Khmr',  # Khmer
# 	'ceb_Latn',  # Cebuano
# 	'lao_Laoo',  # Lao
# 	'jav_Latn',  # Javanese
# 	'war_Latn',  # Waray
# 	'sun_Latn',  # Sundanese
# 	'ilo_Latn',  # Ilocano
# 	'tam_Taml',  # Tamil
# 	'zho_Hans',  # Chinese
# 	'eng_Latn'   # English
# ]

languages = []
for family, langs in EXP2_CONFIG['languages'].items():
	languages.extend(langs)

languages = [LANGNAME2LANGCODE[lang] for lang in languages]
languages
# Out:
# ['eng_Latn',
#  'deu_Latn',
#  'spa_Latn',
#  'fra_Latn',
#  'arb_Arab',
#  'heb_Hebr',
#  'rus_Cyrl',
#  'slk_Latn',
#  'tha_Thai',
#  'lao_Laoo',
#  'khm_Khmr',
#  'vie_Latn',
#  'swh_Latn',
#  'xho_Latn',
#  'zul_Latn',
#  'urd_Arab',
#  'hin_Deva',
#  'kan_Knda',
#  'tel_Telu',
#  'jpn_Jpan',
#  'kor_Hang',
#  'tur_Latn',
#  'azb_Arab',
#  'azj_Latn',
#  'tgl_Latn',
#  'ceb_Latn',
#  'ilo_Latn',
#  'war_Latn',
#  'yue_Hant',
#  'zho_Hans',
#  'ind_Latn',
#  'zsm_Latn',
#  'min_Latn',
#  'min_Arab',
#  'bjn_Latn',
#  'bjn_Arab',
#  'jav_Latn',
#  'sun_Latn']

# %%
# Initialize empty torch tensor to hold all activations: [text_id, layer, language, hidden_size]
activation_per_lang = torch.zeros((len(text_ids), num_layers + 1, len(languages), model_to_hidden_size[model_name])).to('cuda')

# %%
# Load activations for all languages
text_idx = 0
for lang_idx, lang in tqdm(enumerate(languages), total=len(languages), desc='Loading activations for all languages'):
	for layer_id in range(-1, num_layers):
		if layer_id == -1:
			paths = sorted(glob.glob(f'outputs/topic_classification/{model_name}/{extraction_mode}/{lang}/*/{token_position}/layer_embed_tokens.pt'))
		else:
			paths = sorted(glob.glob(f'outputs/topic_classification/{model_name}/{extraction_mode}/{lang}/*/{token_position}/layer_{layer_id}.pt'))
		if len(paths) != len(text_ids):
			print(f"Warning: Expected {len(text_ids)} files for language '{lang}' at layer {layer_id}, but found {len(paths)} files.")
			break
		for path in paths:
			activation = torch.load(path)
			activation_per_lang[text_idx, layer_id + 1, lang_idx, :] = activation.to('cuda')
			text_idx += 1
		text_idx = 0
# Out:
# Loading activations for all languages: 100%|██████████| 38/38 [02:07<00:00,  3.35s/it]

# %%
activation_per_lang.shape
# Out:
# torch.Size([204, 35, 38, 2560])

# %%
# Resulting shape: [layer_id, lang_idx, lang_idx]
# Layer 0: [0, lang_idx, lang_idx]
# Layer 1: [1, lang_idx, lang_idx]
# Layer 2: [2, lang_idx, lang_idx]
# ...
# Layer N: [N, lang_idx, lang_idx]

# I want to compare the distances between languages across layers

# %%
# Calculate cosine distance first for each pair of text, then average
# This is the proper way: distance first, then averaging
# Resulting shape: [layer_id, lang_idx, lang_idx]

# Initialize tensor to store all pairwise distances for each text
all_distances = torch.zeros((len(text_ids), num_layers + 1, len(languages), len(languages))).to('cuda')
all_similarities = torch.zeros((len(text_ids), num_layers + 1, len(languages), len(languages))).to('cuda')

print(f"Calculating distances for {len(text_ids)} texts...")

# For each text sample, calculate pairwise cosine distances
for text_idx in tqdm(range(len(text_ids)), desc="Processing texts"):
	# Get activations for this text
	text_activations = activation_per_lang[text_idx] # [layer_id, lang_idx, hidden_size]

	# Normalize activations per layer for comparability
	normalized_text_activations_layer = torch.nn.functional.normalize(text_activations, dim=0)
	
	# Cosine similarity
	# Normalize activations for cosine similarity
	normalized_text_activations = torch.nn.functional.normalize(normalized_text_activations_layer, dim=-1)
	# Calculate dot product for this text
	similarity = torch.matmul(normalized_text_activations_layer, normalized_text_activations_layer.transpose(-2, -1))
	# Store similarity matrix for debugging
	all_similarities[text_idx] = similarity
	# Convert to cosine distance (1 - cosine_similarity)
	all_distances[text_idx] = 1 - similarity

	# If similarity close to 0, print the text activations for debugging
	if torch.any(similarity < 0.01):
		print(f"Similarity close to 0 for text index {text_idx}. Debugging info:")
		print(f"Text activations shape: {text_activations.shape}")
		print(f"Text activations (first 5 values): {text_activations[0, 0, :5]}")
		print(f"Similarity matrix (first 5x5 block):\n{similarity[:5, :5]}")
	break

# Average the distances across all texts
# This gives us the mean cosine distance between each language pair for each layer
distance_matrix = all_distances.mean(dim=0)
# For debugging, also average the similarities
similarity_matrix = all_similarities.mean(dim=0)

print(f"Distance matrix shape: {distance_matrix.shape}")
print(f"Distance range: [{distance_matrix.min().item():.4f}, {distance_matrix.max().item():.4f}]")
print("Distance calculation complete using 'distance first, then average' method.")
# Out:
# Calculating distances for 204 texts...
# Processing texts:   0%|          | 0/204 [00:00<?, ?it/s]
# Similarity close to 0 for text index 0. Debugging info:
# Text activations shape: torch.Size([35, 38, 2560])
# Text activations (first 5 values): tensor([ 0.3281,  0.2217, -0.1230,  0.1260, -0.4863], device='cuda:0')
# Similarity matrix (first 5x5 block):
# tensor([[[0.0206, 0.0135, 0.0145, 0.0131, 0.0109, 0.0112, 0.0126, 0.0130,
#           0.0150, 0.0149, 0.0138, 0.0116, 0.0119, 0.0123, 0.0124, 0.0129,
#           0.0143, 0.0127, 0.0120, 0.0174, 0.0154, 0.0135, 0.0112, 0.0129,
#           0.0130, 0.0117, 0.0126, 0.0120, 0.0161, 0.0187, 0.0131, 0.0128,
#           0.0143, 0.0133, 0.0144, 0.0138, 0.0127, 0.0126],
#          [0.0135, 0.0132, 0.0116, 0.0108, 0.0090, 0.0092, 0.0105, 0.0130,
#           0.0119, 0.0121, 0.0115, 0.0096, 0.0109, 0.0100, 0.0100, 0.0102,
#           0.0112, 0.0103, 0.0099, 0.0134, 0.0122, 0.0117, 0.0090, 0.0118,
#           0.0115, 0.0094, 0.0099, 0.0097, 0.0126, 0.0140, 0.0107, 0.0107,
#           0.0113, 0.0117, 0.0122, 0.0116, 0.0108, 0.0111],
#          [0.0145, 0.0116, 0.0141, 0.0118, 0.0095, 0.0099, 0.0108, 0.0107,
#           0.0127, 0.0130, 0.0122, 0.0100, 0.0100, 0.0105, 0.0105, 0.0112,
#           0.0122, 0.0112, 0.0105, 0.0141, 0.0128, 0.0115, 0.0093, 0.0106,
#           0.0105, 0.0099, 0.0103, 0.0098, 0.0133, 0.0145, 0.0110, 0.0108,
#           0.0118, 0.0114, 0.0120, 0.0120, 0.0107, 0.0107],
#          [0.0131, 0.0108, 0.0118, 0.0120, 0.0087, 0.0089, 0.0099, 0.0102,
#           0.0116, 0.0122, 0.0115, 0.0094, 0.0094, 0.0097, 0.0097, 0.0101,
#           0.0112, 0.0105, 0.0098, 0.0132, 0.0116, 0.0106, 0.0086, 0.0098,
#           0.0102, 0.0092, 0.0095, 0.0093, 0.0120, 0.0131, 0.0102, 0.0100,
#           0.0111, 0.0104, 0.0112, 0.0107, 0.0099, 0.0101],
#          [0.0109, 0.0090, 0.0095, 0.0087, 0.0088, 0.0079, 0.0089, 0.0091,
#           0.0100, 0.0100, 0.0096, 0.0080, 0.0082, 0.0084, 0.0081, 0.0086,
#           0.0095, 0.0085, 0.0081, 0.0115, 0.0099, 0.0091, 0.0073, 0.0088,
#           0.0088, 0.0077, 0.0082, 0.0078, 0.0102, 0.0120, 0.0085, 0.0084,
#           0.0093, 0.0090, 0.0094, 0.0092, 0.0085, 0.0086]],
#
#         [[2.0320, 1.7937, 1.6766, 1.6346, 1.4624, 1.5666, 1.7328, 1.4927,
#           1.7512, 1.8054, 1.7666, 1.6079, 1.4223, 1.4832, 1.4867, 1.5092,
#           1.4306, 1.5252, 1.4608, 1.7972, 1.7422, 1.6642, 1.4216, 1.6014,
#           1.5612, 1.4217, 1.6213, 1.4934, 1.8828, 1.9818, 1.5933, 1.4922,
#           1.6346, 1.4806, 1.6549, 1.5612, 1.4888, 1.5223],
#          [1.7937, 1.7766, 1.5689, 1.5431, 1.3808, 1.4843, 1.6310, 1.4337,
#           1.6559, 1.7103, 1.6798, 1.5348, 1.3432, 1.3926, 1.4219, 1.3941,
#           1.3372, 1.4575, 1.3698, 1.7030, 1.6069, 1.5659, 1.3501, 1.4956,
#           1.4672, 1.3245, 1.5206, 1.3754, 1.7624, 1.8420, 1.5026, 1.4319,
#           1.5455, 1.3836, 1.5408, 1.4714, 1.4209, 1.4172],
#          [1.6766, 1.5689, 1.5479, 1.4433, 1.2986, 1.3645, 1.5440, 1.3366,
#           1.5474, 1.5752, 1.5525, 1.4504, 1.2742, 1.2944, 1.3378, 1.3159,
#           1.2517, 1.3236, 1.2623, 1.5716, 1.5282, 1.4529, 1.2343, 1.4152,
#           1.3505, 1.2326, 1.4185, 1.3086, 1.6494, 1.7429, 1.4046, 1.3394,
#           1.4676, 1.3001, 1.4563, 1.3543, 1.3382, 1.3482],
#          [1.6346, 1.5431, 1.4433, 1.5340, 1.3015, 1.3625, 1.5107, 1.3232,
#           1.5179, 1.5814, 1.5528, 1.4000, 1.2437, 1.2540, 1.2978, 1.3046,
#           1.2389, 1.3222, 1.2577, 1.5714, 1.4899, 1.4118, 1.2448, 1.3701,
#           1.3510, 1.2425, 1.3913, 1.2902, 1.6041, 1.6809, 1.3694, 1.3172,
#           1.4138, 1.2679, 1.4216, 1.3255, 1.2915, 1.3155],
#          [1.4624, 1.3808, 1.2986, 1.3015, 1.2686, 1.2614, 1.3743, 1.1904,
#           1.3955, 1.4472, 1.4169, 1.2938, 1.1418, 1.1436, 1.1840, 1.2235,
#           1.1611, 1.2246, 1.1742, 1.4233, 1.3776, 1.2849, 1.1509, 1.2595,
#           1.2330, 1.1217, 1.2741, 1.1762, 1.4478, 1.5253, 1.2485, 1.2015,
#           1.3008, 1.1974, 1.2895, 1.2450, 1.1879, 1.1954]],
#
#         [[1.9592, 1.6838, 1.5507, 1.5282, 1.3817, 1.5000, 1.6025, 1.3782,
#           1.6837, 1.7055, 1.6952, 1.5159, 1.3557, 1.4447, 1.4010, 1.4569,
#           1.4006, 1.4566, 1.4388, 1.7361, 1.6361, 1.6089, 1.3561, 1.5183,
#           1.4879, 1.3332, 1.5548, 1.3819, 1.7640, 1.8422, 1.4799, 1.4036,
#           1.5150, 1.4048, 1.5425, 1.4997, 1.4215, 1.4042],
#          [1.6838, 1.6325, 1.4273, 1.4120, 1.2837, 1.3942, 1.4727, 1.2965,
#           1.5608, 1.5790, 1.5773, 1.4287, 1.2487, 1.3312, 1.3059, 1.3271,
#           1.2839, 1.3520, 1.3253, 1.6046, 1.4894, 1.4972, 1.2583, 1.4018,
#           1.3741, 1.2152, 1.4329, 1.2512, 1.6232, 1.6708, 1.3762, 1.3169,
#           1.4008, 1.2944, 1.4096, 1.3897, 1.3386, 1.2870],
#          [1.5507, 1.4273, 1.4218, 1.3451, 1.2210, 1.2773, 1.3945, 1.2149,
#           1.4558, 1.4687, 1.4657, 1.3359, 1.1857, 1.2105, 1.2310, 1.2557,
#           1.2057, 1.2508, 1.2276, 1.4935, 1.4188, 1.3718, 1.1651, 1.3153,
#           1.2585, 1.1390, 1.3361, 1.1906, 1.5155, 1.6024, 1.2880, 1.2341,
#           1.3325, 1.2071, 1.3355, 1.2676, 1.2584, 1.2225],
#          [1.5282, 1.4120, 1.3451, 1.4332, 1.2425, 1.2832, 1.3900, 1.2111,
#           1.4420, 1.4859, 1.4760, 1.3206, 1.1726, 1.1892, 1.2134, 1.2709,
#           1.2056, 1.2545, 1.2357, 1.5074, 1.4088, 1.3419, 1.1807, 1.2941,
#           1.2782, 1.1531, 1.3284, 1.1864, 1.4891, 1.5594, 1.2640, 1.2316,
#           1.3058, 1.2066, 1.3112, 1.2621, 1.2312, 1.2063],
#          [1.3817, 1.2837, 1.2210, 1.2425, 1.2338, 1.2032, 1.2740, 1.1111,
#           1.3435, 1.3864, 1.3752, 1.2283, 1.0988, 1.0953, 1.1219, 1.2062,
#           1.1359, 1.1858, 1.1470, 1.3802, 1.3056, 1.2446, 1.1149, 1.2057,
#           1.1845, 1.0707, 1.2292, 1.1040, 1.3636, 1.4389, 1.1800, 1.1397,
#           1.2152, 1.1429, 1.2136, 1.1939, 1.1394, 1.1149]],
#
#         [[2.3714, 1.8639, 1.9343, 1.9023, 1.6679, 1.7566, 1.8825, 1.6270,
#           2.0385, 2.1072, 2.0493, 1.8183, 1.6962, 1.7115, 1.6749, 1.7463,
#           1.7163, 1.7590, 1.6820, 2.1044, 1.9246, 1.8127, 1.5752, 1.7659,
#           1.7458, 1.6049, 1.8170, 1.6987, 2.1474, 2.2448, 1.7815, 1.7470,
#           1.9061, 1.7170, 1.9033, 1.8219, 1.7298, 1.7067],
#          [1.8639, 1.6980, 1.6387, 1.6214, 1.4427, 1.5102, 1.6054, 1.4136,
#           1.7351, 1.7951, 1.7803, 1.5859, 1.4330, 1.4617, 1.4584, 1.4695,
#           1.4458, 1.5236, 1.4618, 1.7766, 1.6269, 1.5727, 1.3567, 1.5107,
#           1.5037, 1.3478, 1.5628, 1.4206, 1.7988, 1.8684, 1.5409, 1.4974,
#           1.6371, 1.4660, 1.6154, 1.5606, 1.5060, 1.4607],
#          [1.9343, 1.6387, 1.8239, 1.6893, 1.4876, 1.5392, 1.6515, 1.4584,
#           1.7840, 1.8418, 1.8177, 1.6170, 1.4889, 1.4731, 1.5026, 1.5024,
#           1.4841, 1.5302, 1.4665, 1.8344, 1.6860, 1.5889, 1.3708, 1.5615,
#           1.5189, 1.3871, 1.6123, 1.4840, 1.8683, 1.9791, 1.5947, 1.5428,
#           1.6957, 1.4873, 1.6908, 1.5654, 1.5643, 1.5220],
#          [1.9023, 1.6214, 1.6893, 1.8069, 1.4935, 1.5303, 1.6659, 1.4407,
#           1.7491, 1.8451, 1.8138, 1.6173, 1.4691, 1.4594, 1.4885, 1.5240,
#           1.4894, 1.5570, 1.4874, 1.8367, 1.6790, 1.5410, 1.3957, 1.5352,
#           1.5356, 1.3993, 1.5911, 1.4683, 1.8242, 1.9203, 1.5366, 1.5320,
#           1.6508, 1.4943, 1.6377, 1.5597, 1.5231, 1.4848],
#          [1.6679, 1.4427, 1.4876, 1.4935, 1.4627, 1.4086, 1.4623, 1.2793,
#           1.6124, 1.6826, 1.6663, 1.4359, 1.3104, 1.2976, 1.3308, 1.4165,
#           1.3771, 1.4467, 1.3682, 1.6310, 1.5075, 1.3873, 1.2668, 1.3755,
#           1.3743, 1.2622, 1.4324, 1.3221, 1.6312, 1.7254, 1.3883, 1.3694,
#           1.4855, 1.3979, 1.4718, 1.4638, 1.3770, 1.3388]],
#
#         [[2.8664, 2.3199, 2.4343, 2.3456, 2.0656, 2.0257, 2.2600, 2.0279,
#           2.3868, 2.5553, 2.5562, 2.2163, 2.0907, 2.0464, 2.0326, 2.0353,
#           2.0587, 2.1176, 1.9873, 2.6108, 2.3896, 2.2588, 1.9609, 2.2543,
#           2.1300, 2.0299, 2.1798, 2.0555, 2.6552, 2.7210, 2.1833, 2.0409,
#           2.3765, 2.1021, 2.3369, 2.1883, 2.1045, 2.0741],
#          [2.3199, 2.1927, 2.1376, 2.0833, 1.8582, 1.8184, 1.9882, 1.8088,
#           2.1238, 2.2804, 2.2989, 1.9971, 1.8290, 1.8057, 1.8271, 1.8054,
#           1.8044, 1.9069, 1.7836, 2.2493, 2.1122, 2.0201, 1.7460, 1.9830,
#           1.8991, 1.7890, 1.9433, 1.8194, 2.3097, 2.3783, 1.9309, 1.8071,
#           2.0995, 1.8640, 2.0317, 1.9333, 1.8858, 1.8379],
#          [2.4343, 2.1376, 2.4307, 2.1838, 1.9318, 1.8771, 2.0883, 1.9024,
#           2.2319, 2.3799, 2.3938, 2.0941, 1.9583, 1.9068, 1.9227, 1.8606,
#           1.8877, 1.9690, 1.8419, 2.4088, 2.1370, 2.1290, 1.8080, 2.0851,
#           1.9702, 1.8594, 2.0123, 1.8924, 2.4458, 2.5062, 2.0206, 1.8972,
#           2.2179, 1.9667, 2.1487, 2.0157, 1.9936, 1.9231],
#          [2.3456, 2.0833, 2.1838, 2.2436, 1.8891, 1.8239, 2.0278, 1.8389,
#           2.1313, 2.3054, 2.3162, 2.0025, 1.8506, 1.8124, 1.8358, 1.8075,
#           1.8297, 1.9147, 1.7962, 2.2900, 2.0882, 2.0077, 1.7643, 1.9913,
#           1.9345, 1.8251, 1.9600, 1.8501, 2.2949, 2.3707, 1.9348, 1.8233,
#           2.1196, 1.9107, 2.0665, 1.9493, 1.8976, 1.8451],
#          [2.0656, 1.8582, 1.9318, 1.8891, 1.8499, 1.6831, 1.8051, 1.6325,
#           1.9623, 2.0844, 2.1060, 1.7958, 1.6288, 1.6237, 1.6330, 1.6735,
#           1.7073, 1.7770, 1.6609, 2.0544, 1.8842, 1.7931, 1.5979, 1.7759,
#           1.7217, 1.5918, 1.7403, 1.6333, 2.0604, 2.1471, 1.7410, 1.6323,
#           1.8806, 1.7468, 1.8310, 1.8009, 1.7031, 1.6442]]], device='cuda:0')
# Distance matrix shape: torch.Size([35, 38, 38])
# Distance range: [-3.1294, 0.0049]
# Distance calculation complete using 'distance first, then average' method.

# %%
# Get top k minimum distance values in each layer with their language pair identifiers

# Set k as a variable
k = 50  # You can change this value as needed

# Initialize lists to store results
all_min_distances = []
all_min_distance_pairs = []

# For each layer, find the top k minimum distances and corresponding language pairs
for layer_id in range(-1, num_layers):
	layer_distances = distance_matrix[layer_id + 1]
	
	# Create a mask to exclude diagonal elements and upper triangle (to avoid duplicates)
	mask = torch.tril(torch.ones_like(layer_distances, dtype=torch.bool), diagonal=-1)
	
	# Get all distances excluding diagonal and upper triangle, then flatten
	lower_triangle_distances = layer_distances[mask]
	
	# Get top k minimum distances
	topk_min_values, topk_indices = torch.topk(lower_triangle_distances, k=k, largest=False)
	
	# Convert flat indices back to 2D coordinates
	layer_min_distances = []
	layer_min_pairs = []
	
	# Get indices of lower triangle elements
	lower_i, lower_j = torch.where(mask)
	
	for idx in range(k):
		flat_idx = topk_indices[idx].item()
		lang_i_idx = lower_i[flat_idx].item()
		lang_j_idx = lower_j[flat_idx].item()
		
		layer_min_distances.append(topk_min_values[idx].item())
		layer_min_pairs.append((languages[lang_i_idx], languages[lang_j_idx]))
	
	all_min_distances.append(layer_min_distances)
	all_min_distance_pairs.append(layer_min_pairs)

# Create a detailed DataFrame
detailed_results = []
for layer_id in range(-1, num_layers):
	for rank in range(k):
		lang1, lang2 = all_min_distance_pairs[layer_id + 1][rank]
		detailed_results.append({
			'Layer': layer_id,
			'Rank': rank + 1,
			'Min_Distance': all_min_distances[layer_id + 1][rank],
			'Language_Pair': f"{LANGCODE2LANGNAME[lang1]} ({lang1}) - {LANGCODE2LANGNAME[lang2]} ({lang2})"
		})

results_df = pd.DataFrame(detailed_results)

print(f"Top {k} minimum distances per layer:")
print(results_df.to_string(index=False))

# Also print a summary view grouped by layer
print("\nSummary by layer:")
for layer_id in range(-1, num_layers):
	print(f"\nLayer {layer_id:2d}:")
	for rank in range(k):
		lang1, lang2 = all_min_distance_pairs[layer_id + 1][rank]
		distance = all_min_distances[layer_id + 1][rank]
		print(f"  {rank+1}. {distance:.6f} - {LANGCODE2LANGNAME[lang1]} ({lang1}) & {LANGCODE2LANGNAME[lang2]} ({lang2})")
# Out:
# Top 50 minimum distances per layer:
#  Layer  Rank  Min_Distance                                                       Language_Pair
#     -1     1      0.004803               Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#     -1     2      0.004810                Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#     -1     3      0.004815            Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#     -1     4      0.004816                            Japanese (jpn_Jpan) - English (eng_Latn)
#     -1     5      0.004819                 Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#     -1     6      0.004821                   Chinese (Simplified) (zho_Hans) - Thai (tha_Thai)
#     -1     7      0.004821                        Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#     -1     8      0.004823                             Korean (kor_Hang) - Japanese (jpn_Jpan)
#     -1     9      0.004823                  Chinese (Simplified) (zho_Hans) - Hindi (hin_Deva)
#     -1    10      0.004823                         Yue Chinese (yue_Hant) - English (eng_Latn)
#     -1    11      0.004824                               Japanese (jpn_Jpan) - Thai (tha_Thai)
#     -1    12      0.004826                                Japanese (jpn_Jpan) - Lao (lao_Laoo)
#     -1    13      0.004826                              Japanese (jpn_Jpan) - Hindi (hin_Deva)
#     -1    14      0.004826                              Korean (kor_Hang) - English (eng_Latn)
#     -1    15      0.004827                                   Khmer (khm_Khmr) - Lao (lao_Laoo)
#     -1    16      0.004829                                Thai (tha_Thai) - English (eng_Latn)
#     -1    17      0.004829                                 Lao (lao_Laoo) - English (eng_Latn)
#     -1    18      0.004830  Banjar (Latin script) (bjn_Latn) - Chinese (Simplified) (zho_Hans)
#     -1    19      0.004830              Banjar (Latin script) (bjn_Latn) - Japanese (jpn_Jpan)
#     -1    20      0.004831                              Japanese (jpn_Jpan) - Khmer (khm_Khmr)
#     -1    21      0.004831                    Chinese (Simplified) (zho_Hans) - Lao (lao_Laoo)
#     -1    22      0.004831                             Spanish (spa_Latn) - English (eng_Latn)
#     -1    23      0.004831                Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#     -1    24      0.004831    Minangkabau (Latin) (min_Latn) - Chinese (Simplified) (zho_Hans)
#     -1    25      0.004831                          Yue Chinese (yue_Hant) - Korean (kor_Hang)
#     -1    26      0.004831               Banjar (Latin script) (bjn_Latn) - English (eng_Latn)
#     -1    27      0.004831                Chinese (Simplified) (zho_Hans) - Turkish (tur_Latn)
#     -1    28      0.004832                               Hindi (hin_Deva) - English (eng_Latn)
#     -1    29      0.004832                 Minangkabau (Latin) (min_Latn) - English (eng_Latn)
#     -1    30      0.004832                Minangkabau (Latin) (min_Latn) - Japanese (jpn_Jpan)
#     -1    31      0.004832                    North Azerbaijani (azj_Latn) - Slovak (slk_Latn)
#     -1    32      0.004832                                    Lao (lao_Laoo) - Thai (tha_Thai)
#     -1    33      0.004832                             Yue Chinese (yue_Hant) - Lao (lao_Laoo)
#     -1    34      0.004833                            Japanese (jpn_Jpan) - Spanish (spa_Latn)
#     -1    35      0.004833                            Yue Chinese (yue_Hant) - Thai (tha_Thai)
#     -1    36      0.004833                 Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#     -1    37      0.004834                  Chinese (Simplified) (zho_Hans) - Khmer (khm_Khmr)
#     -1    38      0.004834                            Turkish (tur_Latn) - Japanese (jpn_Jpan)
#     -1    39      0.004834                               Khmer (khm_Khmr) - English (eng_Latn)
#     -1    40      0.004834              Banjar (Arabic script) (bjn_Arab) - English (eng_Latn)
#     -1    41      0.004835                Chinese (Simplified) (zho_Hans) - Russian (rus_Cyrl)
#     -1    42      0.004835                                Korean (kor_Hang) - Hindi (hin_Deva)
#     -1    43      0.004835             Banjar (Arabic script) (bjn_Arab) - Japanese (jpn_Jpan)
#     -1    44      0.004835                           Yue Chinese (yue_Hant) - Hindi (hin_Deva)
#     -1    45      0.004835                                 Korean (kor_Hang) - Thai (tha_Thai)
#     -1    46      0.004835                              Tagalog (tgl_Latn) - Slovak (slk_Latn)
#     -1    47      0.004836                             Turkish (tur_Latn) - English (eng_Latn)
#     -1    48      0.004836                              German (deu_Latn) - English (eng_Latn)
#     -1    49      0.004836                                  Korean (kor_Hang) - Lao (lao_Laoo)
#     -1    50      0.004836 Banjar (Arabic script) (bjn_Arab) - Chinese (Simplified) (zho_Hans)
#      0     1     -0.004859            Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      0     2     -0.004813                Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#      0     3     -0.004327                         Yue Chinese (yue_Hant) - English (eng_Latn)
#      0     4     -0.004313                    Chinese (Simplified) (zho_Hans) - Lao (lao_Laoo)
#      0     5     -0.004302               Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      0     6     -0.004127                 Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#      0     7     -0.004113                  Chinese (Simplified) (zho_Hans) - Khmer (khm_Khmr)
#      0     8     -0.004016                 Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      0     9     -0.003983                Chinese (Simplified) (zho_Hans) - Russian (rus_Cyrl)
#      0    10     -0.003980                   Chinese (Simplified) (zho_Hans) - Thai (tha_Thai)
#      0    11     -0.003956                                   Khmer (khm_Khmr) - Lao (lao_Laoo)
#      0    12     -0.003948                                 Lao (lao_Laoo) - English (eng_Latn)
#      0    13     -0.003908                            Japanese (jpn_Jpan) - English (eng_Latn)
#      0    14     -0.003891                              German (deu_Latn) - English (eng_Latn)
#      0    15     -0.003862                             Yue Chinese (yue_Hant) - Lao (lao_Laoo)
#      0    16     -0.003812                        Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      0    17     -0.003758                               Khmer (khm_Khmr) - English (eng_Latn)
#      0    18     -0.003737                          Yue Chinese (yue_Hant) - German (deu_Latn)
#      0    19     -0.003682                                Thai (tha_Thai) - English (eng_Latn)
#      0    20     -0.003667                                    Lao (lao_Laoo) - Thai (tha_Thai)
#      0    21     -0.003667                                Japanese (jpn_Jpan) - Lao (lao_Laoo)
#      0    22     -0.003666                           Yue Chinese (yue_Hant) - Khmer (khm_Khmr)
#      0    23     -0.003642                Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      0    24     -0.003638                              Korean (kor_Hang) - English (eng_Latn)
#      0    25     -0.003612                          Yue Chinese (yue_Hant) - Korean (kor_Hang)
#      0    26     -0.003593                            Yue Chinese (yue_Hant) - Thai (tha_Thai)
#      0    27     -0.003592                             Russian (rus_Cyrl) - English (eng_Latn)
#      0    28     -0.003585    Minangkabau (Latin) (min_Latn) - Chinese (Simplified) (zho_Hans)
#      0    29     -0.003498             Chinese (Simplified) (zho_Hans) - Vietnamese (vie_Latn)
#      0    30     -0.003482                                  Lao (lao_Laoo) - German (deu_Latn)
#      0    31     -0.003470  Banjar (Latin script) (bjn_Latn) - Chinese (Simplified) (zho_Hans)
#      0    32     -0.003467                              Japanese (jpn_Jpan) - Khmer (khm_Khmr)
#      0    33     -0.003460                         Yue Chinese (yue_Hant) - Russian (rus_Cyrl)
#      0    34     -0.003446                             Japanese (jpn_Jpan) - German (deu_Latn)
#      0    35     -0.003371                                 Lao (lao_Laoo) - Russian (rus_Cyrl)
#      0    36     -0.003370                                  Korean (kor_Hang) - Lao (lao_Laoo)
#      0    37     -0.003346                                  Khmer (khm_Khmr) - Thai (tha_Thai)
#      0    38     -0.003338                 Chinese (Simplified) (zho_Hans) - French (fra_Latn)
#      0    39     -0.003332                                Khmer (khm_Khmr) - German (deu_Latn)
#      0    40     -0.003327                               Japanese (jpn_Jpan) - Thai (tha_Thai)
#      0    41     -0.003317                             Spanish (spa_Latn) - English (eng_Latn)
#      0    42     -0.003304                            Japanese (jpn_Jpan) - Russian (rus_Cyrl)
#      0    43     -0.003290             Indonesian (ind_Latn) - Chinese (Simplified) (zho_Hans)
#      0    44     -0.003283                Chinese (Simplified) (zho_Hans) - Ilocano (ilo_Latn)
#      0    45     -0.003282                             Korean (kor_Hang) - Japanese (jpn_Jpan)
#      0    46     -0.003260                Chinese (Simplified) (zho_Hans) - Turkish (tur_Latn)
#      0    47     -0.003256                             Turkish (tur_Latn) - English (eng_Latn)
#      0    48     -0.003232                               Khmer (khm_Khmr) - Russian (rus_Cyrl)
#      0    49     -0.003215                                 Thai (tha_Thai) - German (deu_Latn)
#      0    50     -0.003210               Banjar (Latin script) (bjn_Latn) - English (eng_Latn)
#      1     1     -0.004324            Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      1     2     -0.004128                Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#      1     3     -0.003995               Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      1     4     -0.003782                                   Khmer (khm_Khmr) - Lao (lao_Laoo)
#      1     5     -0.003773                    Chinese (Simplified) (zho_Hans) - Lao (lao_Laoo)
#      1     6     -0.003745                         Yue Chinese (yue_Hant) - English (eng_Latn)
#      1     7     -0.003718                  Chinese (Simplified) (zho_Hans) - Khmer (khm_Khmr)
#      1     8     -0.003609                            Japanese (jpn_Jpan) - English (eng_Latn)
#      1     9     -0.003608                   Chinese (Simplified) (zho_Hans) - Thai (tha_Thai)
#      1    10     -0.003580                                    Lao (lao_Laoo) - Thai (tha_Thai)
#      1    11     -0.003578                 Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      1    12     -0.003531                        Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      1    13     -0.003526                             Yue Chinese (yue_Hant) - Lao (lao_Laoo)
#      1    14     -0.003458                                 Lao (lao_Laoo) - English (eng_Latn)
#      1    15     -0.003432                           Yue Chinese (yue_Hant) - Khmer (khm_Khmr)
#      1    16     -0.003408                               Khmer (khm_Khmr) - English (eng_Latn)
#      1    17     -0.003370                                Japanese (jpn_Jpan) - Lao (lao_Laoo)
#      1    18     -0.003352                              German (deu_Latn) - English (eng_Latn)
#      1    19     -0.003351                                Thai (tha_Thai) - English (eng_Latn)
#      1    20     -0.003328                            Yue Chinese (yue_Hant) - Thai (tha_Thai)
#      1    21     -0.003309                              Japanese (jpn_Jpan) - Khmer (khm_Khmr)
#      1    22     -0.003288                 Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#      1    23     -0.003253                                  Khmer (khm_Khmr) - Thai (tha_Thai)
#      1    24     -0.003197                Chinese (Simplified) (zho_Hans) - Russian (rus_Cyrl)
#      1    25     -0.003189                               Japanese (jpn_Jpan) - Thai (tha_Thai)
#      1    26     -0.003135                          Yue Chinese (yue_Hant) - Korean (kor_Hang)
#      1    27     -0.003118                              Korean (kor_Hang) - English (eng_Latn)
#      1    28     -0.003058                             Korean (kor_Hang) - Japanese (jpn_Jpan)
#      1    29     -0.003055                          Yue Chinese (yue_Hant) - German (deu_Latn)
#      1    30     -0.003028                                  Korean (kor_Hang) - Lao (lao_Laoo)
#      1    31     -0.002985                             Turkish (tur_Latn) - English (eng_Latn)
#      1    32     -0.002982                                Korean (kor_Hang) - Khmer (khm_Khmr)
#      1    33     -0.002964                             Japanese (jpn_Jpan) - German (deu_Latn)
#      1    34     -0.002954                             Russian (rus_Cyrl) - English (eng_Latn)
#      1    35     -0.002953                Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      1    36     -0.002900             Chinese (Simplified) (zho_Hans) - Vietnamese (vie_Latn)
#      1    37     -0.002890                Chinese (Simplified) (zho_Hans) - Ilocano (ilo_Latn)
#      1    38     -0.002889                Chinese (Simplified) (zho_Hans) - Turkish (tur_Latn)
#      1    39     -0.002867    Minangkabau (Latin) (min_Latn) - Chinese (Simplified) (zho_Hans)
#      1    40     -0.002838                            Japanese (jpn_Jpan) - Russian (rus_Cyrl)
#      1    41     -0.002838                                  Lao (lao_Laoo) - German (deu_Latn)
#      1    42     -0.002830                                Khmer (khm_Khmr) - German (deu_Latn)
#      1    43     -0.002780                         Yue Chinese (yue_Hant) - Turkish (tur_Latn)
#      1    44     -0.002768  Banjar (Latin script) (bjn_Latn) - Chinese (Simplified) (zho_Hans)
#      1    45     -0.002749                                 Thai (tha_Thai) - German (deu_Latn)
#      1    46     -0.002742                 Chinese (Simplified) (zho_Hans) - French (fra_Latn)
#      1    47     -0.002720                                 Korean (kor_Hang) - Thai (tha_Thai)
#      1    48     -0.002720                             Ilocano (ilo_Latn) - English (eng_Latn)
#      1    49     -0.002718                         Yue Chinese (yue_Hant) - Russian (rus_Cyrl)
#      1    50     -0.002699                             Spanish (spa_Latn) - English (eng_Latn)
#      2     1     -0.006407            Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      2     2     -0.006102                Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#      2     3     -0.005964                                   Khmer (khm_Khmr) - Lao (lao_Laoo)
#      2     4     -0.005913               Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      2     5     -0.005777                    Chinese (Simplified) (zho_Hans) - Lao (lao_Laoo)
#      2     6     -0.005659                                    Lao (lao_Laoo) - Thai (tha_Thai)
#      2     7     -0.005625                         Yue Chinese (yue_Hant) - English (eng_Latn)
#      2     8     -0.005553                  Chinese (Simplified) (zho_Hans) - Khmer (khm_Khmr)
#      2     9     -0.005434                             Yue Chinese (yue_Hant) - Lao (lao_Laoo)
#      2    10     -0.005428                                 Lao (lao_Laoo) - English (eng_Latn)
#      2    11     -0.005414                            Japanese (jpn_Jpan) - English (eng_Latn)
#      2    12     -0.005404                        Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      2    13     -0.005382                   Chinese (Simplified) (zho_Hans) - Thai (tha_Thai)
#      2    14     -0.005243                                Japanese (jpn_Jpan) - Lao (lao_Laoo)
#      2    15     -0.005167                                  Khmer (khm_Khmr) - Thai (tha_Thai)
#      2    16     -0.005144                               Khmer (khm_Khmr) - English (eng_Latn)
#      2    17     -0.005135                           Yue Chinese (yue_Hant) - Khmer (khm_Khmr)
#      2    18     -0.005091                                Thai (tha_Thai) - English (eng_Latn)
#      2    19     -0.004999                              Japanese (jpn_Jpan) - Khmer (khm_Khmr)
#      2    20     -0.004977                            Yue Chinese (yue_Hant) - Thai (tha_Thai)
#      2    21     -0.004968                 Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      2    22     -0.004819    Minangkabau (Latin) (min_Latn) - Chinese (Simplified) (zho_Hans)
#      2    23     -0.004815                               Japanese (jpn_Jpan) - Thai (tha_Thai)
#      2    24     -0.004799                Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      2    25     -0.004648  Banjar (Latin script) (bjn_Latn) - Chinese (Simplified) (zho_Hans)
#      2    26     -0.004604                                  Korean (kor_Hang) - Lao (lao_Laoo)
#      2    27     -0.004602                Chinese (Simplified) (zho_Hans) - Russian (rus_Cyrl)
#      2    28     -0.004580                             Spanish (spa_Latn) - English (eng_Latn)
#      2    29     -0.004532                              Korean (kor_Hang) - English (eng_Latn)
#      2    30     -0.004512                 Chinese (Simplified) (zho_Hans) - French (fra_Latn)
#      2    31     -0.004457                     Minangkabau (Latin) (min_Latn) - Lao (lao_Laoo)
#      2    32     -0.004442                 Minangkabau (Latin) (min_Latn) - English (eng_Latn)
#      2    33     -0.004428               Banjar (Latin script) (bjn_Latn) - English (eng_Latn)
#      2    34     -0.004423                              French (fra_Latn) - English (eng_Latn)
#      2    35     -0.004386             Minangkabau (Latin) (min_Latn) - Yue Chinese (yue_Hant)
#      2    36     -0.004384                   Banjar (Latin script) (bjn_Latn) - Lao (lao_Laoo)
#      2    37     -0.004371                             Korean (kor_Hang) - Japanese (jpn_Jpan)
#      2    38     -0.004338                          Yue Chinese (yue_Hant) - Korean (kor_Hang)
#      2    39     -0.004326                             Russian (rus_Cyrl) - English (eng_Latn)
#      2    40     -0.004321                                Korean (kor_Hang) - Khmer (khm_Khmr)
#      2    41     -0.004314             Chinese (Simplified) (zho_Hans) - Vietnamese (vie_Latn)
#      2    42     -0.004313                Chinese (Simplified) (zho_Hans) - Ilocano (ilo_Latn)
#      2    43     -0.004307                   Minangkabau (Latin) (min_Latn) - Khmer (khm_Khmr)
#      2    44     -0.004275           Banjar (Latin script) (bjn_Latn) - Yue Chinese (yue_Hant)
#      2    45     -0.004257                 Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#      2    46     -0.004256                         Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      2    47     -0.004246 Banjar (Arabic script) (bjn_Arab) - Chinese (Simplified) (zho_Hans)
#      2    48     -0.004235                  Banjar (Arabic script) (bjn_Arab) - Lao (lao_Laoo)
#      2    49     -0.004235                              German (deu_Latn) - English (eng_Latn)
#      2    50     -0.004227                                 Kannada (kan_Knda) - Lao (lao_Laoo)
#      3     1     -0.009051            Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      3     2     -0.008645                                   Khmer (khm_Khmr) - Lao (lao_Laoo)
#      3     3     -0.008454               Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      3     4     -0.008436                Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#      3     5     -0.008286                  Chinese (Simplified) (zho_Hans) - Khmer (khm_Khmr)
#      3     6     -0.008202                    Chinese (Simplified) (zho_Hans) - Lao (lao_Laoo)
#      3     7     -0.008114                         Yue Chinese (yue_Hant) - English (eng_Latn)
#      3     8     -0.008107                        Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      3     9     -0.008082                             Yue Chinese (yue_Hant) - Lao (lao_Laoo)
#      3    10     -0.007989                           Yue Chinese (yue_Hant) - Khmer (khm_Khmr)
#      3    11     -0.007896                            Japanese (jpn_Jpan) - English (eng_Latn)
#      3    12     -0.007783                              Japanese (jpn_Jpan) - Khmer (khm_Khmr)
#      3    13     -0.007762                                Japanese (jpn_Jpan) - Lao (lao_Laoo)
#      3    14     -0.007628                               Khmer (khm_Khmr) - English (eng_Latn)
#      3    15     -0.007624                                 Lao (lao_Laoo) - English (eng_Latn)
#      3    16     -0.007608                                    Lao (lao_Laoo) - Thai (tha_Thai)
#      3    17     -0.007418                   Chinese (Simplified) (zho_Hans) - Thai (tha_Thai)
#      3    18     -0.007405                                  Khmer (khm_Khmr) - Thai (tha_Thai)
#      3    19     -0.007383                Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      3    20     -0.007232                 Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      3    21     -0.007159                            Yue Chinese (yue_Hant) - Thai (tha_Thai)
#      3    22     -0.007091    Minangkabau (Latin) (min_Latn) - Chinese (Simplified) (zho_Hans)
#      3    23     -0.007087                         Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      3    24     -0.007031                             Spanish (spa_Latn) - English (eng_Latn)
#      3    25     -0.006947                   Minangkabau (Latin) (min_Latn) - Khmer (khm_Khmr)
#      3    26     -0.006906                            Japanese (jpn_Jpan) - Spanish (spa_Latn)
#      3    27     -0.006835                          Yue Chinese (yue_Hant) - Korean (kor_Hang)
#      3    28     -0.006834                               Japanese (jpn_Jpan) - Thai (tha_Thai)
#      3    29     -0.006832                               Khmer (khm_Khmr) - Spanish (spa_Latn)
#      3    30     -0.006830                                  Korean (kor_Hang) - Lao (lao_Laoo)
#      3    31     -0.006812                              Korean (kor_Hang) - English (eng_Latn)
#      3    32     -0.006800                             Korean (kor_Hang) - Japanese (jpn_Jpan)
#      3    33     -0.006798                                Thai (tha_Thai) - English (eng_Latn)
#      3    34     -0.006774                     Minangkabau (Latin) (min_Latn) - Lao (lao_Laoo)
#      3    35     -0.006766                                Korean (kor_Hang) - Khmer (khm_Khmr)
#      3    36     -0.006764                                 Lao (lao_Laoo) - Spanish (spa_Latn)
#      3    37     -0.006757                 Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#      3    38     -0.006752             Minangkabau (Latin) (min_Latn) - Yue Chinese (yue_Hant)
#      3    39     -0.006748                 Minangkabau (Latin) (min_Latn) - English (eng_Latn)
#      3    40     -0.006719                 Chinese (Simplified) (zho_Hans) - French (fra_Latn)
#      3    41     -0.006669  Banjar (Latin script) (bjn_Latn) - Chinese (Simplified) (zho_Hans)
#      3    42     -0.006596                              French (fra_Latn) - English (eng_Latn)
#      3    43     -0.006554               Banjar (Latin script) (bjn_Latn) - English (eng_Latn)
#      3    44     -0.006549                 Banjar (Latin script) (bjn_Latn) - Khmer (khm_Khmr)
#      3    45     -0.006470                              German (deu_Latn) - English (eng_Latn)
#      3    46     -0.006452                                Khmer (khm_Khmr) - French (fra_Latn)
#      3    47     -0.006436                   Banjar (Latin script) (bjn_Latn) - Lao (lao_Laoo)
#      3    48     -0.006420                          Yue Chinese (yue_Hant) - German (deu_Latn)
#      3    49     -0.006415             Chinese (Simplified) (zho_Hans) - Vietnamese (vie_Latn)
#      3    50     -0.006411           Banjar (Latin script) (bjn_Latn) - Yue Chinese (yue_Hant)
#      4     1     -0.012433            Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      4     2     -0.012032                Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#      4     3     -0.011746                                   Khmer (khm_Khmr) - Lao (lao_Laoo)
#      4     4     -0.011744               Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      4     5     -0.011448                         Yue Chinese (yue_Hant) - English (eng_Latn)
#      4     6     -0.011339                  Chinese (Simplified) (zho_Hans) - Khmer (khm_Khmr)
#      4     7     -0.011303                    Chinese (Simplified) (zho_Hans) - Lao (lao_Laoo)
#      4     8     -0.011193                        Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      4     9     -0.011128                             Yue Chinese (yue_Hant) - Lao (lao_Laoo)
#      4    10     -0.010993                           Yue Chinese (yue_Hant) - Khmer (khm_Khmr)
#      4    11     -0.010957                            Japanese (jpn_Jpan) - English (eng_Latn)
#      4    12     -0.010797                                Japanese (jpn_Jpan) - Lao (lao_Laoo)
#      4    13     -0.010751                              Japanese (jpn_Jpan) - Khmer (khm_Khmr)
#      4    14     -0.010598                               Khmer (khm_Khmr) - English (eng_Latn)
#      4    15     -0.010591                                 Lao (lao_Laoo) - English (eng_Latn)
#      4    16     -0.010569                                    Lao (lao_Laoo) - Thai (tha_Thai)
#      4    17     -0.010518                   Chinese (Simplified) (zho_Hans) - Thai (tha_Thai)
#      4    18     -0.010471                Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      4    19     -0.010325                                  Khmer (khm_Khmr) - Thai (tha_Thai)
#      4    20     -0.010238                             Spanish (spa_Latn) - English (eng_Latn)
#      4    21     -0.010216                 Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      4    22     -0.010137                            Yue Chinese (yue_Hant) - Thai (tha_Thai)
#      4    23     -0.010026    Minangkabau (Latin) (min_Latn) - Chinese (Simplified) (zho_Hans)
#      4    24     -0.010016                         Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      4    25     -0.009959                 Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#      4    26     -0.009824                                Thai (tha_Thai) - English (eng_Latn)
#      4    27     -0.009771                               Japanese (jpn_Jpan) - Thai (tha_Thai)
#      4    28     -0.009710                            Japanese (jpn_Jpan) - Spanish (spa_Latn)
#      4    29     -0.009699                              Korean (kor_Hang) - English (eng_Latn)
#      4    30     -0.009684                              German (deu_Latn) - English (eng_Latn)
#      4    31     -0.009665                               Khmer (khm_Khmr) - Spanish (spa_Latn)
#      4    32     -0.009642                 Minangkabau (Latin) (min_Latn) - English (eng_Latn)
#      4    33     -0.009642                             Korean (kor_Hang) - Japanese (jpn_Jpan)
#      4    34     -0.009636                                 Lao (lao_Laoo) - Spanish (spa_Latn)
#      4    35     -0.009635                   Minangkabau (Latin) (min_Latn) - Khmer (khm_Khmr)
#      4    36     -0.009604                          Yue Chinese (yue_Hant) - Korean (kor_Hang)
#      4    37     -0.009574                                  Korean (kor_Hang) - Lao (lao_Laoo)
#      4    38     -0.009573             Minangkabau (Latin) (min_Latn) - Yue Chinese (yue_Hant)
#      4    39     -0.009516                          Yue Chinese (yue_Hant) - German (deu_Latn)
#      4    40     -0.009509                     Minangkabau (Latin) (min_Latn) - Lao (lao_Laoo)
#      4    41     -0.009477                 Chinese (Simplified) (zho_Hans) - French (fra_Latn)
#      4    42     -0.009468                                Korean (kor_Hang) - Khmer (khm_Khmr)
#      4    43     -0.009387                              French (fra_Latn) - English (eng_Latn)
#      4    44     -0.009335                Chinese (Simplified) (zho_Hans) - Russian (rus_Cyrl)
#      4    45     -0.009324  Banjar (Latin script) (bjn_Latn) - Chinese (Simplified) (zho_Hans)
#      4    46     -0.009255                                  Lao (lao_Laoo) - German (deu_Latn)
#      4    47     -0.009240                                Khmer (khm_Khmr) - German (deu_Latn)
#      4    48     -0.009180                             Japanese (jpn_Jpan) - German (deu_Latn)
#      4    49     -0.009158               Banjar (Latin script) (bjn_Latn) - English (eng_Latn)
#      4    50     -0.009154                Chinese (Simplified) (zho_Hans) - Turkish (tur_Latn)
#      5     1     -0.017422                                   Khmer (khm_Khmr) - Lao (lao_Laoo)
#      5     2     -0.017304            Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      5     3     -0.016677                    Chinese (Simplified) (zho_Hans) - Lao (lao_Laoo)
#      5     4     -0.016487                             Yue Chinese (yue_Hant) - Lao (lao_Laoo)
#      5     5     -0.016475                Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#      5     6     -0.016321                  Chinese (Simplified) (zho_Hans) - Khmer (khm_Khmr)
#      5     7     -0.016316               Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      5     8     -0.016026                                Japanese (jpn_Jpan) - Lao (lao_Laoo)
#      5     9     -0.015946                           Yue Chinese (yue_Hant) - Khmer (khm_Khmr)
#      5    10     -0.015883                         Yue Chinese (yue_Hant) - English (eng_Latn)
#      5    11     -0.015788                        Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      5    12     -0.015664                                 Lao (lao_Laoo) - English (eng_Latn)
#      5    13     -0.015628                                    Lao (lao_Laoo) - Thai (tha_Thai)
#      5    14     -0.015463                              Japanese (jpn_Jpan) - Khmer (khm_Khmr)
#      5    15     -0.015249                            Japanese (jpn_Jpan) - English (eng_Latn)
#      5    16     -0.015199                               Khmer (khm_Khmr) - English (eng_Latn)
#      5    17     -0.014948                   Chinese (Simplified) (zho_Hans) - Thai (tha_Thai)
#      5    18     -0.014921                                  Khmer (khm_Khmr) - Thai (tha_Thai)
#      5    19     -0.014872                Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      5    20     -0.014724                 Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#      5    21     -0.014555                            Yue Chinese (yue_Hant) - Thai (tha_Thai)
#      5    22     -0.014538                 Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      5    23     -0.014525                                 Lao (lao_Laoo) - Spanish (spa_Latn)
#      5    24     -0.014485                                  Korean (kor_Hang) - Lao (lao_Laoo)
#      5    25     -0.014408                     Minangkabau (Latin) (min_Latn) - Lao (lao_Laoo)
#      5    26     -0.014407                             Spanish (spa_Latn) - English (eng_Latn)
#      5    27     -0.014385    Minangkabau (Latin) (min_Latn) - Chinese (Simplified) (zho_Hans)
#      5    28     -0.014318                         Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      5    29     -0.014318                                  Lao (lao_Laoo) - German (deu_Latn)
#      5    30     -0.014231                               Japanese (jpn_Jpan) - Thai (tha_Thai)
#      5    31     -0.014151                               Khmer (khm_Khmr) - Spanish (spa_Latn)
#      5    32     -0.014105                   Minangkabau (Latin) (min_Latn) - Khmer (khm_Khmr)
#      5    33     -0.014100                          Yue Chinese (yue_Hant) - German (deu_Latn)
#      5    34     -0.014073                                  Lao (lao_Laoo) - French (fra_Latn)
#      5    35     -0.014062                              German (deu_Latn) - English (eng_Latn)
#      5    36     -0.014014                                Korean (kor_Hang) - Khmer (khm_Khmr)
#      5    37     -0.014011                                Khmer (khm_Khmr) - German (deu_Latn)
#      5    38     -0.014007                                Thai (tha_Thai) - English (eng_Latn)
#      5    39     -0.013936                 Minangkabau (Latin) (min_Latn) - English (eng_Latn)
#      5    40     -0.013917             Minangkabau (Latin) (min_Latn) - Yue Chinese (yue_Hant)
#      5    41     -0.013903                 Chinese (Simplified) (zho_Hans) - French (fra_Latn)
#      5    42     -0.013896                              Korean (kor_Hang) - English (eng_Latn)
#      5    43     -0.013863                          Yue Chinese (yue_Hant) - Korean (kor_Hang)
#      5    44     -0.013830                            Japanese (jpn_Jpan) - Spanish (spa_Latn)
#      5    45     -0.013828                   Banjar (Latin script) (bjn_Latn) - Lao (lao_Laoo)
#      5    46     -0.013798                             Japanese (jpn_Jpan) - German (deu_Latn)
#      5    47     -0.013790                             Korean (kor_Hang) - Japanese (jpn_Jpan)
#      5    48     -0.013729                  Banjar (Arabic script) (bjn_Arab) - Lao (lao_Laoo)
#      5    49     -0.013641                                Khmer (khm_Khmr) - French (fra_Latn)
#      5    50     -0.013610  Banjar (Latin script) (bjn_Latn) - Chinese (Simplified) (zho_Hans)
#      6     1     -0.019784                                   Khmer (khm_Khmr) - Lao (lao_Laoo)
#      6     2     -0.019283            Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      6     3     -0.018476                    Chinese (Simplified) (zho_Hans) - Lao (lao_Laoo)
#      6     4     -0.018426                             Yue Chinese (yue_Hant) - Lao (lao_Laoo)
#      6     5     -0.018128               Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      6     6     -0.018115                  Chinese (Simplified) (zho_Hans) - Khmer (khm_Khmr)
#      6     7     -0.017956                                Japanese (jpn_Jpan) - Lao (lao_Laoo)
#      6     8     -0.017859                           Yue Chinese (yue_Hant) - Khmer (khm_Khmr)
#      6     9     -0.017799                Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#      6    10     -0.017664                        Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      6    11     -0.017578                                    Lao (lao_Laoo) - Thai (tha_Thai)
#      6    12     -0.017419                         Yue Chinese (yue_Hant) - English (eng_Latn)
#      6    13     -0.017194                              Japanese (jpn_Jpan) - Khmer (khm_Khmr)
#      6    14     -0.017151                                 Lao (lao_Laoo) - English (eng_Latn)
#      6    15     -0.016769                                  Khmer (khm_Khmr) - Thai (tha_Thai)
#      6    16     -0.016734                               Khmer (khm_Khmr) - English (eng_Latn)
#      6    17     -0.016559                            Japanese (jpn_Jpan) - English (eng_Latn)
#      6    18     -0.016554                   Chinese (Simplified) (zho_Hans) - Thai (tha_Thai)
#      6    19     -0.016440                Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      6    20     -0.016415                                  Korean (kor_Hang) - Lao (lao_Laoo)
#      6    21     -0.016357                 Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      6    22     -0.016346                     Minangkabau (Latin) (min_Latn) - Lao (lao_Laoo)
#      6    23     -0.016304                 Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#      6    24     -0.016247                                 Lao (lao_Laoo) - Spanish (spa_Latn)
#      6    25     -0.016200                            Yue Chinese (yue_Hant) - Thai (tha_Thai)
#      6    26     -0.016109                             Korean (kor_Hang) - Japanese (jpn_Jpan)
#      6    27     -0.016060    Minangkabau (Latin) (min_Latn) - Chinese (Simplified) (zho_Hans)
#      6    28     -0.015965                               Japanese (jpn_Jpan) - Thai (tha_Thai)
#      6    29     -0.015963                   Minangkabau (Latin) (min_Latn) - Khmer (khm_Khmr)
#      6    30     -0.015951                         Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      6    31     -0.015923                                  Lao (lao_Laoo) - French (fra_Latn)
#      6    32     -0.015908                               Khmer (khm_Khmr) - Spanish (spa_Latn)
#      6    33     -0.015851                             Spanish (spa_Latn) - English (eng_Latn)
#      6    34     -0.015850                                  Lao (lao_Laoo) - German (deu_Latn)
#      6    35     -0.015800                          Yue Chinese (yue_Hant) - Korean (kor_Hang)
#      6    36     -0.015786                                Korean (kor_Hang) - Khmer (khm_Khmr)
#      6    37     -0.015738             Minangkabau (Latin) (min_Latn) - Yue Chinese (yue_Hant)
#      6    38     -0.015695                 Chinese (Simplified) (zho_Hans) - French (fra_Latn)
#      6    39     -0.015675                          Yue Chinese (yue_Hant) - German (deu_Latn)
#      6    40     -0.015631                   Banjar (Latin script) (bjn_Latn) - Lao (lao_Laoo)
#      6    41     -0.015527                                Khmer (khm_Khmr) - French (fra_Latn)
#      6    42     -0.015472                 Minangkabau (Latin) (min_Latn) - English (eng_Latn)
#      6    43     -0.015469                                Khmer (khm_Khmr) - German (deu_Latn)
#      6    44     -0.015425                            Japanese (jpn_Jpan) - Spanish (spa_Latn)
#      6    45     -0.015364                             Japanese (jpn_Jpan) - German (deu_Latn)
#      6    46     -0.015351                              German (deu_Latn) - English (eng_Latn)
#      6    47     -0.015327                              Korean (kor_Hang) - English (eng_Latn)
#      6    48     -0.015316                              Vietnamese (vie_Latn) - Lao (lao_Laoo)
#      6    49     -0.015306                          Yue Chinese (yue_Hant) - French (fra_Latn)
#      6    50     -0.015271                Minangkabau (Latin) (min_Latn) - Japanese (jpn_Jpan)
#      7     1     -0.020169                                   Khmer (khm_Khmr) - Lao (lao_Laoo)
#      7     2     -0.018525            Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      7     3     -0.018309                    Chinese (Simplified) (zho_Hans) - Lao (lao_Laoo)
#      7     4     -0.018025                             Yue Chinese (yue_Hant) - Lao (lao_Laoo)
#      7     5     -0.017924               Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      7     6     -0.017917                  Chinese (Simplified) (zho_Hans) - Khmer (khm_Khmr)
#      7     7     -0.017905                                Japanese (jpn_Jpan) - Lao (lao_Laoo)
#      7     8     -0.017806                                    Lao (lao_Laoo) - Thai (tha_Thai)
#      7     9     -0.017770                Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#      7    10     -0.017460                           Yue Chinese (yue_Hant) - Khmer (khm_Khmr)
#      7    11     -0.017261                              Japanese (jpn_Jpan) - Khmer (khm_Khmr)
#      7    12     -0.017219                                 Lao (lao_Laoo) - English (eng_Latn)
#      7    13     -0.017135                        Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      7    14     -0.017005                                  Khmer (khm_Khmr) - Thai (tha_Thai)
#      7    15     -0.017004                         Yue Chinese (yue_Hant) - English (eng_Latn)
#      7    16     -0.016804                               Khmer (khm_Khmr) - English (eng_Latn)
#      7    17     -0.016773                                  Korean (kor_Hang) - Lao (lao_Laoo)
#      7    18     -0.016730                     Minangkabau (Latin) (min_Latn) - Lao (lao_Laoo)
#      7    19     -0.016584                             Korean (kor_Hang) - Japanese (jpn_Jpan)
#      7    20     -0.016566                 Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      7    21     -0.016485                                 Lao (lao_Laoo) - Spanish (spa_Latn)
#      7    22     -0.016480                Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      7    23     -0.016442                   Chinese (Simplified) (zho_Hans) - Thai (tha_Thai)
#      7    24     -0.016422                            Japanese (jpn_Jpan) - English (eng_Latn)
#      7    25     -0.016378                 Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#      7    26     -0.016314                   Minangkabau (Latin) (min_Latn) - Khmer (khm_Khmr)
#      7    27     -0.016272                             Spanish (spa_Latn) - English (eng_Latn)
#      7    28     -0.016263                                  Lao (lao_Laoo) - French (fra_Latn)
#      7    29     -0.016248                                Korean (kor_Hang) - Khmer (khm_Khmr)
#      7    30     -0.016146                   Banjar (Latin script) (bjn_Latn) - Lao (lao_Laoo)
#      7    31     -0.016094                               Khmer (khm_Khmr) - Spanish (spa_Latn)
#      7    32     -0.016077                                  Lao (lao_Laoo) - German (deu_Latn)
#      7    33     -0.016073    Minangkabau (Latin) (min_Latn) - Chinese (Simplified) (zho_Hans)
#      7    34     -0.016007                               Japanese (jpn_Jpan) - Thai (tha_Thai)
#      7    35     -0.015969                              Vietnamese (vie_Latn) - Lao (lao_Laoo)
#      7    36     -0.015929                            Yue Chinese (yue_Hant) - Thai (tha_Thai)
#      7    37     -0.015866                              Korean (kor_Hang) - English (eng_Latn)
#      7    38     -0.015861                 Minangkabau (Latin) (min_Latn) - English (eng_Latn)
#      7    39     -0.015847                  Banjar (Arabic script) (bjn_Arab) - Lao (lao_Laoo)
#      7    40     -0.015822                                Khmer (khm_Khmr) - French (fra_Latn)
#      7    41     -0.015801                              German (deu_Latn) - English (eng_Latn)
#      7    42     -0.015762                 Chinese (Simplified) (zho_Hans) - French (fra_Latn)
#      7    43     -0.015750                          Yue Chinese (yue_Hant) - Korean (kor_Hang)
#      7    44     -0.015710                 Banjar (Latin script) (bjn_Latn) - Khmer (khm_Khmr)
#      7    45     -0.015692                              French (fra_Latn) - English (eng_Latn)
#      7    46     -0.015678                         Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      7    47     -0.015669                                Khmer (khm_Khmr) - German (deu_Latn)
#      7    48     -0.015607                                Thai (tha_Thai) - English (eng_Latn)
#      7    49     -0.015603               Banjar (Latin script) (bjn_Latn) - English (eng_Latn)
#      7    50     -0.015601                            Japanese (jpn_Jpan) - Spanish (spa_Latn)
#      8     1     -0.019825                                   Khmer (khm_Khmr) - Lao (lao_Laoo)
#      8     2     -0.017823            Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      8     3     -0.017708                                Japanese (jpn_Jpan) - Lao (lao_Laoo)
#      8     4     -0.017632                                    Lao (lao_Laoo) - Thai (tha_Thai)
#      8     5     -0.017570                    Chinese (Simplified) (zho_Hans) - Lao (lao_Laoo)
#      8     6     -0.017440                             Yue Chinese (yue_Hant) - Lao (lao_Laoo)
#      8     7     -0.017215               Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      8     8     -0.017105                  Chinese (Simplified) (zho_Hans) - Khmer (khm_Khmr)
#      8     9     -0.017063                Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#      8    10     -0.016894                              Japanese (jpn_Jpan) - Khmer (khm_Khmr)
#      8    11     -0.016839                           Yue Chinese (yue_Hant) - Khmer (khm_Khmr)
#      8    12     -0.016825                                 Lao (lao_Laoo) - English (eng_Latn)
#      8    13     -0.016730                        Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      8    14     -0.016627                                  Khmer (khm_Khmr) - Thai (tha_Thai)
#      8    15     -0.016543                                  Korean (kor_Hang) - Lao (lao_Laoo)
#      8    16     -0.016461                         Yue Chinese (yue_Hant) - English (eng_Latn)
#      8    17     -0.016403                             Korean (kor_Hang) - Japanese (jpn_Jpan)
#      8    18     -0.016255                               Khmer (khm_Khmr) - English (eng_Latn)
#      8    19     -0.016056                     Minangkabau (Latin) (min_Latn) - Lao (lao_Laoo)
#      8    20     -0.016031                                 Lao (lao_Laoo) - Spanish (spa_Latn)
#      8    21     -0.015994                            Japanese (jpn_Jpan) - English (eng_Latn)
#      8    22     -0.015976                             Spanish (spa_Latn) - English (eng_Latn)
#      8    23     -0.015867                   Chinese (Simplified) (zho_Hans) - Thai (tha_Thai)
#      8    24     -0.015863                  Banjar (Arabic script) (bjn_Arab) - Lao (lao_Laoo)
#      8    25     -0.015856                               Japanese (jpn_Jpan) - Thai (tha_Thai)
#      8    26     -0.015841                Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      8    27     -0.015831                                Korean (kor_Hang) - Khmer (khm_Khmr)
#      8    28     -0.015762                 Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      8    29     -0.015725                                 Kannada (kan_Knda) - Lao (lao_Laoo)
#      8    30     -0.015688                                  Lao (lao_Laoo) - French (fra_Latn)
#      8    31     -0.015619                   Banjar (Latin script) (bjn_Latn) - Lao (lao_Laoo)
#      8    32     -0.015617                 Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#      8    33     -0.015615                   Minangkabau (Latin) (min_Latn) - Khmer (khm_Khmr)
#      8    34     -0.015608                                  Lao (lao_Laoo) - German (deu_Latn)
#      8    35     -0.015563                               Khmer (khm_Khmr) - Spanish (spa_Latn)
#      8    36     -0.015528                              Vietnamese (vie_Latn) - Lao (lao_Laoo)
#      8    37     -0.015456                            Yue Chinese (yue_Hant) - Thai (tha_Thai)
#      8    38     -0.015445                                 Turkish (tur_Latn) - Lao (lao_Laoo)
#      8    39     -0.015372                              Korean (kor_Hang) - English (eng_Latn)
#      8    40     -0.015322                            Turkish (tur_Latn) - Japanese (jpn_Jpan)
#      8    41     -0.015294                                Thai (tha_Thai) - English (eng_Latn)
#      8    42     -0.015277                              French (fra_Latn) - English (eng_Latn)
#      8    43     -0.015274                          Yue Chinese (yue_Hant) - Korean (kor_Hang)
#      8    44     -0.015271                 Minangkabau (Latin) (min_Latn) - English (eng_Latn)
#      8    45     -0.015255                              German (deu_Latn) - English (eng_Latn)
#      8    46     -0.015242                             Japanese (jpn_Jpan) - German (deu_Latn)
#      8    47     -0.015238                            Japanese (jpn_Jpan) - Spanish (spa_Latn)
#      8    48     -0.015223                Banjar (Arabic script) (bjn_Arab) - Khmer (khm_Khmr)
#      8    49     -0.015207                Chinese (Simplified) (zho_Hans) - Russian (rus_Cyrl)
#      8    50     -0.015189                         Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      9     1     -0.022326                                   Khmer (khm_Khmr) - Lao (lao_Laoo)
#      9     2     -0.019812            Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      9     3     -0.019583                    Chinese (Simplified) (zho_Hans) - Lao (lao_Laoo)
# ...
#   47. -0.428504 - Minangkabau (Latin) (min_Latn) & Standard Malay (zsm_Latn)
#   48. -0.427169 - Banjar (Latin script) (bjn_Latn) & Waray (war_Latn)
#   49. -0.425763 - Hindi (hin_Deva) & Russian (rus_Cyrl)
#   50. -0.421778 - Chinese (Simplified) (zho_Hans) & Japanese (jpn_Jpan)
#
# Layer 29:
#   1. -0.845518 - Waray (war_Latn) & Cebuano (ceb_Latn)
#   2. -0.771728 - Javanese (jav_Latn) & Banjar (Latin script) (bjn_Latn)
#   3. -0.765547 - Khmer (khm_Khmr) & Lao (lao_Laoo)
#   4. -0.747797 - Telugu (tel_Telu) & Kannada (kan_Knda)
#   5. -0.741568 - Zulu (zul_Latn) & Xhosa (xho_Latn)
#   6. -0.738665 - Sundanese (sun_Latn) & Banjar (Latin script) (bjn_Latn)
#   7. -0.736181 - Banjar (Arabic script) (bjn_Arab) & Minangkabau (Arabic) (min_Arab)
#   8. -0.716547 - Sundanese (sun_Latn) & Javanese (jav_Latn)
#   9. -0.679272 - Lao (lao_Laoo) & Thai (tha_Thai)
#   10. -0.659735 - Waray (war_Latn) & Ilocano (ilo_Latn)
#   11. -0.630136 - Standard Malay (zsm_Latn) & Indonesian (ind_Latn)
#   12. -0.612239 - Hindi (hin_Deva) & Urdu (urd_Arab)
#   13. -0.597771 - Khmer (khm_Khmr) & Thai (tha_Thai)
#   14. -0.589261 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   15. -0.580186 - Kannada (kan_Knda) & Urdu (urd_Arab)
#   16. -0.578867 - Telugu (tel_Telu) & Hindi (hin_Deva)
#   17. -0.575771 - North Azerbaijani (azj_Latn) & South Azerbaijani (azb_Arab)
#   18. -0.572324 - Kannada (kan_Knda) & Hindi (hin_Deva)
#   19. -0.571467 - Hebrew (heb_Hebr) & MSA (Arabic) (arb_Arab)
#   20. -0.570678 - French (fra_Latn) & Spanish (spa_Latn)
#   21. -0.570354 - Telugu (tel_Telu) & Urdu (urd_Arab)
#   22. -0.552559 - Banjar (Latin script) (bjn_Latn) & Minangkabau (Latin) (min_Latn)
#   23. -0.549392 - Sundanese (sun_Latn) & Minangkabau (Latin) (min_Latn)
#   24. -0.537402 - Korean (kor_Hang) & Japanese (jpn_Jpan)
#   25. -0.536047 - Vietnamese (vie_Latn) & Lao (lao_Laoo)
#   26. -0.535369 - Vietnamese (vie_Latn) & Thai (tha_Thai)
#   27. -0.530929 - Cebuano (ceb_Latn) & Tagalog (tgl_Latn)
#   28. -0.513656 - Javanese (jav_Latn) & Minangkabau (Latin) (min_Latn)
#   29. -0.504615 - Waray (war_Latn) & Tagalog (tgl_Latn)
#   30. -0.495356 - Minangkabau (Arabic) (min_Arab) & Minangkabau (Latin) (min_Latn)
#   31. -0.493654 - Ilocano (ilo_Latn) & Cebuano (ceb_Latn)
#   32. -0.491031 - Vietnamese (vie_Latn) & Khmer (khm_Khmr)
#   33. -0.479953 - Korean (kor_Hang) & Hindi (hin_Deva)
#   34. -0.469396 - Chinese (Simplified) (zho_Hans) & Thai (tha_Thai)
#   35. -0.467858 - Lao (lao_Laoo) & Hebrew (heb_Hebr)
#   36. -0.467080 - Telugu (tel_Telu) & Hebrew (heb_Hebr)
#   37. -0.466736 - Minangkabau (Latin) (min_Latn) & Standard Malay (zsm_Latn)
#   38. -0.464731 - Korean (kor_Hang) & Telugu (tel_Telu)
#   39. -0.462997 - Banjar (Latin script) (bjn_Latn) & Ilocano (ilo_Latn)
#   40. -0.462849 - Thai (tha_Thai) & Hebrew (heb_Hebr)
#   41. -0.462145 - Chinese (Simplified) (zho_Hans) & Khmer (khm_Khmr)
#   42. -0.460588 - Indonesian (ind_Latn) & Thai (tha_Thai)
#   43. -0.456059 - Khmer (khm_Khmr) & Hebrew (heb_Hebr)
#   44. -0.455931 - Banjar (Latin script) (bjn_Latn) & Waray (war_Latn)
#   45. -0.453534 - Chinese (Simplified) (zho_Hans) & Korean (kor_Hang)
#   46. -0.446944 - Hindi (hin_Deva) & Russian (rus_Cyrl)
#   47. -0.439585 - Minangkabau (Latin) (min_Latn) & Indonesian (ind_Latn)
#   48. -0.434115 - Russian (rus_Cyrl) & German (deu_Latn)
#   49. -0.431691 - Chinese (Simplified) (zho_Hans) & Vietnamese (vie_Latn)
#   50. -0.430845 - French (fra_Latn) & German (deu_Latn)
#
# Layer 30:
#   1. -0.947954 - Waray (war_Latn) & Cebuano (ceb_Latn)
#   2. -0.907444 - Zulu (zul_Latn) & Xhosa (xho_Latn)
#   3. -0.904446 - Javanese (jav_Latn) & Banjar (Latin script) (bjn_Latn)
#   4. -0.838379 - Sundanese (sun_Latn) & Banjar (Latin script) (bjn_Latn)
#   5. -0.819182 - Khmer (khm_Khmr) & Lao (lao_Laoo)
#   6. -0.819003 - Sundanese (sun_Latn) & Javanese (jav_Latn)
#   7. -0.792432 - Banjar (Arabic script) (bjn_Arab) & Minangkabau (Arabic) (min_Arab)
#   8. -0.766631 - Telugu (tel_Telu) & Kannada (kan_Knda)
#   9. -0.749232 - Waray (war_Latn) & Ilocano (ilo_Latn)
#   10. -0.715117 - Lao (lao_Laoo) & Thai (tha_Thai)
#   11. -0.675146 - Standard Malay (zsm_Latn) & Indonesian (ind_Latn)
#   12. -0.655006 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   13. -0.633086 - Hindi (hin_Deva) & Urdu (urd_Arab)
#   14. -0.629909 - Banjar (Latin script) (bjn_Latn) & Minangkabau (Latin) (min_Latn)
#   15. -0.627780 - Khmer (khm_Khmr) & Thai (tha_Thai)
#   16. -0.619694 - Telugu (tel_Telu) & Hindi (hin_Deva)
#   17. -0.618612 - North Azerbaijani (azj_Latn) & South Azerbaijani (azb_Arab)
#   18. -0.610326 - Kannada (kan_Knda) & Hindi (hin_Deva)
#   19. -0.610291 - Hebrew (heb_Hebr) & MSA (Arabic) (arb_Arab)
#   20. -0.600454 - Sundanese (sun_Latn) & Minangkabau (Latin) (min_Latn)
#   21. -0.596510 - Cebuano (ceb_Latn) & Tagalog (tgl_Latn)
#   22. -0.589866 - Telugu (tel_Telu) & Urdu (urd_Arab)
#   23. -0.584213 - French (fra_Latn) & Spanish (spa_Latn)
#   24. -0.582077 - Kannada (kan_Knda) & Urdu (urd_Arab)
#   25. -0.571438 - Javanese (jav_Latn) & Minangkabau (Latin) (min_Latn)
#   26. -0.570983 - Korean (kor_Hang) & Japanese (jpn_Jpan)
#   27. -0.560434 - Ilocano (ilo_Latn) & Cebuano (ceb_Latn)
#   28. -0.556294 - Waray (war_Latn) & Tagalog (tgl_Latn)
#   29. -0.550377 - Minangkabau (Arabic) (min_Arab) & Minangkabau (Latin) (min_Latn)
#   30. -0.549009 - Vietnamese (vie_Latn) & Lao (lao_Laoo)
#   31. -0.545967 - Vietnamese (vie_Latn) & Thai (tha_Thai)
#   32. -0.520571 - Korean (kor_Hang) & Hindi (hin_Deva)
#   33. -0.518865 - Minangkabau (Latin) (min_Latn) & Standard Malay (zsm_Latn)
#   34. -0.516639 - Chinese (Simplified) (zho_Hans) & Thai (tha_Thai)
#   35. -0.511168 - Banjar (Latin script) (bjn_Latn) & Ilocano (ilo_Latn)
#   36. -0.510791 - Vietnamese (vie_Latn) & Khmer (khm_Khmr)
#   37. -0.510237 - Telugu (tel_Telu) & Hebrew (heb_Hebr)
#   38. -0.508102 - Chinese (Simplified) (zho_Hans) & Korean (kor_Hang)
#   39. -0.505311 - Hindi (hin_Deva) & Russian (rus_Cyrl)
#   40. -0.502824 - Chinese (Simplified) (zho_Hans) & Khmer (khm_Khmr)
#   41. -0.502313 - Lao (lao_Laoo) & Hebrew (heb_Hebr)
#   42. -0.501001 - Korean (kor_Hang) & Telugu (tel_Telu)
#   43. -0.491666 - Minangkabau (Latin) (min_Latn) & Indonesian (ind_Latn)
#   44. -0.490474 - Indonesian (ind_Latn) & Thai (tha_Thai)
#   45. -0.485542 - Thai (tha_Thai) & Hebrew (heb_Hebr)
#   46. -0.476133 - Yue Chinese (yue_Hant) & Japanese (jpn_Jpan)
#   47. -0.475267 - Banjar (Latin script) (bjn_Latn) & Waray (war_Latn)
#   48. -0.474665 - Khmer (khm_Khmr) & Hebrew (heb_Hebr)
#   49. -0.469020 - Russian (rus_Cyrl) & German (deu_Latn)
#   50. -0.467022 - Chinese (Simplified) (zho_Hans) & Hindi (hin_Deva)
#
# Layer 31:
#   1. -1.224620 - Banjar (Arabic script) (bjn_Arab) & Minangkabau (Arabic) (min_Arab)
#   2. -1.196202 - Zulu (zul_Latn) & Xhosa (xho_Latn)
#   3. -1.120039 - Khmer (khm_Khmr) & Lao (lao_Laoo)
#   4. -1.082352 - Telugu (tel_Telu) & Kannada (kan_Knda)
#   5. -1.073461 - Javanese (jav_Latn) & Banjar (Latin script) (bjn_Latn)
#   6. -1.046032 - Waray (war_Latn) & Cebuano (ceb_Latn)
#   7. -0.995428 - Sundanese (sun_Latn) & Banjar (Latin script) (bjn_Latn)
#   8. -0.988656 - Sundanese (sun_Latn) & Javanese (jav_Latn)
#   9. -0.927521 - Lao (lao_Laoo) & Thai (tha_Thai)
#   10. -0.902553 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   11. -0.872737 - Waray (war_Latn) & Ilocano (ilo_Latn)
#   12. -0.872462 - Standard Malay (zsm_Latn) & Indonesian (ind_Latn)
#   13. -0.852224 - Hebrew (heb_Hebr) & MSA (Arabic) (arb_Arab)
#   14. -0.844477 - Telugu (tel_Telu) & Hindi (hin_Deva)
#   15. -0.828663 - Khmer (khm_Khmr) & Thai (tha_Thai)
#   16. -0.825413 - Kannada (kan_Knda) & Hindi (hin_Deva)
#   17. -0.821684 - Hindi (hin_Deva) & Urdu (urd_Arab)
#   18. -0.816361 - Telugu (tel_Telu) & Urdu (urd_Arab)
#   19. -0.763267 - Sundanese (sun_Latn) & Minangkabau (Latin) (min_Latn)
#   20. -0.756368 - Banjar (Latin script) (bjn_Latn) & Minangkabau (Latin) (min_Latn)
#   21. -0.753597 - Korean (kor_Hang) & Japanese (jpn_Jpan)
#   22. -0.749925 - Kannada (kan_Knda) & Urdu (urd_Arab)
#   23. -0.738684 - French (fra_Latn) & Spanish (spa_Latn)
#   24. -0.736892 - North Azerbaijani (azj_Latn) & South Azerbaijani (azb_Arab)
#   25. -0.729841 - Korean (kor_Hang) & Hindi (hin_Deva)
#   26. -0.729601 - Telugu (tel_Telu) & Hebrew (heb_Hebr)
#   27. -0.700631 - Cebuano (ceb_Latn) & Tagalog (tgl_Latn)
#   28. -0.699167 - Chinese (Simplified) (zho_Hans) & Thai (tha_Thai)
#   29. -0.698782 - Javanese (jav_Latn) & Minangkabau (Latin) (min_Latn)
#   30. -0.697130 - Vietnamese (vie_Latn) & Lao (lao_Laoo)
#   31. -0.694488 - Korean (kor_Hang) & Telugu (tel_Telu)
#   32. -0.690868 - Vietnamese (vie_Latn) & Thai (tha_Thai)
#   33. -0.680870 - Lao (lao_Laoo) & Hebrew (heb_Hebr)
#   34. -0.679834 - Minangkabau (Arabic) (min_Arab) & Minangkabau (Latin) (min_Latn)
#   35. -0.679056 - Chinese (Simplified) (zho_Hans) & Korean (kor_Hang)
#   36. -0.663710 - Thai (tha_Thai) & Hebrew (heb_Hebr)
#   37. -0.660215 - Waray (war_Latn) & Tagalog (tgl_Latn)
#   38. -0.655021 - Korean (kor_Hang) & Kannada (kan_Knda)
#   39. -0.654042 - Minangkabau (Latin) (min_Latn) & Standard Malay (zsm_Latn)
#   40. -0.649187 - Chinese (Simplified) (zho_Hans) & Khmer (khm_Khmr)
#   41. -0.648559 - Chinese (Simplified) (zho_Hans) & Hindi (hin_Deva)
#   42. -0.642793 - Minangkabau (Latin) (min_Latn) & Indonesian (ind_Latn)
#   43. -0.642555 - Ilocano (ilo_Latn) & Cebuano (ceb_Latn)
#   44. -0.641907 - Khmer (khm_Khmr) & Hebrew (heb_Hebr)
#   45. -0.637497 - Kannada (kan_Knda) & Khmer (khm_Khmr)
#   46. -0.637040 - Korean (kor_Hang) & Khmer (khm_Khmr)
#   47. -0.633825 - Vietnamese (vie_Latn) & Khmer (khm_Khmr)
#   48. -0.632114 - Telugu (tel_Telu) & Khmer (khm_Khmr)
#   49. -0.628321 - Banjar (Arabic script) (bjn_Arab) & Khmer (khm_Khmr)
#   50. -0.626630 - Korean (kor_Hang) & Russian (rus_Cyrl)
#
# Layer 32:
#   1. -1.594678 - Banjar (Arabic script) (bjn_Arab) & Minangkabau (Arabic) (min_Arab)
#   2. -1.451407 - Zulu (zul_Latn) & Xhosa (xho_Latn)
#   3. -1.443624 - Khmer (khm_Khmr) & Lao (lao_Laoo)
#   4. -1.330734 - Javanese (jav_Latn) & Banjar (Latin script) (bjn_Latn)
#   5. -1.318949 - Telugu (tel_Telu) & Kannada (kan_Knda)
#   6. -1.311226 - Waray (war_Latn) & Cebuano (ceb_Latn)
#   7. -1.247975 - Sundanese (sun_Latn) & Banjar (Latin script) (bjn_Latn)
#   8. -1.242121 - Sundanese (sun_Latn) & Javanese (jav_Latn)
#   9. -1.128543 - Standard Malay (zsm_Latn) & Indonesian (ind_Latn)
#   10. -1.121951 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   11. -1.092621 - Lao (lao_Laoo) & Thai (tha_Thai)
#   12. -1.062357 - Waray (war_Latn) & Ilocano (ilo_Latn)
#   13. -1.059946 - Telugu (tel_Telu) & Hindi (hin_Deva)
#   14. -1.034471 - Kannada (kan_Knda) & Hindi (hin_Deva)
#   15. -1.009098 - Banjar (Latin script) (bjn_Latn) & Minangkabau (Latin) (min_Latn)
#   16. -0.995537 - Hebrew (heb_Hebr) & MSA (Arabic) (arb_Arab)
#   17. -0.985646 - Sundanese (sun_Latn) & Minangkabau (Latin) (min_Latn)
#   18. -0.974682 - Hindi (hin_Deva) & Urdu (urd_Arab)
#   19. -0.971610 - Telugu (tel_Telu) & Urdu (urd_Arab)
#   20. -0.940425 - Khmer (khm_Khmr) & Thai (tha_Thai)
#   21. -0.927740 - Javanese (jav_Latn) & Minangkabau (Latin) (min_Latn)
#   22. -0.921597 - Kannada (kan_Knda) & Khmer (khm_Khmr)
#   23. -0.908748 - Kannada (kan_Knda) & Lao (lao_Laoo)
#   24. -0.907255 - Korean (kor_Hang) & Japanese (jpn_Jpan)
#   25. -0.903057 - Kannada (kan_Knda) & Urdu (urd_Arab)
#   26. -0.896316 - Minangkabau (Arabic) (min_Arab) & Minangkabau (Latin) (min_Latn)
#   27. -0.895463 - Korean (kor_Hang) & Hindi (hin_Deva)
#   28. -0.862055 - Telugu (tel_Telu) & Hebrew (heb_Hebr)
#   29. -0.849332 - Minangkabau (Latin) (min_Latn) & Standard Malay (zsm_Latn)
#   30. -0.849173 - Minangkabau (Latin) (min_Latn) & Indonesian (ind_Latn)
#   31. -0.842733 - North Azerbaijani (azj_Latn) & South Azerbaijani (azb_Arab)
#   32. -0.838212 - French (fra_Latn) & Spanish (spa_Latn)
#   33. -0.837486 - Korean (kor_Hang) & Kannada (kan_Knda)
#   34. -0.835555 - Telugu (tel_Telu) & Khmer (khm_Khmr)
#   35. -0.829625 - Lao (lao_Laoo) & Hebrew (heb_Hebr)
#   36. -0.826983 - Vietnamese (vie_Latn) & Lao (lao_Laoo)
#   37. -0.825409 - Hindi (hin_Deva) & Lao (lao_Laoo)
#   38. -0.824337 - Cebuano (ceb_Latn) & Tagalog (tgl_Latn)
#   39. -0.823786 - Chinese (Simplified) (zho_Hans) & Thai (tha_Thai)
#   40. -0.821575 - Korean (kor_Hang) & Telugu (tel_Telu)
#   41. -0.815903 - Telugu (tel_Telu) & Lao (lao_Laoo)
#   42. -0.812376 - Vietnamese (vie_Latn) & Thai (tha_Thai)
#   43. -0.812194 - Banjar (Arabic script) (bjn_Arab) & Khmer (khm_Khmr)
#   44. -0.810599 - Chinese (Simplified) (zho_Hans) & Korean (kor_Hang)
#   45. -0.807371 - North Azerbaijani (azj_Latn) & Turkish (tur_Latn)
#   46. -0.802627 - Korean (kor_Hang) & Khmer (khm_Khmr)
#   47. -0.801310 - Minangkabau (Arabic) (min_Arab) & Standard Malay (zsm_Latn)
#   48. -0.797443 - Korean (kor_Hang) & Lao (lao_Laoo)
#   49. -0.795471 - Banjar (Arabic script) (bjn_Arab) & Hindi (hin_Deva)
#   50. -0.794500 - Chinese (Simplified) (zho_Hans) & Hindi (hin_Deva)
#
# Layer 33:
#   1. -2.711907 - Banjar (Arabic script) (bjn_Arab) & Minangkabau (Arabic) (min_Arab)
#   2. -2.160610 - Zulu (zul_Latn) & Xhosa (xho_Latn)
#   3. -2.026888 - Javanese (jav_Latn) & Banjar (Latin script) (bjn_Latn)
#   4. -1.968981 - Sundanese (sun_Latn) & Banjar (Latin script) (bjn_Latn)
#   5. -1.865251 - Sundanese (sun_Latn) & Javanese (jav_Latn)
#   6. -1.846632 - Khmer (khm_Khmr) & Lao (lao_Laoo)
#   7. -1.774512 - Waray (war_Latn) & Cebuano (ceb_Latn)
#   8. -1.709414 - Telugu (tel_Telu) & Kannada (kan_Knda)
#   9. -1.662931 - Banjar (Latin script) (bjn_Latn) & Minangkabau (Latin) (min_Latn)
#   10. -1.633621 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   11. -1.601215 - Standard Malay (zsm_Latn) & Indonesian (ind_Latn)
#   12. -1.574996 - Waray (war_Latn) & Ilocano (ilo_Latn)
#   13. -1.524893 - Sundanese (sun_Latn) & Minangkabau (Latin) (min_Latn)
#   14. -1.481346 - Telugu (tel_Telu) & Hindi (hin_Deva)
#   15. -1.430402 - Javanese (jav_Latn) & Minangkabau (Latin) (min_Latn)
#   16. -1.420652 - Lao (lao_Laoo) & Thai (tha_Thai)
#   17. -1.419864 - Hebrew (heb_Hebr) & MSA (Arabic) (arb_Arab)
#   18. -1.397877 - Minangkabau (Arabic) (min_Arab) & Minangkabau (Latin) (min_Latn)
#   19. -1.373183 - Kannada (kan_Knda) & Hindi (hin_Deva)
#   20. -1.367106 - Hindi (hin_Deva) & Urdu (urd_Arab)
#   21. -1.330238 - Korean (kor_Hang) & Japanese (jpn_Jpan)
#   22. -1.327077 - Minangkabau (Latin) (min_Latn) & Standard Malay (zsm_Latn)
#   23. -1.322365 - Telugu (tel_Telu) & Urdu (urd_Arab)
#   24. -1.320562 - Minangkabau (Latin) (min_Latn) & Indonesian (ind_Latn)
#   25. -1.260857 - Banjar (Latin script) (bjn_Latn) & Ilocano (ilo_Latn)
#   26. -1.254647 - Banjar (Arabic script) (bjn_Arab) & Hindi (hin_Deva)
#   27. -1.253417 - Khmer (khm_Khmr) & Thai (tha_Thai)
#   28. -1.240045 - Cebuano (ceb_Latn) & Tagalog (tgl_Latn)
#   29. -1.234010 - Banjar (Latin script) (bjn_Latn) & Minangkabau (Arabic) (min_Arab)
#   30. -1.232832 - French (fra_Latn) & Spanish (spa_Latn)
#   31. -1.221912 - Kannada (kan_Knda) & Lao (lao_Laoo)
#   32. -1.211896 - Kannada (kan_Knda) & Khmer (khm_Khmr)
#   33. -1.211407 - Korean (kor_Hang) & Hindi (hin_Deva)
#   34. -1.199622 - Banjar (Arabic script) (bjn_Arab) & Lao (lao_Laoo)
#   35. -1.199461 - North Azerbaijani (azj_Latn) & Turkish (tur_Latn)
#   36. -1.197540 - Banjar (Arabic script) (bjn_Arab) & Khmer (khm_Khmr)
#   37. -1.195115 - Chinese (Simplified) (zho_Hans) & Korean (kor_Hang)
#   38. -1.192751 - Hindi (hin_Deva) & Thai (tha_Thai)
#   39. -1.191874 - Yue Chinese (yue_Hant) & Japanese (jpn_Jpan)
#   40. -1.181634 - Ilocano (ilo_Latn) & Cebuano (ceb_Latn)
#   41. -1.178093 - Waray (war_Latn) & Tagalog (tgl_Latn)
#   42. -1.165652 - Korean (kor_Hang) & Telugu (tel_Telu)
#   43. -1.163810 - Chinese (Simplified) (zho_Hans) & Thai (tha_Thai)
#   44. -1.153994 - Minangkabau (Arabic) (min_Arab) & Standard Malay (zsm_Latn)
#   45. -1.141058 - Thai (tha_Thai) & Hebrew (heb_Hebr)
#   46. -1.136566 - Kannada (kan_Knda) & Urdu (urd_Arab)
#   47. -1.136386 - Banjar (Arabic script) (bjn_Arab) & Urdu (urd_Arab)
#   48. -1.130810 - Vietnamese (vie_Latn) & Thai (tha_Thai)
#   49. -1.129659 - North Azerbaijani (azj_Latn) & South Azerbaijani (azb_Arab)
#   50. -1.121713 - Minangkabau (Arabic) (min_Arab) & Lao (lao_Laoo)

# %%
# Calculate mean and std deviation of the distances for each layer
layer_means = distance_matrix.mean(dim=(1, 2)).cpu().numpy()
layer_stds = distance_matrix.std(dim=(1, 2)).cpu().numpy()

# Create a DataFrame to display the statistics
layer_stats_df = pd.DataFrame({
	'Layer': range(-1, num_layers),
	'Mean_Distance': layer_means,
	'Std_Distance': layer_stds
})

print("Layer-wise Distance Statistics:")
print(layer_stats_df.to_string(index=False))
# Out:
# Layer-wise Distance Statistics:
#  Layer  Mean_Distance  Std_Distance
#     -1       0.004848      0.000009
#      0      -0.001897      0.000811
#      1      -0.001551      0.000763
#      2      -0.002786      0.000956
#      3      -0.004589      0.001200
#      4      -0.007101      0.001398
#      5      -0.010764      0.001848
#      6      -0.012117      0.002040
#      7      -0.012580      0.001946
#      8      -0.012378      0.001839
#      9      -0.014045      0.002014
#     10      -0.015260      0.002237
#     11      -0.018091      0.002643
#     12      -0.019475      0.002980
#     13      -0.014394      0.002607
#     14      -0.014553      0.002671
#     15      -0.018922      0.003521
#     16      -0.031248      0.005760
#     17      -0.042230      0.008584
#     18      -0.050815      0.010630
#     19      -0.065009      0.014673
#     20      -0.087202      0.020626
#     21      -0.110351      0.026261
#     22      -0.128983      0.034340
#     23      -0.146534      0.040065
#     24      -0.169686      0.054918
#     25      -0.227966      0.077292
#     26      -0.245003      0.100195
#     27      -0.268858      0.124725
#     28      -0.272132      0.149007
#     29      -0.265659      0.172143
#     30      -0.282975      0.194497
#     31      -0.361891      0.258232
#     32      -0.458546      0.311963
#     33      -0.711473      0.426306

# %% [markdown]
# ## Plotting and Cluster Formation

# %% [markdown]
# ### Heatmap

# %%
lengths_per_family = {}
for family, langs in EXP2_CONFIG['languages'].items():
    lengths_per_family[family] = len(langs)

# %%
# Heatmap per layer of the silhouette scores between languages, make a subplot for each layer with 4 columns
import seaborn as sns
import matplotlib.pyplot as plt

# Find global min and max across all layers for consistent scale
global_min = float('inf')
global_max = float('-inf')
for layer_id in range(-1, num_layers):
	layer_distances = similarity_matrix[layer_id + 1]
	global_min = min(global_min, layer_distances.min().item())
	global_max = max(global_max, layer_distances.max().item())

fig, axes = plt.subplots(nrows=(num_layers + 1) // 4 + 1, ncols=4, figsize=(20, 5 * ((num_layers + 1) // 4 + 1)))
axes = axes.flatten()
for layer_id in tqdm(range(0, num_layers)):
	layer_distances = similarity_matrix[layer_id + 1]
	sns.heatmap(layer_distances.cpu().numpy(), 
		xticklabels=[LANGCODE2LANGNAME[lang] for lang in languages], 
		yticklabels=[LANGCODE2LANGNAME[lang] for lang in languages], 
		ax=axes[layer_id], 
		cmap='viridis',
		vmin=global_min,
		vmax=global_max,
		# annot=True,
		# fmt='.2f',
	)
	axes[layer_id].set_title(f'Layer {layer_id} Cosine Similarity')
	plt.setp(axes[layer_id].get_xticklabels(), rotation=90, ha='right', rotation_mode='anchor')

	# Setup fontsize of the x and y label
	axes[layer_id].tick_params(axis='x', labelsize=5)
	axes[layer_id].tick_params(axis='y', labelsize=5)
	
	# Add bolded grid lines to separate language families
	# Calculate cumulative positions for family boundaries
	cumulative_langs = 0
	for family, num_langs in lengths_per_family.items():
		cumulative_langs += num_langs
		# Draw horizontal and vertical lines at family boundaries
		axes[layer_id].axhline(cumulative_langs, color='black', linewidth=1.5)
		axes[layer_id].axvline(cumulative_langs, color='black', linewidth=1.5)

	# if layer_id + 1 == 3:
	# 	break
	
plt.tight_layout()
image_path = f'plot/cosine_heatmap_{model_name}.png'
os.makedirs('plot', exist_ok=True)
plt.savefig(image_path, dpi=300, bbox_inches='tight')
plt.close()
# Out:
# 100%|██████████| 34/34 [01:20<00:00,  2.36s/it]

# %%
import seaborn as sns

# Make 5 bins of the silhouette scores and color the heatmap accordingly
import matplotlib.pyplot as plt

# Find global min and max across all layers for consistent scale
global_min = float('inf')
global_max = float('-inf')
for layer_id in range(-1, num_layers):
	layer_distances = similarity_matrix[layer_id + 1]
	# Exclude diagonal elements (which are 0)
	mask_no_diag = ~torch.eye(len(languages), dtype=torch.bool, device='cuda')
	non_diag_values = layer_distances[mask_no_diag]
	global_min = min(global_min, non_diag_values.min().item())
	global_max = max(global_max, non_diag_values.max().item())

# Create 3 bins
n_bins = 5
bin_edges = np.linspace(global_min, global_max, n_bins + 1)

# Create subplots
fig, axes = plt.subplots(nrows=(num_layers + 1) // 4 + 1, ncols=4, figsize=(20, 5 * ((num_layers + 1) // 4 + 1)))
axes = axes.flatten()

for layer_id in tqdm(range(0, num_layers)):
	layer_distances = similarity_matrix[layer_id + 1].cpu().numpy()
	
	# Discretize the distances into bins
	binned_distances = np.digitize(layer_distances, bin_edges) - 1
	binned_distances = np.clip(binned_distances, 0, n_bins - 1)
	
	sns.heatmap(binned_distances, 
		xticklabels=[LANGCODE2LANGNAME[lang] for lang in languages], 
		yticklabels=[LANGCODE2LANGNAME[lang] for lang in languages], 
		ax=axes[layer_id], 
		cmap='viridis',
		vmin=0,
		vmax=n_bins - 1,
		cbar_kws={'label': 'Bin', 'ticks': range(n_bins)}
	)
	axes[layer_id].set_title(f'Layer {layer_id} Binned Cosine Similarity')
	plt.setp(axes[layer_id].get_xticklabels(), rotation=90, ha='right', rotation_mode='anchor')

	# Setup fontsize of the x and y label
	axes[layer_id].tick_params(axis='x', labelsize=5)
	axes[layer_id].tick_params(axis='y', labelsize=5)
	
	# Add bolded grid lines to separate language families
	cumulative_langs = 0
	for family, num_langs in lengths_per_family.items():
		cumulative_langs += num_langs
		axes[layer_id].axhline(cumulative_langs, color='black', linewidth=1.5)
		axes[layer_id].axvline(cumulative_langs, color='black', linewidth=1.5)
	
plt.tight_layout()
image_path = f'plot/cosine_binned{n_bins}_heatmap_{model_name}.png'
os.makedirs('plot', exist_ok=True)
plt.savefig(image_path, dpi=300, bbox_inches='tight')
plt.close()

print(f"Bin edges: {bin_edges}")
# Out:
# 100%|██████████| 34/34 [01:19<00:00,  2.33s/it]
# Bin edges: [3.59604892e-05 5.43390575e-01 1.08674519e+00 1.63009980e+00
#  2.17345442e+00 2.71680903e+00]

# %% [markdown]
# ### Clustering

# %%
percentiles = np.percentile(range(-1, num_layers), [0, 2, 25, 50, 75, 100])
# Round to nearest integer
percentiles = [int(round(p)) for p in percentiles]
print(f"\nPercentile layers: {percentiles}")
# Out:
# Percentile layers: [-1, 0, 8, 16, 24, 33]

# %%
# Plot with heatmap - reversed colormap for high similarity highlighting
import matplotlib.pyplot as plt
import seaborn as sns

# # Calculate global min and max for consistent scale across all layers
# global_min = distance_matrix.min().cpu().numpy()
# global_max = distance_matrix.max().cpu().numpy()

percentiles = np.percentile(range(-1, num_layers), [2, 25, 50, 75, 100])
# Round to nearest integer
percentiles = [int(round(p)) for p in percentiles]

for layer_id in range(-1, num_layers):
	if layer_id not in percentiles:
		continue
	plt.figure(figsize=(10, 8))
	sns.heatmap(distance_matrix[layer_id + 1].cpu().numpy(), 
				xticklabels=languages, 
				yticklabels=languages, 
				cmap='viridis_r',  # Reversed colormap - bright colors for low distances (high similarity)
				# vmin=global_min,
				# vmax=global_max
				)
	plt.title(f'Layer {layer_id + 1} Language Distance Matrix (High Similarity Highlighted)', fontsize=12)
	plt.xlabel('Language', fontsize=10)
	plt.ylabel('Language', fontsize=10)
	plt.xticks(rotation=45, fontsize=4)
	plt.yticks(rotation=45, fontsize=4)
	
	# Adjust colorbar label size
	cbar = plt.gca().collections[0].colorbar
	cbar.ax.tick_params(labelsize=10)
	
	plt.tight_layout()
	plt.show()

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
# Create subplots for dendrograms across all layers
fig, axes = plt.subplots(nrows=9, ncols=5, figsize=(25, 80))
fig.suptitle('Hierarchical Clustering Dendrograms Across All Layers', fontsize=16)

# Flatten axes for easier indexing
axes = axes.flatten()

for layer_id in range(-1, num_layers):
	ax_idx = layer_id + 1
	
	# Perform clustering for this layer
	linked = linkage(distance_matrix[layer_id + 1].cpu().numpy(), 'complete')
	
	# Create dendrogram in the corresponding subplot
	dendrogram(linked, 
			   labels=[LANGCODE2LANGNAME[lang] for lang in languages], 
			   orientation='right',
			   ax=axes[ax_idx])
	
	axes[ax_idx].set_title(f"Layer {layer_id}", fontsize=12)
	axes[ax_idx].tick_params(axis='y', labelsize=8)
	axes[ax_idx].tick_params(axis='x', labelsize=8)

# Save image
image_path = f'plot/cosine_dendrograms_{model_name}.png'
os.makedirs('plot', exist_ok=True)
plt.savefig(image_path, dpi=300, bbox_inches='tight')
plt.close()

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# Assuming 'distance_matrix' is your 90x90 numpy array

# 1. Perform clustering directly on the distance matrix
# No conversion is needed!
layer_id = 0  # Change this to the desired layer index
hac = AgglomerativeClustering(n_clusters=1, metric='precomputed', linkage='complete')
clusters = hac.fit_predict(distance_matrix[layer_id + 1].cpu().numpy())

print("Cluster assignments:", clusters)

# 2. Visualize the dendrogram with language labels - horizontal orientation
# The linkage function also works directly with a distance matrix
linked = linkage(distance_matrix[layer_id + 1].cpu().numpy(), 'complete')

plt.figure(figsize=(10, 15))
dendrogram(linked, labels=[LANGCODE2LANGNAME[lang] for lang in languages], orientation='right')
plt.title(f"Hierarchical Clustering Dendrogram Layer {layer_id}")
plt.xlabel("Distance")
plt.ylabel("Languages")
plt.tight_layout()
plt.show()

# %%
from sklearn.cluster import SpectralClustering
import numpy as np

# Assuming 'sim_matrix' is your 90x90 numpy array
# No need to convert to distance here, as it uses the affinity matrix directly!

spectral = SpectralClustering(n_clusters=4, affinity='precomputed', random_state=0)
clusters = spectral.fit_predict(similarity_matrix[1].cpu().numpy())

print("Cluster assignments:", clusters)

# Print cluster information with language names and codes
for cluster_id in np.unique(clusters):
	cluster_languages = [languages[i] for i in range(len(languages)) if clusters[i] == cluster_id]
	print(f"\nCluster {cluster_id} ({len(cluster_languages)} languages):")
	for lang_code in cluster_languages:
		print(f"  - {LANGCODE2LANGNAME[lang_code]} ({lang_code})")

# %%
from sklearn.cluster import AffinityPropagation
import numpy as np

# Assuming 'sim_matrix' is your 90x90 numpy array

# The 'damping' factor can be adjusted (0.5 to 1) to avoid oscillations
ap = AffinityPropagation(affinity='precomputed', damping=0.5, random_state=0)
clusters = ap.fit_predict(similarity_matrix[1].cpu().numpy())

# The number of clusters is found automatically
num_clusters = len(np.unique(clusters))
print(f"Found {num_clusters} clusters.")
print("Cluster assignments:", clusters)

# Print cluster information with language names and codes
for cluster_id in np.unique(clusters):
	cluster_languages = [languages[i] for i in range(len(languages)) if clusters[i] == cluster_id]
	print(f"\nCluster {cluster_id} ({len(cluster_languages)} languages):")
	for lang_code in cluster_languages:
		print(f"  - {LANGCODE2LANGNAME[lang_code]} ({lang_code})")
