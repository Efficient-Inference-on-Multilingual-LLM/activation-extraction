# %%
import os
import sys

# Change to parent directory
os.chdir('..')
# Add current directory to path
sys.path.append('.')

# %%
import pandas as pd
import numpy as np
from src.utils.const import LANGCODE2LANGNAME, LANGNAME2LANGCODE, MODEL2HIDDEN_SIZE, MODEL2NUM_LAYERS, EXP2_CONFIG
from src.utils.metrics import AlignmentMetrics
import glob
import torch
from tqdm import tqdm

# %%
model_name = 'gemma-3-4b-it' # 1152 size for 1b, 2560 for 4b
model_to_num_layers = {
    'gemma-3-1b-it': 26,
	'gemma-3-4b-it': 34,
    'gemma-3-270m-it': 18,
    'gemma-2-9b-it': 42
}
model_to_hidden_size = {
	'gemma-3-1b-it': 1152,
	'gemma-3-4b-it': 2560,
	'gemma-3-270m-it': 640,
	'gemma-2-9b-it': 3584
}
num_layers = model_to_num_layers[model_name]
extraction_mode = 'raw'
token_position = 'last_token'
languages = glob.glob('outputs/topic_classification/gemma-3-4b-it/raw/*')
languages = sorted([lang.split('/')[-1] for lang in languages])
text_ids = glob.glob('outputs/topic_classification/gemma-3-4b-it/raw/ace_Latn/*')
text_ids = [text_id.split('/')[-1].split('.')[0] for text_id in text_ids]

# %%
# # Extract language codes from the comment and add eng_Latn
# languages = [
# 	'vie_Latn',  # Vietnamese
# 	'ind_Latn',  # Indonesian
# 	'tha_Thai',  # Thai
# 	'zsm_Latn',  # Malay
# 	'mya_Mymr',  # Burmese -> 0 problem
# 	'tgl_Latn',  # Tagalog
# 	'khm_Khmr',  # Khmer
# 	'ceb_Latn',  # Cebuano
# 	'lao_Laoo',  # Lao
# 	'jav_Latn',  # Javanese
# 	'war_Latn',  # Waray
# 	'sun_Latn',  # Sundanese
# 	'ilo_Latn',  # Ilocano
# 	'tam_Taml',  # Tamil
# 	'zho_Hans',  # Chinese
# 	'eng_Latn'   # English
# ]

languages = []
for family, langs in EXP2_CONFIG['languages'].items():
	languages.extend(langs)

languages = [LANGNAME2LANGCODE[lang] for lang in languages]
languages
# Out:
# ['eng_Latn',
#  'deu_Latn',
#  'spa_Latn',
#  'fra_Latn',
#  'arb_Arab',
#  'heb_Hebr',
#  'rus_Cyrl',
#  'slk_Latn',
#  'tha_Thai',
#  'lao_Laoo',
#  'khm_Khmr',
#  'vie_Latn',
#  'swh_Latn',
#  'xho_Latn',
#  'zul_Latn',
#  'urd_Arab',
#  'hin_Deva',
#  'kan_Knda',
#  'tel_Telu',
#  'jpn_Jpan',
#  'kor_Hang',
#  'tur_Latn',
#  'azb_Arab',
#  'azj_Latn',
#  'tgl_Latn',
#  'ceb_Latn',
#  'ilo_Latn',
#  'war_Latn',
#  'yue_Hant',
#  'zho_Hans',
#  'ind_Latn',
#  'zsm_Latn',
#  'min_Latn',
#  'min_Arab',
#  'bjn_Latn',
#  'bjn_Arab',
#  'jav_Latn',
#  'sun_Latn']

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Initialize empty torch tensor to hold all activations [text_id, layer_id, language, hidden_size]
activation_per_lang = torch.zeros((len(text_ids), num_layers + 1, len(languages), MODEL2HIDDEN_SIZE[model_name])).to(device)
print(f'Activation tensor shape: {activation_per_lang.shape}')

# # Reshape to [text_id * language, layer_id, hidden_size]
# activation_per_lang = activation_per_lang.view(-1, num_layers + 1, MODEL2HIDDEN_SIZE[model_name])
# print(f'Reshaped activation tensor shape: {activation_per_lang.shape}')

# # Initialize empty torch tensor to hold all labels [text_id, language]
# labels = torch.zeros((len(text_ids) * len(languages),), dtype=torch.long).to('cuda')
# print(f'Labels tensor shape: {labels.shape}')
# Out:
# Activation tensor shape: torch.Size([204, 35, 38, 2560])

# %%
activation_per_lang.shape
# Out:
# torch.Size([204, 35, 38, 2560])

# %%
# Load activations for all languages
id2langcode = {idx: lang for idx, lang in enumerate(languages)}
langcode2id = {lang: idx for idx, lang in enumerate(languages)}
text_idx = 0
for lang_idx, lang in tqdm(enumerate(languages), total=len(languages), desc='Loading activations for all languages'):
	for layer_id in range(-1, num_layers):
		if layer_id == -1:
			paths = sorted(glob.glob(f'outputs/topic_classification/{model_name}/{extraction_mode}/{lang}/*/{token_position}/layer_embed_tokens.pt'))
		else:
			paths = sorted(glob.glob(f'outputs/topic_classification/{model_name}/{extraction_mode}/{lang}/*/{token_position}/layer_{layer_id}.pt'))
		if len(paths) != len(text_ids):
			print(f"Warning: Expected {len(text_ids)} files for language '{lang}' at layer {layer_id}, but found {len(paths)} files.")
			break
		for path in paths:
			activation = torch.load(path)
			activation_per_lang[text_idx, layer_id + 1, lang_idx, :] = activation.to(device)
			text_idx += 1
		text_idx = 0
# Out:
# Loading activations for all languages: 100%|██████████| 38/38 [02:38<00:00,  4.17s/it]

# %%
import torch.nn.functional as F

feats_A = torch.randn(64, 8192)
feats_B = torch.randn(64, 8192)
feats_A = F.normalize(feats_A, dim=-1)
feats_B = F.normalize(feats_B, dim=-1)

# measure score
score = AlignmentMetrics.measure('cknna', feats_A, feats_B, topk=10)

# alternative
score = AlignmentMetrics.cknna(feats_A, feats_B, topk=10)

# %%
score
# Out:
# 0.1209156326036149

# %%
# 4. Calculate the silhouette score on the GPU
# The function takes the data and the predicted labels as input.
cka_matrix = torch.zeros((num_layers + 1, len(languages), len(languages))).to(device)
for layer_id in tqdm(range(-1, num_layers)):
	# Calculate pairwise silhouette scores per language
	for lang_idx1 in range(len(languages)):
		for lang_idx2 in range(len(languages)):
			if lang_idx1 != lang_idx2:
				# Get activations for both languages
				activations_lang1 = activation_per_lang[:, layer_id + 1, lang_idx1, :]
				activations_lang2 = activation_per_lang[:, layer_id + 1, lang_idx2, :]

				# Normalize activations
				activations_lang1 = F.normalize(activations_lang1, dim=-1)
				activations_lang2 = F.normalize(activations_lang2, dim=-1)

				# Store score in matrix
				cka_matrix[layer_id + 1, lang_idx1, lang_idx2] = AlignmentMetrics.cka(activations_lang1, activations_lang2)
				# cka_matrix[layer_id + 1, lang_idx1, lang_idx2] = AlignmentMetrics.cknna(activations_lang1, activations_lang2, topk=10)

				# print(f"Wasserstein Distance between {id2langcode[lang_idx1]} and {id2langcode[lang_idx2]}: {score:.4f}")

# For this well-separated data, you should see a high score (e.g., > 0.8)
# A high score indicates that the clusters are dense and well-separated.
# Out:
# 100%|██████████| 35/35 [00:34<00:00,  1.03it/s]

# %%
cka_matrix.shape
# Out:
# torch.Size([35, 38, 38])

# %%
# Get top k maximum distance values in each layer with their language pair identifiers

# Set k as a variable
k = 50  # You can change this value as needed

# Initialize lists to store results
all_max_distances = []
all_max_distance_pairs = []

# For each layer, find the top k maximum distances and corresponding language pairs
for layer_id in range(-1, num_layers):
	layer_distances = cka_matrix[layer_id + 1]
	
	# Create a mask to exclude diagonal elements and upper triangle (to avoid duplicates)
	mask = torch.tril(torch.ones_like(layer_distances, dtype=torch.bool), diagonal=-1)
	
	# Get all distances excluding diagonal and upper triangle, then flatten
	lower_triangle_distances = layer_distances[mask]
	
	# Get top k maximum distances
	topk_max_values, topk_indices = torch.topk(lower_triangle_distances, k=k, largest=True)
	
	# Convert flat indices back to 2D coordinates
	layer_max_distances = []
	layer_max_pairs = []
	
	# Get indices of lower triangle elements
	lower_i, lower_j = torch.where(mask)
	
	for idx in range(k):
		flat_idx = topk_indices[idx].item()
		lang_i_idx = lower_i[flat_idx].item()
		lang_j_idx = lower_j[flat_idx].item()
		
		layer_max_distances.append(topk_max_values[idx].item())
		layer_max_pairs.append((languages[lang_i_idx], languages[lang_j_idx]))
	
	all_max_distances.append(layer_max_distances)
	all_max_distance_pairs.append(layer_max_pairs)

# Create a detailed DataFrame
detailed_results = []
for layer_id in range(-1, num_layers):
	for rank in range(k):
		lang1, lang2 = all_max_distance_pairs[layer_id + 1][rank]
		detailed_results.append({
			'Layer': layer_id,
			'Rank': rank + 1,
			'Max_Distance': all_max_distances[layer_id + 1][rank],
			'Language_Pair': f"{LANGCODE2LANGNAME[lang1]} ({lang1}) - {LANGCODE2LANGNAME[lang2]} ({lang2})"
		})

results_df = pd.DataFrame(detailed_results)

print(f"Top {k} maximum distances per layer:")
print(results_df.to_string(index=False))

# Also print a summary view grouped by layer
print("\nSummary by layer:")
for layer_id in range(-1, num_layers):
	print(f"\nLayer {layer_id:2d}:")
	for rank in range(k):
		lang1, lang2 = all_max_distance_pairs[layer_id + 1][rank]
		distance = all_max_distances[layer_id + 1][rank]
		print(f"  {rank+1}. {distance:.6f} - {LANGCODE2LANGNAME[lang1]} ({lang1}) & {LANGCODE2LANGNAME[lang2]} ({lang2})")
# Out:
# Top 50 maximum distances per layer:
#  Layer  Rank  Max_Distance                                                        Language_Pair
#     -1     1      0.004707                               German (deu_Latn) - English (eng_Latn)
#     -1     2      0.004707                              Spanish (spa_Latn) - English (eng_Latn)
#     -1     3      0.004707                               Spanish (spa_Latn) - German (deu_Latn)
#     -1     4      0.004707                               French (fra_Latn) - English (eng_Latn)
#     -1     5      0.004707                                French (fra_Latn) - German (deu_Latn)
#     -1     6      0.004707                               French (fra_Latn) - Spanish (spa_Latn)
#     -1     7      0.004707                         MSA (Arabic) (arb_Arab) - English (eng_Latn)
#     -1     8      0.004707                          MSA (Arabic) (arb_Arab) - German (deu_Latn)
#     -1     9      0.004707                         MSA (Arabic) (arb_Arab) - Spanish (spa_Latn)
#     -1    10      0.004707                          MSA (Arabic) (arb_Arab) - French (fra_Latn)
#     -1    11      0.004707                               Hebrew (heb_Hebr) - English (eng_Latn)
#     -1    12      0.004707                                Hebrew (heb_Hebr) - German (deu_Latn)
#     -1    13      0.004707                               Hebrew (heb_Hebr) - Spanish (spa_Latn)
#     -1    14      0.004707                                Hebrew (heb_Hebr) - French (fra_Latn)
#     -1    15      0.004707                          Hebrew (heb_Hebr) - MSA (Arabic) (arb_Arab)
#     -1    16      0.004707                              Russian (rus_Cyrl) - English (eng_Latn)
#     -1    17      0.004707                               Russian (rus_Cyrl) - German (deu_Latn)
#     -1    18      0.004707                              Russian (rus_Cyrl) - Spanish (spa_Latn)
#     -1    19      0.004707                               Russian (rus_Cyrl) - French (fra_Latn)
#     -1    20      0.004707                         Russian (rus_Cyrl) - MSA (Arabic) (arb_Arab)
#     -1    21      0.004707                               Russian (rus_Cyrl) - Hebrew (heb_Hebr)
#     -1    22      0.004707                               Slovak (slk_Latn) - English (eng_Latn)
#     -1    23      0.004707                                Slovak (slk_Latn) - German (deu_Latn)
#     -1    24      0.004707                               Slovak (slk_Latn) - Spanish (spa_Latn)
#     -1    25      0.004707                                Slovak (slk_Latn) - French (fra_Latn)
#     -1    26      0.004707                          Slovak (slk_Latn) - MSA (Arabic) (arb_Arab)
#     -1    27      0.004707                                Slovak (slk_Latn) - Hebrew (heb_Hebr)
#     -1    28      0.004707                               Slovak (slk_Latn) - Russian (rus_Cyrl)
#     -1    29      0.004707                                 Thai (tha_Thai) - English (eng_Latn)
#     -1    30      0.004707                                  Thai (tha_Thai) - German (deu_Latn)
#     -1    31      0.004707                                 Thai (tha_Thai) - Spanish (spa_Latn)
#     -1    32      0.004707                                  Thai (tha_Thai) - French (fra_Latn)
#     -1    33      0.004707                            Thai (tha_Thai) - MSA (Arabic) (arb_Arab)
#     -1    34      0.004707                                  Thai (tha_Thai) - Hebrew (heb_Hebr)
#     -1    35      0.004707                                 Thai (tha_Thai) - Russian (rus_Cyrl)
#     -1    36      0.004707                                  Thai (tha_Thai) - Slovak (slk_Latn)
#     -1    37      0.004707                                  Lao (lao_Laoo) - English (eng_Latn)
#     -1    38      0.004707                                   Lao (lao_Laoo) - German (deu_Latn)
#     -1    39      0.004707                                  Lao (lao_Laoo) - Spanish (spa_Latn)
#     -1    40      0.004707                                   Lao (lao_Laoo) - French (fra_Latn)
#     -1    41      0.004707                             Lao (lao_Laoo) - MSA (Arabic) (arb_Arab)
#     -1    42      0.004707                                   Lao (lao_Laoo) - Hebrew (heb_Hebr)
#     -1    43      0.004707                                  Lao (lao_Laoo) - Russian (rus_Cyrl)
#     -1    44      0.004707                                   Lao (lao_Laoo) - Slovak (slk_Latn)
#     -1    45      0.004707                                     Lao (lao_Laoo) - Thai (tha_Thai)
#     -1    46      0.004707                                Khmer (khm_Khmr) - English (eng_Latn)
#     -1    47      0.004707                                 Khmer (khm_Khmr) - German (deu_Latn)
#     -1    48      0.004707                                Khmer (khm_Khmr) - Spanish (spa_Latn)
#     -1    49      0.004707                                 Khmer (khm_Khmr) - French (fra_Latn)
#     -1    50      0.004707                           Khmer (khm_Khmr) - MSA (Arabic) (arb_Arab)
#      0     1      0.738115             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      0     2      0.723309     Minangkabau (Arabic) (min_Arab) - Minangkabau (Latin) (min_Latn)
#      0     3      0.722696                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      0     4      0.719861                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      0     5      0.710827                          Hebrew (heb_Hebr) - MSA (Arabic) (arb_Arab)
#      0     6      0.708485 Banjar (Arabic script) (bjn_Arab) - Banjar (Latin script) (bjn_Latn)
#      0     7      0.698983  Banjar (Arabic script) (bjn_Arab) - Minangkabau (Arabic) (min_Arab)
#      0     8      0.685511    Banjar (Latin script) (bjn_Latn) - Minangkabau (Latin) (min_Latn)
#      0     9      0.678003                  Minangkabau (Arabic) (min_Arab) - Hebrew (heb_Hebr)
#      0    10      0.675249                         Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      0    11      0.675121                 Minangkabau (Arabic) (min_Arab) - Ilocano (ilo_Latn)
#      0    12      0.668855                                   Zulu (zul_Latn) - Xhosa (xho_Latn)
#      0    13      0.666164   Banjar (Latin script) (bjn_Latn) - Minangkabau (Arabic) (min_Arab)
#      0    14      0.665734                 Banjar (Latin script) (bjn_Latn) - German (deu_Latn)
#      0    15      0.663309                  Minangkabau (Latin) (min_Latn) - Ilocano (ilo_Latn)
#      0    16      0.661917                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      0    17      0.660059                              Ilocano (ilo_Latn) - Tagalog (tgl_Latn)
#      0    18      0.656151                        Indonesian (ind_Latn) - Vietnamese (vie_Latn)
#      0    19      0.654581                Banjar (Latin script) (bjn_Latn) - Ilocano (ilo_Latn)
#      0    20      0.654193                              Ilocano (ilo_Latn) - Cebuano (ceb_Latn)
#      0    21      0.652307                               Turkish (tur_Latn) - Hebrew (heb_Hebr)
#      0    22      0.651072                               Ilocano (ilo_Latn) - Hebrew (heb_Hebr)
#      0    23      0.650334                               Spanish (spa_Latn) - German (deu_Latn)
#      0    24      0.650029                              Russian (rus_Cyrl) - Spanish (spa_Latn)
#      0    25      0.647683                        Standard Malay (zsm_Latn) - German (deu_Latn)
#      0    26      0.647152                 Banjar (Latin script) (bjn_Latn) - Hebrew (heb_Hebr)
#      0    27      0.646571                              Ilocano (ilo_Latn) - Swahili (swh_Latn)
#      0    28      0.646521               Minangkabau (Latin) (min_Latn) - Indonesian (ind_Latn)
#      0    29      0.645416                           Yue Chinese (yue_Hant) - Hebrew (heb_Hebr)
#      0    30      0.644888              Sundanese (sun_Latn) - Banjar (Latin script) (bjn_Latn)
#      0    31      0.643320                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      0    32      0.643275                Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      0    33      0.642182                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      0    34      0.639846                               Russian (rus_Cyrl) - German (deu_Latn)
#      0    35      0.639471                   Minangkabau (Latin) (min_Latn) - Hebrew (heb_Hebr)
#      0    36      0.638964                Banjar (Arabic script) (bjn_Arab) - Hebrew (heb_Hebr)
#      0    37      0.637332               Minangkabau (Latin) (min_Latn) - Vietnamese (vie_Latn)
#      0    38      0.636092            Minangkabau (Arabic) (min_Arab) - MSA (Arabic) (arb_Arab)
#      0    39      0.634156             Banjar (Latin script) (bjn_Latn) - Vietnamese (vie_Latn)
#      0    40      0.633597                    Standard Malay (zsm_Latn) - Vietnamese (vie_Latn)
#      0    41      0.633565       Minangkabau (Arabic) (min_Arab) - South Azerbaijani (azb_Arab)
#      0    42      0.632581                           Vietnamese (vie_Latn) - English (eng_Latn)
#      0    43      0.631961                              Spanish (spa_Latn) - English (eng_Latn)
#      0    44      0.631065                              Korean (kor_Hang) - Japanese (jpn_Jpan)
#      0    45      0.630101             Banjar (Latin script) (bjn_Latn) - Indonesian (ind_Latn)
#      0    46      0.628927                            Vietnamese (vie_Latn) - German (deu_Latn)
#      0    47      0.628309                Sundanese (sun_Latn) - Minangkabau (Latin) (min_Latn)
#      0    48      0.627692                            Sundanese (sun_Latn) - Ilocano (ilo_Latn)
#      0    49      0.627605                          MSA (Arabic) (arb_Arab) - German (deu_Latn)
#      0    50      0.625709                            Indonesian (ind_Latn) - German (deu_Latn)
#      1     1      0.707875             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      1     2      0.679197                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      1     3      0.664329                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      1     4      0.653813                               Spanish (spa_Latn) - German (deu_Latn)
#      1     5      0.649290                           Vietnamese (vie_Latn) - English (eng_Latn)
#      1     6      0.647158                           Indonesian (ind_Latn) - English (eng_Latn)
#      1     7      0.639564                              Spanish (spa_Latn) - English (eng_Latn)
#      1     8      0.636966                        Indonesian (ind_Latn) - Vietnamese (vie_Latn)
#      1     9      0.633092                               French (fra_Latn) - English (eng_Latn)
#      1    10      0.632273                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      1    11      0.632036                           Indonesian (ind_Latn) - Spanish (spa_Latn)
#      1    12      0.630561                         Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      1    13      0.624945                              Russian (rus_Cyrl) - Spanish (spa_Latn)
#      1    14      0.622884                          Hebrew (heb_Hebr) - MSA (Arabic) (arb_Arab)
#      1    15      0.620585                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      1    16      0.618163                               French (fra_Latn) - Spanish (spa_Latn)
#      1    17      0.608744                            Indonesian (ind_Latn) - German (deu_Latn)
#      1    18      0.607598                           Vietnamese (vie_Latn) - Spanish (spa_Latn)
#      1    19      0.605972                            Vietnamese (vie_Latn) - German (deu_Latn)
#      1    20      0.605227                          Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      1    21      0.605133                Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      1    22      0.604603                            Indonesian (ind_Latn) - French (fra_Latn)
#      1    23      0.604019                               German (deu_Latn) - English (eng_Latn)
#      1    24      0.602715                    Standard Malay (zsm_Latn) - Vietnamese (vie_Latn)
#      1    25      0.601238                           Yue Chinese (yue_Hant) - German (deu_Latn)
#      1    26      0.599519                               Russian (rus_Cyrl) - German (deu_Latn)
#      1    27      0.592583                          Yue Chinese (yue_Hant) - Russian (rus_Cyrl)
#      1    28      0.590877                        Standard Malay (zsm_Latn) - German (deu_Latn)
#      1    29      0.589004                                Slovak (slk_Latn) - German (deu_Latn)
#      1    30      0.588461                          MSA (Arabic) (arb_Arab) - German (deu_Latn)
#      1    31      0.588402                            Vietnamese (vie_Latn) - French (fra_Latn)
#      1    32      0.588066                       Standard Malay (zsm_Latn) - Spanish (spa_Latn)
#      1    33      0.583365                         MSA (Arabic) (arb_Arab) - Spanish (spa_Latn)
#      1    34      0.582446                              Japanese (jpn_Jpan) - German (deu_Latn)
#      1    35      0.581323                              Korean (kor_Hang) - Japanese (jpn_Jpan)
#      1    36      0.580305                       Yue Chinese (yue_Hant) - Vietnamese (vie_Latn)
#      1    37      0.579785                           Indonesian (ind_Latn) - Russian (rus_Cyrl)
#      1    38      0.579533                           Indonesian (ind_Latn) - Turkish (tur_Latn)
#      1    39      0.579120                          Slovak (slk_Latn) - MSA (Arabic) (arb_Arab)
#      1    40      0.578809                           Yue Chinese (yue_Hant) - Korean (kor_Hang)
#      1    41      0.578627                                Slovak (slk_Latn) - Hebrew (heb_Hebr)
#      1    42      0.577802                                Hebrew (heb_Hebr) - German (deu_Latn)
#      1    43      0.577672                             Japanese (jpn_Jpan) - Spanish (spa_Latn)
#      1    44      0.577353                              Turkish (tur_Latn) - Spanish (spa_Latn)
#      1    45      0.577187                           Vietnamese (vie_Latn) - Russian (rus_Cyrl)
#      1    46      0.576882                                French (fra_Latn) - German (deu_Latn)
#      1    47      0.573281                            Indonesian (ind_Latn) - Slovak (slk_Latn)
#      1    48      0.572733             Banjar (Latin script) (bjn_Latn) - Indonesian (ind_Latn)
#      1    49      0.571728                               Swahili (swh_Latn) - Slovak (slk_Latn)
#      1    50      0.571129                               Turkish (tur_Latn) - Slovak (slk_Latn)
#      2     1      0.589321                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      2     2      0.575013                              Spanish (spa_Latn) - English (eng_Latn)
#      2     3      0.572065             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      2     4      0.564977                           Indonesian (ind_Latn) - English (eng_Latn)
#      2     5      0.533092                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      2     6      0.522825                           Vietnamese (vie_Latn) - English (eng_Latn)
#      2     7      0.508730                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      2     8      0.504373                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      2     9      0.501688                          Javanese (jav_Latn) - Indonesian (ind_Latn)
#      2    10      0.497832                               French (fra_Latn) - English (eng_Latn)
#      2    11      0.495678                               French (fra_Latn) - Spanish (spa_Latn)
#      2    12      0.487702                 Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      2    13      0.486213                           Indonesian (ind_Latn) - Spanish (spa_Latn)
#      2    14      0.483050                               Spanish (spa_Latn) - German (deu_Latn)
#      2    15      0.479208                             Javanese (jav_Latn) - Swahili (swh_Latn)
#      2    16      0.472043                                   Zulu (zul_Latn) - Xhosa (xho_Latn)
#      2    17      0.470398                              Ilocano (ilo_Latn) - Cebuano (ceb_Latn)
#      2    18      0.470341                       Standard Malay (zsm_Latn) - English (eng_Latn)
#      2    19      0.470316               Minangkabau (Latin) (min_Latn) - Indonesian (ind_Latn)
#      2    20      0.461847                           Sundanese (sun_Latn) - Javanese (jav_Latn)
#      2    21      0.461262                         Sundanese (sun_Latn) - Indonesian (ind_Latn)
#      2    22      0.460839                              Russian (rus_Cyrl) - Spanish (spa_Latn)
#      2    23      0.460593                           Vietnamese (vie_Latn) - Spanish (spa_Latn)
#      2    24      0.459958                   Chinese (Simplified) (zho_Hans) - Hindi (hin_Deva)
#      2    25      0.459920                                Hindi (hin_Deva) - English (eng_Latn)
#      2    26      0.459883                      Javanese (jav_Latn) - Standard Malay (zsm_Latn)
#      2    27      0.457059                 Javanese (jav_Latn) - Minangkabau (Latin) (min_Latn)
#      2    28      0.454687                                Hindi (hin_Deva) - Spanish (spa_Latn)
#      2    29      0.452387                        Indonesian (ind_Latn) - Vietnamese (vie_Latn)
#      2    30      0.446692                    Standard Malay (zsm_Latn) - Vietnamese (vie_Latn)
#      2    31      0.446492                               German (deu_Latn) - English (eng_Latn)
#      2    32      0.442196                             Javanese (jav_Latn) - English (eng_Latn)
#      2    33      0.441926             Banjar (Latin script) (bjn_Latn) - Indonesian (ind_Latn)
#      2    34      0.441409    Banjar (Latin script) (bjn_Latn) - Minangkabau (Latin) (min_Latn)
#      2    35      0.440773               Javanese (jav_Latn) - Banjar (Latin script) (bjn_Latn)
#      2    36      0.438792                       Standard Malay (zsm_Latn) - Spanish (spa_Latn)
#      2    37      0.436296                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      2    38      0.435335                  Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      2    39      0.433741                         Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      2    40      0.429231                               Korean (kor_Hang) - English (eng_Latn)
#      2    41      0.427801                            Sundanese (sun_Latn) - English (eng_Latn)
#      2    42      0.425608                           Indonesian (ind_Latn) - Turkish (tur_Latn)
#      2    43      0.423015                          Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      2    44      0.421598                         Sundanese (sun_Latn) - Vietnamese (vie_Latn)
#      2    45      0.420907                                Waray (war_Latn) - English (eng_Latn)
#      2    46      0.418542                              Turkish (tur_Latn) - Spanish (spa_Latn)
#      2    47      0.416147              Indonesian (ind_Latn) - Chinese (Simplified) (zho_Hans)
#      2    48      0.414638                                Slovak (slk_Latn) - German (deu_Latn)
#      2    49      0.414227                Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      2    50      0.414220                 Chinese (Simplified) (zho_Hans) - Russian (rus_Cyrl)
#      3     1      0.608948             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      3     2      0.597641                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      3     3      0.582505                              Spanish (spa_Latn) - English (eng_Latn)
#      3     4      0.567818                           Indonesian (ind_Latn) - English (eng_Latn)
#      3     5      0.532892                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      3     6      0.531365                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      3     7      0.522554                           Vietnamese (vie_Latn) - English (eng_Latn)
#      3     8      0.521934                          Javanese (jav_Latn) - Indonesian (ind_Latn)
#      3     9      0.512893                               French (fra_Latn) - Spanish (spa_Latn)
#      3    10      0.509445                 Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      3    11      0.502812                               French (fra_Latn) - English (eng_Latn)
#      3    12      0.498640                           Indonesian (ind_Latn) - Spanish (spa_Latn)
#      3    13      0.494709                                Hindi (hin_Deva) - English (eng_Latn)
#      3    14      0.493158                               Spanish (spa_Latn) - German (deu_Latn)
#      3    15      0.485145                      Javanese (jav_Latn) - Standard Malay (zsm_Latn)
#      3    16      0.483917                                Hindi (hin_Deva) - Spanish (spa_Latn)
#      3    17      0.478371                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      3    18      0.477985                   Chinese (Simplified) (zho_Hans) - Hindi (hin_Deva)
#      3    19      0.473020                       Standard Malay (zsm_Latn) - English (eng_Latn)
#      3    20      0.472523    Banjar (Latin script) (bjn_Latn) - Minangkabau (Latin) (min_Latn)
#      3    21      0.472479                           Sundanese (sun_Latn) - Javanese (jav_Latn)
#      3    22      0.472456                              Russian (rus_Cyrl) - Spanish (spa_Latn)
#      3    23      0.470703               Minangkabau (Latin) (min_Latn) - Indonesian (ind_Latn)
#      3    24      0.470447             Banjar (Latin script) (bjn_Latn) - Indonesian (ind_Latn)
#      3    25      0.469748                           Vietnamese (vie_Latn) - Spanish (spa_Latn)
#      3    26      0.469445                                   Zulu (zul_Latn) - Xhosa (xho_Latn)
#      3    27      0.467270                  Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      3    28      0.467002                        Indonesian (ind_Latn) - Vietnamese (vie_Latn)
#      3    29      0.463076                         Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      3    30      0.462292               Javanese (jav_Latn) - Banjar (Latin script) (bjn_Latn)
#      3    31      0.460728                           Tagalog (tgl_Latn) - Vietnamese (vie_Latn)
#      3    32      0.459238                             Javanese (jav_Latn) - Swahili (swh_Latn)
#      3    33      0.458562                               German (deu_Latn) - English (eng_Latn)
#      3    34      0.457366                    Standard Malay (zsm_Latn) - Vietnamese (vie_Latn)
#      3    35      0.457104                               Korean (kor_Hang) - English (eng_Latn)
#      3    36      0.455656                Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      3    37      0.454900                         Sundanese (sun_Latn) - Indonesian (ind_Latn)
#      3    38      0.452637                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      3    39      0.451548                       Standard Malay (zsm_Latn) - Spanish (spa_Latn)
#      3    40      0.450093                           Indonesian (ind_Latn) - Turkish (tur_Latn)
#      3    41      0.449109                 Javanese (jav_Latn) - Minangkabau (Latin) (min_Latn)
#      3    42      0.445412                 Chinese (Simplified) (zho_Hans) - Russian (rus_Cyrl)
#      3    43      0.443381                          Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      3    44      0.442847              Chinese (Simplified) (zho_Hans) - Vietnamese (vie_Latn)
#      3    45      0.440958              Indonesian (ind_Latn) - Chinese (Simplified) (zho_Hans)
#      3    46      0.439029                                Turkish (tur_Latn) - Hindi (hin_Deva)
#      3    47      0.437607                              Turkish (tur_Latn) - Spanish (spa_Latn)
#      3    48      0.436254                            Vietnamese (vie_Latn) - Slovak (slk_Latn)
#      3    49      0.434365                            Yue Chinese (yue_Hant) - Hindi (hin_Deva)
#      3    50      0.433057                               Japanese (jpn_Jpan) - Hindi (hin_Deva)
#      4     1      0.685133                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      4     2      0.682632                              Spanish (spa_Latn) - English (eng_Latn)
#      4     3      0.678455             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      4     4      0.652498                           Indonesian (ind_Latn) - English (eng_Latn)
#      4     5      0.644874                               French (fra_Latn) - English (eng_Latn)
#      4     6      0.637798                               French (fra_Latn) - Spanish (spa_Latn)
#      4     7      0.630304                                Hindi (hin_Deva) - English (eng_Latn)
#      4     8      0.614279                           Vietnamese (vie_Latn) - English (eng_Latn)
#      4     9      0.608459                           Indonesian (ind_Latn) - Spanish (spa_Latn)
#      4    10      0.606824                                Hindi (hin_Deva) - Spanish (spa_Latn)
#      4    11      0.598570                       Standard Malay (zsm_Latn) - English (eng_Latn)
#      4    12      0.597410                               Spanish (spa_Latn) - German (deu_Latn)
#      4    13      0.582450                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      4    14      0.581921                        Indonesian (ind_Latn) - Vietnamese (vie_Latn)
#      4    15      0.579731                           Vietnamese (vie_Latn) - Spanish (spa_Latn)
#      4    16      0.579646                               German (deu_Latn) - English (eng_Latn)
#      4    17      0.577398                            Indonesian (ind_Latn) - French (fra_Latn)
#      4    18      0.576475                       Standard Malay (zsm_Latn) - Spanish (spa_Latn)
#      4    19      0.574775                 Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      4    20      0.574398                    Standard Malay (zsm_Latn) - Vietnamese (vie_Latn)
#      4    21      0.572643                   Chinese (Simplified) (zho_Hans) - Hindi (hin_Deva)
#      4    22      0.567899                               Korean (kor_Hang) - English (eng_Latn)
#      4    23      0.566630                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      4    24      0.564084                         Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      4    25      0.557431                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      4    26      0.557058                               Japanese (jpn_Jpan) - Hindi (hin_Deva)
#      4    27      0.556884                      Javanese (jav_Latn) - Standard Malay (zsm_Latn)
#      4    28      0.556740                              Russian (rus_Cyrl) - Spanish (spa_Latn)
#      4    29      0.556410                         Standard Malay (zsm_Latn) - Hindi (hin_Deva)
#      4    30      0.555776                          Javanese (jav_Latn) - Indonesian (ind_Latn)
#      4    31      0.554315                                 Hindi (hin_Deva) - German (deu_Latn)
#      4    32      0.550070                            Vietnamese (vie_Latn) - French (fra_Latn)
#      4    33      0.549519                             Indonesian (ind_Latn) - Hindi (hin_Deva)
#      4    34      0.548933                                Turkish (tur_Latn) - Hindi (hin_Deva)
#      4    35      0.548377                  Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      4    36      0.546627                Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      4    37      0.545161                                 Korean (kor_Hang) - Hindi (hin_Deva)
#      4    38      0.540822                 Chinese (Simplified) (zho_Hans) - Russian (rus_Cyrl)
#      4    39      0.538959                          Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      4    40      0.538939                            Yue Chinese (yue_Hant) - Hindi (hin_Deva)
#      4    41      0.537260                                 Hindi (hin_Deva) - French (fra_Latn)
#      4    42      0.535609                            Indonesian (ind_Latn) - German (deu_Latn)
#      4    43      0.535334              Chinese (Simplified) (zho_Hans) - Vietnamese (vie_Latn)
#      4    44      0.535221                       Yue Chinese (yue_Hant) - Vietnamese (vie_Latn)
#      4    45      0.534244                                Slovak (slk_Latn) - German (deu_Latn)
#      4    46      0.532044                       Indonesian (ind_Latn) - Yue Chinese (yue_Hant)
#      4    47      0.531757                 Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#      4    48      0.531696                             Javanese (jav_Latn) - Swahili (swh_Latn)
#      4    49      0.530968                               Korean (kor_Hang) - Spanish (spa_Latn)
#      4    50      0.530897                                Hindi (hin_Deva) - Russian (rus_Cyrl)
#      5     1      0.718802             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      5     2      0.695214                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      5     3      0.688153                              Spanish (spa_Latn) - English (eng_Latn)
#      5     4      0.655743                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      5     5      0.654759                           Indonesian (ind_Latn) - English (eng_Latn)
#      5     6      0.642555                               French (fra_Latn) - Spanish (spa_Latn)
#      5     7      0.640984                               French (fra_Latn) - English (eng_Latn)
#      5     8      0.637184                                Waray (war_Latn) - Ilocano (ilo_Latn)
#      5     9      0.635186                               Spanish (spa_Latn) - German (deu_Latn)
#      5    10      0.632867                              Cebuano (ceb_Latn) - Tagalog (tgl_Latn)
#      5    11      0.632579                        Indonesian (ind_Latn) - Vietnamese (vie_Latn)
#      5    12      0.630625                            Vietnamese (vie_Latn) - Slovak (slk_Latn)
#      5    13      0.629421                                Slovak (slk_Latn) - German (deu_Latn)
#      5    14      0.628945                           Vietnamese (vie_Latn) - English (eng_Latn)
#      5    15      0.625779                           Indonesian (ind_Latn) - Spanish (spa_Latn)
#      5    16      0.620291                    Standard Malay (zsm_Latn) - Vietnamese (vie_Latn)
#      5    17      0.619374                         Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      5    18      0.615232                                Hindi (hin_Deva) - Spanish (spa_Latn)
#      5    19      0.614271                                Hindi (hin_Deva) - English (eng_Latn)
#      5    20      0.611667                           Tagalog (tgl_Latn) - Vietnamese (vie_Latn)
#      5    21      0.610871                           Vietnamese (vie_Latn) - Spanish (spa_Latn)
#      5    22      0.610599                   Chinese (Simplified) (zho_Hans) - Hindi (hin_Deva)
#      5    23      0.608181                       Yue Chinese (yue_Hant) - Vietnamese (vie_Latn)
#      5    24      0.608057                      Vietnamese (vie_Latn) - MSA (Arabic) (arb_Arab)
#      5    25      0.606159              Chinese (Simplified) (zho_Hans) - Vietnamese (vie_Latn)
#      5    26      0.605679                 Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      5    27      0.601066                Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      5    28      0.601055                                Waray (war_Latn) - Tagalog (tgl_Latn)
#      5    29      0.600834                                   Zulu (zul_Latn) - Xhosa (xho_Latn)
#      5    30      0.600500                          Javanese (jav_Latn) - Indonesian (ind_Latn)
#      5    31      0.599202                       Standard Malay (zsm_Latn) - English (eng_Latn)
#      5    32      0.598284                              Ilocano (ilo_Latn) - Cebuano (ceb_Latn)
#      5    33      0.597015                              Russian (rus_Cyrl) - Spanish (spa_Latn)
#      5    34      0.596358                               Japanese (jpn_Jpan) - Hindi (hin_Deva)
#      5    35      0.594924                               German (deu_Latn) - English (eng_Latn)
#      5    36      0.594921                           Yue Chinese (yue_Hant) - Slovak (slk_Latn)
#      5    37      0.594587                  Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      5    38      0.592165                           Turkish (tur_Latn) - Vietnamese (vie_Latn)
#      5    39      0.592137                            Yue Chinese (yue_Hant) - Hindi (hin_Deva)
#      5    40      0.590027                            Indonesian (ind_Latn) - German (deu_Latn)
#      5    41      0.588758                            Vietnamese (vie_Latn) - German (deu_Latn)
#      5    42      0.588015                            Indonesian (ind_Latn) - French (fra_Latn)
#      5    43      0.587461                        Standard Malay (zsm_Latn) - Slovak (slk_Latn)
#      5    44      0.586345                                Turkish (tur_Latn) - Hindi (hin_Deva)
#      5    45      0.585654                                 Korean (kor_Hang) - Hindi (hin_Deva)
#      5    46      0.583558                            Vietnamese (vie_Latn) - French (fra_Latn)
#      5    47      0.583157                          Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      5    48      0.582716                       Standard Malay (zsm_Latn) - Spanish (spa_Latn)
#      5    49      0.582569                      Javanese (jav_Latn) - Standard Malay (zsm_Latn)
#      5    50      0.581874                               Tagalog (tgl_Latn) - Slovak (slk_Latn)
#      6     1      0.822046             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      6     2      0.794042                              Spanish (spa_Latn) - English (eng_Latn)
#      6     3      0.783787                               French (fra_Latn) - English (eng_Latn)
#      6     4      0.765563                               French (fra_Latn) - Spanish (spa_Latn)
#      6     5      0.763965                               Spanish (spa_Latn) - German (deu_Latn)
#      6     6      0.762486                           Indonesian (ind_Latn) - English (eng_Latn)
#      6     7      0.760790                               German (deu_Latn) - English (eng_Latn)
#      6     8      0.760751                                Slovak (slk_Latn) - German (deu_Latn)
#      6     9      0.753210                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      6    10      0.752211                         Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      6    11      0.746056                           Yue Chinese (yue_Hant) - German (deu_Latn)
#      6    12      0.742224                 Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      6    13      0.741571                              Russian (rus_Cyrl) - Spanish (spa_Latn)
#      6    14      0.739262                              Russian (rus_Cyrl) - English (eng_Latn)
#      6    15      0.738204                 Chinese (Simplified) (zho_Hans) - Russian (rus_Cyrl)
#      6    16      0.737722                                Hindi (hin_Deva) - English (eng_Latn)
#      6    17      0.736808                           Yue Chinese (yue_Hant) - Slovak (slk_Latn)
#      6    18      0.734704                Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      6    19      0.733456                          Yue Chinese (yue_Hant) - Russian (rus_Cyrl)
#      6    20      0.733316                          Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      6    21      0.732980                            Indonesian (ind_Latn) - French (fra_Latn)
#      6    22      0.732115                          Yue Chinese (yue_Hant) - English (eng_Latn)
#      6    23      0.731802                            Indonesian (ind_Latn) - German (deu_Latn)
#      6    24      0.730868                           Indonesian (ind_Latn) - Spanish (spa_Latn)
#      6    25      0.730609                                French (fra_Latn) - German (deu_Latn)
#      6    26      0.730514                     Yue Chinese (yue_Hant) - MSA (Arabic) (arb_Arab)
#      6    27      0.730483                               Russian (rus_Cyrl) - German (deu_Latn)
#      6    28      0.728123                          Slovak (slk_Latn) - MSA (Arabic) (arb_Arab)
#      6    29      0.728018                 Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#      6    30      0.727666                               Russian (rus_Cyrl) - French (fra_Latn)
#      6    31      0.727461                               Slovak (slk_Latn) - English (eng_Latn)
#      6    32      0.727215                       Indonesian (ind_Latn) - Yue Chinese (yue_Hant)
#      6    33      0.726192                  Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#      6    34      0.726028                            Indonesian (ind_Latn) - Slovak (slk_Latn)
#      6    35      0.725475                               Slovak (slk_Latn) - Russian (rus_Cyrl)
#      6    36      0.725111                          MSA (Arabic) (arb_Arab) - German (deu_Latn)
#      6    37      0.724976                            Yue Chinese (yue_Hant) - Hindi (hin_Deva)
#      6    38      0.724328                               Slovak (slk_Latn) - Spanish (spa_Latn)
#      6    39      0.724298                              Japanese (jpn_Jpan) - German (deu_Latn)
#      6    40      0.723280                                 Hindi (hin_Deva) - German (deu_Latn)
#      6    41      0.723000                               Japanese (jpn_Jpan) - Hindi (hin_Deva)
#      6    42      0.722904                  Chinese (Simplified) (zho_Hans) - Slovak (slk_Latn)
#      6    43      0.722524                   Chinese (Simplified) (zho_Hans) - Hindi (hin_Deva)
#      6    44      0.721377                                 Hindi (hin_Deva) - Slovak (slk_Latn)
#      6    45      0.721009                                Slovak (slk_Latn) - French (fra_Latn)
#      6    46      0.719830                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      6    47      0.718357                           Yue Chinese (yue_Hant) - Korean (kor_Hang)
#      6    48      0.717777                               Turkish (tur_Latn) - German (deu_Latn)
#      6    49      0.717416                           Indonesian (ind_Latn) - Russian (rus_Cyrl)
#      6    50      0.716824                  Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      7     1      0.814536             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      7     2      0.790768                               French (fra_Latn) - English (eng_Latn)
#      7     3      0.785839                              Spanish (spa_Latn) - English (eng_Latn)
#      7     4      0.770059                               French (fra_Latn) - Spanish (spa_Latn)
#      7     5      0.761558                               German (deu_Latn) - English (eng_Latn)
#      7     6      0.761485                               Spanish (spa_Latn) - German (deu_Latn)
#      7     7      0.758874                           Indonesian (ind_Latn) - English (eng_Latn)
#      7     8      0.752626                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      7     9      0.751567                         Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      7    10      0.746232                                Slovak (slk_Latn) - German (deu_Latn)
#      7    11      0.746004                                Slovak (slk_Latn) - French (fra_Latn)
#      7    12      0.744154                                French (fra_Latn) - German (deu_Latn)
#      7    13      0.743110                              Russian (rus_Cyrl) - English (eng_Latn)
#      7    14      0.742849                            Indonesian (ind_Latn) - French (fra_Latn)
#      7    15      0.739885                               Russian (rus_Cyrl) - French (fra_Latn)
#      7    16      0.739586                              Russian (rus_Cyrl) - Spanish (spa_Latn)
#      7    17      0.739563                          Yue Chinese (yue_Hant) - Russian (rus_Cyrl)
#      7    18      0.738441                 Chinese (Simplified) (zho_Hans) - Russian (rus_Cyrl)
#      7    19      0.737951                Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      7    20      0.735023                               Slovak (slk_Latn) - Russian (rus_Cyrl)
#      7    21      0.734177                           Yue Chinese (yue_Hant) - German (deu_Latn)
#      7    22      0.731511                               Russian (rus_Cyrl) - German (deu_Latn)
#      7    23      0.730384                 Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      7    24      0.728952                               Slovak (slk_Latn) - Spanish (spa_Latn)
#      7    25      0.727103                          Slovak (slk_Latn) - MSA (Arabic) (arb_Arab)
#      7    26      0.726912                           Yue Chinese (yue_Hant) - Korean (kor_Hang)
#      7    27      0.726177                               Slovak (slk_Latn) - English (eng_Latn)
#      7    28      0.726166                           Yue Chinese (yue_Hant) - Slovak (slk_Latn)
#      7    29      0.725597                            Indonesian (ind_Latn) - German (deu_Latn)
#      7    30      0.724751                 Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#      7    31      0.724237                              Japanese (jpn_Jpan) - German (deu_Latn)
#      7    32      0.723530                  Chinese (Simplified) (zho_Hans) - Slovak (slk_Latn)
#      7    33      0.723385                          Yue Chinese (yue_Hant) - English (eng_Latn)
#      7    34      0.723233                  Chinese (Simplified) (zho_Hans) - German (deu_Latn)
#      7    35      0.722859                     Yue Chinese (yue_Hant) - MSA (Arabic) (arb_Arab)
#      7    36      0.722378                          Yue Chinese (yue_Hant) - Spanish (spa_Latn)
#      7    37      0.722360                           Yue Chinese (yue_Hant) - French (fra_Latn)
#      7    38      0.722005                  Chinese (Simplified) (zho_Hans) - Korean (kor_Hang)
#      7    39      0.721650                                Hindi (hin_Deva) - English (eng_Latn)
#      7    40      0.721263                          MSA (Arabic) (arb_Arab) - German (deu_Latn)
#      7    41      0.720625                              Korean (kor_Hang) - Japanese (jpn_Jpan)
#      7    42      0.720389                           Indonesian (ind_Latn) - Spanish (spa_Latn)
#      7    43      0.720186                          Hebrew (heb_Hebr) - MSA (Arabic) (arb_Arab)
#      7    44      0.718922                               Turkish (tur_Latn) - German (deu_Latn)
#      7    45      0.718493                                Waray (war_Latn) - Cebuano (ceb_Latn)
#      7    46      0.717912                            Indonesian (ind_Latn) - Slovak (slk_Latn)
#      7    47      0.716908                           Indonesian (ind_Latn) - Russian (rus_Cyrl)
#      7    48      0.716402                         Russian (rus_Cyrl) - MSA (Arabic) (arb_Arab)
#      7    49      0.716253                               Turkish (tur_Latn) - French (fra_Latn)
#      7    50      0.716225                       Indonesian (ind_Latn) - Yue Chinese (yue_Hant)
#      8     1      0.837462             Chinese (Simplified) (zho_Hans) - Yue Chinese (yue_Hant)
#      8     2      0.831056                               French (fra_Latn) - English (eng_Latn)
#      8     3      0.816894                              Spanish (spa_Latn) - English (eng_Latn)
#      8     4      0.811143                               German (deu_Latn) - English (eng_Latn)
#      8     5      0.806784                               Spanish (spa_Latn) - German (deu_Latn)
#      8     6      0.803140                           Indonesian (ind_Latn) - English (eng_Latn)
#      8     7      0.801178                    Standard Malay (zsm_Latn) - Indonesian (ind_Latn)
#      8     8      0.800305                               French (fra_Latn) - Spanish (spa_Latn)
#      8     9      0.795595                               Russian (rus_Cyrl) - French (fra_Latn)
#      8    10      0.795201                              Russian (rus_Cyrl) - English (eng_Latn)
#      8    11      0.793341                                French (fra_Latn) - German (deu_Latn)
#      8    12      0.792097                                Slovak (slk_Latn) - German (deu_Latn)
#      8    13      0.788375                               Russian (rus_Cyrl) - German (deu_Latn)
#      8    14      0.787569                          Yue Chinese (yue_Hant) - English (eng_Latn)
#      8    15      0.787129                            Indonesian (ind_Latn) - French (fra_Latn)
#      8    16      0.785891                               Slovak (slk_Latn) - Russian (rus_Cyrl)
#      8    17      0.785257                                Slovak (slk_Latn) - French (fra_Latn)
#      8    18      0.783231                                Hindi (hin_Deva) - English (eng_Latn)
#      8    19      0.781905                         Yue Chinese (yue_Hant) - Japanese (jpn_Jpan)
#      8    20      0.779803                              Russian (rus_Cyrl) - Spanish (spa_Latn)
#      8    21      0.779444                          Yue Chinese (yue_Hant) - Russian (rus_Cyrl)
#      8    22      0.778798                           Yue Chinese (yue_Hant) - French (fra_Latn)
#      8    23      0.777046                 Chinese (Simplified) (zho_Hans) - Russian (rus_Cyrl)
#      8    24      0.775265                 Chinese (Simplified) (zho_Hans) - English (eng_Latn)
#      8    25      0.774171                               Slovak (slk_Latn) - English (eng_Latn)
#      8    26      0.772517                           Yue Chinese (yue_Hant) - German (deu_Latn)
#      8    27      0.772379                           Indonesian (ind_Latn) - Russian (rus_Cyrl)
#      8    28      0.772191                            Indonesian (ind_Latn) - German (deu_Latn)
#      8    29      0.768060                          MSA (Arabic) (arb_Arab) - German (deu_Latn)
#      8    30      0.766380                          Hebrew (heb_Hebr) - MSA (Arabic) (arb_Arab)
#      8    31      0.766166                            Yue Chinese (yue_Hant) - Hindi (hin_Deva)
#      8    32      0.765633                          Slovak (slk_Latn) - MSA (Arabic) (arb_Arab)
#      8    33      0.765538                               Slovak (slk_Latn) - Spanish (spa_Latn)
#      8    34      0.765132                       Indonesian (ind_Latn) - Yue Chinese (yue_Hant)
#      8    35      0.764936                           Indonesian (ind_Latn) - Spanish (spa_Latn)
#      8    36      0.764560                         MSA (Arabic) (arb_Arab) - Spanish (spa_Latn)
#      8    37      0.764540                                 Hindi (hin_Deva) - French (fra_Latn)
#      8    38      0.764382                           Yue Chinese (yue_Hant) - Slovak (slk_Latn)
#      8    39      0.764257                         Russian (rus_Cyrl) - MSA (Arabic) (arb_Arab)
#      8    40      0.763929                      Indonesian (ind_Latn) - MSA (Arabic) (arb_Arab)
#      8    41      0.763663                                 Hindi (hin_Deva) - German (deu_Latn)
#      8    42      0.763418                               Russian (rus_Cyrl) - Hebrew (heb_Hebr)
#      8    43      0.763232                            Indonesian (ind_Latn) - Slovak (slk_Latn)
#      8    44      0.761773                Chinese (Simplified) (zho_Hans) - Japanese (jpn_Jpan)
#      8    45      0.761680                            Indonesian (ind_Latn) - Hebrew (heb_Hebr)
#      8    46      0.761582                 Chinese (Simplified) (zho_Hans) - Spanish (spa_Latn)
#      8    47      0.761558                       Standard Malay (zsm_Latn) - English (eng_Latn)
#      8    48      0.761134                  Chinese (Simplified) (zho_Hans) - French (fra_Latn)
# ...
#   35. 0.637470 - Indonesian (ind_Latn) & German (deu_Latn)
#   36. 0.636807 - Yue Chinese (yue_Hant) & Japanese (jpn_Jpan)
#   37. 0.634978 - Turkish (tur_Latn) & German (deu_Latn)
#   38. 0.634088 - MSA (Arabic) (arb_Arab) & German (deu_Latn)
#   39. 0.633077 - Japanese (jpn_Jpan) & Russian (rus_Cyrl)
#   40. 0.632538 - Indonesian (ind_Latn) & Slovak (slk_Latn)
#   41. 0.630978 - MSA (Arabic) (arb_Arab) & French (fra_Latn)
#   42. 0.629336 - Vietnamese (vie_Latn) & German (deu_Latn)
#   43. 0.628327 - Indonesian (ind_Latn) & Vietnamese (vie_Latn)
#   44. 0.627124 - MSA (Arabic) (arb_Arab) & Spanish (spa_Latn)
#   45. 0.626705 - Tagalog (tgl_Latn) & French (fra_Latn)
#   46. 0.623917 - Indonesian (ind_Latn) & French (fra_Latn)
#   47. 0.623183 - MSA (Arabic) (arb_Arab) & English (eng_Latn)
#   48. 0.619423 - Japanese (jpn_Jpan) & Spanish (spa_Latn)
#   49. 0.616770 - Hebrew (heb_Hebr) & French (fra_Latn)
#   50. 0.616085 - Chinese (Simplified) (zho_Hans) & Japanese (jpn_Jpan)
#
# Layer 29:
#   1. 0.750397 - German (deu_Latn) & English (eng_Latn)
#   2. 0.750008 - Slovak (slk_Latn) & German (deu_Latn)
#   3. 0.743685 - French (fra_Latn) & English (eng_Latn)
#   4. 0.741194 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   5. 0.740615 - Spanish (spa_Latn) & English (eng_Latn)
#   6. 0.736803 - Russian (rus_Cyrl) & German (deu_Latn)
#   7. 0.734414 - French (fra_Latn) & Spanish (spa_Latn)
#   8. 0.731532 - French (fra_Latn) & German (deu_Latn)
#   9. 0.727858 - Slovak (slk_Latn) & Russian (rus_Cyrl)
#   10. 0.720333 - Russian (rus_Cyrl) & French (fra_Latn)
#   11. 0.718774 - Spanish (spa_Latn) & German (deu_Latn)
#   12. 0.718345 - Russian (rus_Cyrl) & Spanish (spa_Latn)
#   13. 0.707639 - Russian (rus_Cyrl) & English (eng_Latn)
#   14. 0.691976 - Chinese (Simplified) (zho_Hans) & Russian (rus_Cyrl)
#   15. 0.681671 - Chinese (Simplified) (zho_Hans) & English (eng_Latn)
#   16. 0.673960 - Russian (rus_Cyrl) & MSA (Arabic) (arb_Arab)
#   17. 0.668234 - Slovak (slk_Latn) & French (fra_Latn)
#   18. 0.668080 - Turkish (tur_Latn) & Japanese (jpn_Jpan)
#   19. 0.659814 - Yue Chinese (yue_Hant) & Russian (rus_Cyrl)
#   20. 0.656133 - Slovak (slk_Latn) & English (eng_Latn)
#   21. 0.655214 - Japanese (jpn_Jpan) & German (deu_Latn)
#   22. 0.654135 - Chinese (Simplified) (zho_Hans) & French (fra_Latn)
#   23. 0.648972 - Indonesian (ind_Latn) & Russian (rus_Cyrl)
#   24. 0.647378 - Vietnamese (vie_Latn) & French (fra_Latn)
#   25. 0.643741 - Slovak (slk_Latn) & Spanish (spa_Latn)
#   26. 0.642185 - Chinese (Simplified) (zho_Hans) & German (deu_Latn)
#   27. 0.641572 - Chinese (Simplified) (zho_Hans) & Spanish (spa_Latn)
#   28. 0.640655 - Tagalog (tgl_Latn) & German (deu_Latn)
#   29. 0.640321 - Tagalog (tgl_Latn) & Russian (rus_Cyrl)
#   30. 0.639913 - Yue Chinese (yue_Hant) & Japanese (jpn_Jpan)
#   31. 0.638430 - Vietnamese (vie_Latn) & Russian (rus_Cyrl)
#   32. 0.638336 - Chinese (Simplified) (zho_Hans) & Slovak (slk_Latn)
#   33. 0.636732 - Yue Chinese (yue_Hant) & English (eng_Latn)
#   34. 0.636563 - Tagalog (tgl_Latn) & Slovak (slk_Latn)
#   35. 0.636557 - Indonesian (ind_Latn) & German (deu_Latn)
#   36. 0.634530 - Indonesian (ind_Latn) & English (eng_Latn)
#   37. 0.634344 - MSA (Arabic) (arb_Arab) & German (deu_Latn)
#   38. 0.633177 - Turkish (tur_Latn) & German (deu_Latn)
#   39. 0.632674 - MSA (Arabic) (arb_Arab) & French (fra_Latn)
#   40. 0.632235 - Japanese (jpn_Jpan) & Russian (rus_Cyrl)
#   41. 0.627500 - Indonesian (ind_Latn) & Slovak (slk_Latn)
#   42. 0.627335 - MSA (Arabic) (arb_Arab) & Spanish (spa_Latn)
#   43. 0.626833 - Indonesian (ind_Latn) & Vietnamese (vie_Latn)
#   44. 0.626393 - Indonesian (ind_Latn) & French (fra_Latn)
#   45. 0.624804 - Tagalog (tgl_Latn) & French (fra_Latn)
#   46. 0.624730 - Vietnamese (vie_Latn) & German (deu_Latn)
#   47. 0.620848 - MSA (Arabic) (arb_Arab) & English (eng_Latn)
#   48. 0.620301 - Hebrew (heb_Hebr) & French (fra_Latn)
#   49. 0.618958 - Chinese (Simplified) (zho_Hans) & Japanese (jpn_Jpan)
#   50. 0.615837 - Turkish (tur_Latn) & Russian (rus_Cyrl)
#
# Layer 30:
#   1. 0.749700 - Slovak (slk_Latn) & German (deu_Latn)
#   2. 0.747359 - German (deu_Latn) & English (eng_Latn)
#   3. 0.742774 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   4. 0.739975 - French (fra_Latn) & English (eng_Latn)
#   5. 0.737593 - Russian (rus_Cyrl) & German (deu_Latn)
#   6. 0.736717 - Spanish (spa_Latn) & English (eng_Latn)
#   7. 0.733143 - French (fra_Latn) & Spanish (spa_Latn)
#   8. 0.728900 - French (fra_Latn) & German (deu_Latn)
#   9. 0.725181 - Slovak (slk_Latn) & Russian (rus_Cyrl)
#   10. 0.720932 - Russian (rus_Cyrl) & Spanish (spa_Latn)
#   11. 0.719537 - Spanish (spa_Latn) & German (deu_Latn)
#   12. 0.719326 - Russian (rus_Cyrl) & French (fra_Latn)
#   13. 0.704319 - Russian (rus_Cyrl) & English (eng_Latn)
#   14. 0.695047 - Chinese (Simplified) (zho_Hans) & Russian (rus_Cyrl)
#   15. 0.681882 - Chinese (Simplified) (zho_Hans) & English (eng_Latn)
#   16. 0.678373 - Russian (rus_Cyrl) & MSA (Arabic) (arb_Arab)
#   17. 0.668563 - Turkish (tur_Latn) & Japanese (jpn_Jpan)
#   18. 0.665461 - Slovak (slk_Latn) & French (fra_Latn)
#   19. 0.661272 - Yue Chinese (yue_Hant) & Russian (rus_Cyrl)
#   20. 0.654094 - Chinese (Simplified) (zho_Hans) & French (fra_Latn)
#   21. 0.651806 - Indonesian (ind_Latn) & Russian (rus_Cyrl)
#   22. 0.649405 - Japanese (jpn_Jpan) & German (deu_Latn)
#   23. 0.648441 - Slovak (slk_Latn) & English (eng_Latn)
#   24. 0.645188 - Tagalog (tgl_Latn) & Russian (rus_Cyrl)
#   25. 0.644654 - Chinese (Simplified) (zho_Hans) & Spanish (spa_Latn)
#   26. 0.644610 - Vietnamese (vie_Latn) & French (fra_Latn)
#   27. 0.644549 - Chinese (Simplified) (zho_Hans) & German (deu_Latn)
#   28. 0.641399 - Slovak (slk_Latn) & Spanish (spa_Latn)
#   29. 0.640783 - Indonesian (ind_Latn) & German (deu_Latn)
#   30. 0.640249 - Tagalog (tgl_Latn) & German (deu_Latn)
#   31. 0.639691 - MSA (Arabic) (arb_Arab) & German (deu_Latn)
#   32. 0.638868 - Yue Chinese (yue_Hant) & Japanese (jpn_Jpan)
#   33. 0.637392 - Vietnamese (vie_Latn) & Russian (rus_Cyrl)
#   34. 0.636116 - Tagalog (tgl_Latn) & Slovak (slk_Latn)
#   35. 0.635449 - MSA (Arabic) (arb_Arab) & French (fra_Latn)
#   36. 0.634744 - Indonesian (ind_Latn) & English (eng_Latn)
#   37. 0.633690 - MSA (Arabic) (arb_Arab) & Spanish (spa_Latn)
#   38. 0.633162 - Chinese (Simplified) (zho_Hans) & Slovak (slk_Latn)
#   39. 0.632909 - Yue Chinese (yue_Hant) & English (eng_Latn)
#   40. 0.629402 - Indonesian (ind_Latn) & Slovak (slk_Latn)
#   41. 0.626547 - Japanese (jpn_Jpan) & Russian (rus_Cyrl)
#   42. 0.626184 - Turkish (tur_Latn) & German (deu_Latn)
#   43. 0.625995 - Indonesian (ind_Latn) & French (fra_Latn)
#   44. 0.625333 - Hebrew (heb_Hebr) & French (fra_Latn)
#   45. 0.624365 - Tagalog (tgl_Latn) & French (fra_Latn)
#   46. 0.623791 - MSA (Arabic) (arb_Arab) & English (eng_Latn)
#   47. 0.623662 - Vietnamese (vie_Latn) & German (deu_Latn)
#   48. 0.623546 - Indonesian (ind_Latn) & Vietnamese (vie_Latn)
#   49. 0.618424 - Chinese (Simplified) (zho_Hans) & Japanese (jpn_Jpan)
#   50. 0.617583 - Korean (kor_Hang) & Japanese (jpn_Jpan)
#
# Layer 31:
#   1. 0.748237 - Slovak (slk_Latn) & German (deu_Latn)
#   2. 0.746173 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   3. 0.737836 - French (fra_Latn) & Spanish (spa_Latn)
#   4. 0.737310 - Russian (rus_Cyrl) & German (deu_Latn)
#   5. 0.733844 - German (deu_Latn) & English (eng_Latn)
#   6. 0.729871 - French (fra_Latn) & German (deu_Latn)
#   7. 0.729837 - French (fra_Latn) & English (eng_Latn)
#   8. 0.723934 - Spanish (spa_Latn) & English (eng_Latn)
#   9. 0.723212 - Russian (rus_Cyrl) & French (fra_Latn)
#   10. 0.721766 - Slovak (slk_Latn) & Russian (rus_Cyrl)
#   11. 0.720833 - Spanish (spa_Latn) & German (deu_Latn)
#   12. 0.718464 - Russian (rus_Cyrl) & Spanish (spa_Latn)
#   13. 0.696371 - Chinese (Simplified) (zho_Hans) & Russian (rus_Cyrl)
#   14. 0.690429 - Russian (rus_Cyrl) & English (eng_Latn)
#   15. 0.674769 - Chinese (Simplified) (zho_Hans) & English (eng_Latn)
#   16. 0.671243 - Turkish (tur_Latn) & Japanese (jpn_Jpan)
#   17. 0.670315 - Russian (rus_Cyrl) & MSA (Arabic) (arb_Arab)
#   18. 0.667719 - Slovak (slk_Latn) & French (fra_Latn)
#   19. 0.662412 - Yue Chinese (yue_Hant) & Russian (rus_Cyrl)
#   20. 0.655277 - Chinese (Simplified) (zho_Hans) & French (fra_Latn)
#   21. 0.649765 - Indonesian (ind_Latn) & Russian (rus_Cyrl)
#   22. 0.648057 - Japanese (jpn_Jpan) & German (deu_Latn)
#   23. 0.647151 - Tagalog (tgl_Latn) & Russian (rus_Cyrl)
#   24. 0.646606 - Chinese (Simplified) (zho_Hans) & German (deu_Latn)
#   25. 0.645017 - Yue Chinese (yue_Hant) & Japanese (jpn_Jpan)
#   26. 0.644312 - Chinese (Simplified) (zho_Hans) & Spanish (spa_Latn)
#   27. 0.643707 - Vietnamese (vie_Latn) & French (fra_Latn)
#   28. 0.642312 - Slovak (slk_Latn) & Spanish (spa_Latn)
#   29. 0.639968 - Indonesian (ind_Latn) & German (deu_Latn)
#   30. 0.638688 - Tagalog (tgl_Latn) & German (deu_Latn)
#   31. 0.637401 - Tagalog (tgl_Latn) & Slovak (slk_Latn)
#   32. 0.636339 - Vietnamese (vie_Latn) & Russian (rus_Cyrl)
#   33. 0.634804 - MSA (Arabic) (arb_Arab) & German (deu_Latn)
#   34. 0.632858 - Hebrew (heb_Hebr) & French (fra_Latn)
#   35. 0.632550 - MSA (Arabic) (arb_Arab) & French (fra_Latn)
#   36. 0.632153 - Slovak (slk_Latn) & English (eng_Latn)
#   37. 0.631428 - Chinese (Simplified) (zho_Hans) & Slovak (slk_Latn)
#   38. 0.630170 - Indonesian (ind_Latn) & Vietnamese (vie_Latn)
#   39. 0.630021 - Tagalog (tgl_Latn) & French (fra_Latn)
#   40. 0.629907 - Indonesian (ind_Latn) & English (eng_Latn)
#   41. 0.629683 - Indonesian (ind_Latn) & Slovak (slk_Latn)
#   42. 0.628588 - Yue Chinese (yue_Hant) & English (eng_Latn)
#   43. 0.627192 - Japanese (jpn_Jpan) & Russian (rus_Cyrl)
#   44. 0.627165 - Turkish (tur_Latn) & German (deu_Latn)
#   45. 0.626943 - MSA (Arabic) (arb_Arab) & Spanish (spa_Latn)
#   46. 0.626677 - Vietnamese (vie_Latn) & German (deu_Latn)
#   47. 0.625001 - Indonesian (ind_Latn) & French (fra_Latn)
#   48. 0.624878 - Korean (kor_Hang) & Japanese (jpn_Jpan)
#   49. 0.624121 - Chinese (Simplified) (zho_Hans) & Japanese (jpn_Jpan)
#   50. 0.616040 - Turkish (tur_Latn) & Russian (rus_Cyrl)
#
# Layer 32:
#   1. 0.752359 - Slovak (slk_Latn) & German (deu_Latn)
#   2. 0.748799 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   3. 0.737490 - French (fra_Latn) & Spanish (spa_Latn)
#   4. 0.737181 - Russian (rus_Cyrl) & German (deu_Latn)
#   5. 0.730620 - French (fra_Latn) & German (deu_Latn)
#   6. 0.727455 - German (deu_Latn) & English (eng_Latn)
#   7. 0.726279 - French (fra_Latn) & English (eng_Latn)
#   8. 0.724984 - Russian (rus_Cyrl) & French (fra_Latn)
#   9. 0.721245 - Russian (rus_Cyrl) & Spanish (spa_Latn)
#   10. 0.720833 - Spanish (spa_Latn) & English (eng_Latn)
#   11. 0.720377 - Spanish (spa_Latn) & German (deu_Latn)
#   12. 0.719111 - Slovak (slk_Latn) & Russian (rus_Cyrl)
#   13. 0.697589 - Chinese (Simplified) (zho_Hans) & Russian (rus_Cyrl)
#   14. 0.688073 - Russian (rus_Cyrl) & English (eng_Latn)
#   15. 0.675355 - Russian (rus_Cyrl) & MSA (Arabic) (arb_Arab)
#   16. 0.669645 - Chinese (Simplified) (zho_Hans) & English (eng_Latn)
#   17. 0.669339 - Slovak (slk_Latn) & French (fra_Latn)
#   18. 0.669062 - Turkish (tur_Latn) & Japanese (jpn_Jpan)
#   19. 0.663183 - Yue Chinese (yue_Hant) & Russian (rus_Cyrl)
#   20. 0.657358 - Chinese (Simplified) (zho_Hans) & French (fra_Latn)
#   21. 0.652491 - Tagalog (tgl_Latn) & Russian (rus_Cyrl)
#   22. 0.648322 - Chinese (Simplified) (zho_Hans) & German (deu_Latn)
#   23. 0.647141 - Indonesian (ind_Latn) & Russian (rus_Cyrl)
#   24. 0.646936 - Chinese (Simplified) (zho_Hans) & Spanish (spa_Latn)
#   25. 0.645200 - Japanese (jpn_Jpan) & German (deu_Latn)
#   26. 0.644946 - Tagalog (tgl_Latn) & German (deu_Latn)
#   27. 0.644770 - Tagalog (tgl_Latn) & Slovak (slk_Latn)
#   28. 0.644222 - Slovak (slk_Latn) & Spanish (spa_Latn)
#   29. 0.643451 - Yue Chinese (yue_Hant) & Japanese (jpn_Jpan)
#   30. 0.641984 - Vietnamese (vie_Latn) & French (fra_Latn)
#   31. 0.641777 - MSA (Arabic) (arb_Arab) & German (deu_Latn)
#   32. 0.640104 - Indonesian (ind_Latn) & German (deu_Latn)
#   33. 0.639944 - Vietnamese (vie_Latn) & Russian (rus_Cyrl)
#   34. 0.638140 - MSA (Arabic) (arb_Arab) & French (fra_Latn)
#   35. 0.638125 - Tagalog (tgl_Latn) & French (fra_Latn)
#   36. 0.632574 - Hebrew (heb_Hebr) & French (fra_Latn)
#   37. 0.631847 - MSA (Arabic) (arb_Arab) & Spanish (spa_Latn)
#   38. 0.628429 - Turkish (tur_Latn) & German (deu_Latn)
#   39. 0.627543 - Chinese (Simplified) (zho_Hans) & Slovak (slk_Latn)
#   40. 0.627420 - Vietnamese (vie_Latn) & German (deu_Latn)
#   41. 0.627409 - Indonesian (ind_Latn) & Slovak (slk_Latn)
#   42. 0.626075 - Indonesian (ind_Latn) & Vietnamese (vie_Latn)
#   43. 0.625966 - Slovak (slk_Latn) & English (eng_Latn)
#   44. 0.624240 - Indonesian (ind_Latn) & English (eng_Latn)
#   45. 0.623159 - Korean (kor_Hang) & Japanese (jpn_Jpan)
#   46. 0.622735 - Indonesian (ind_Latn) & French (fra_Latn)
#   47. 0.622484 - Chinese (Simplified) (zho_Hans) & Japanese (jpn_Jpan)
#   48. 0.622420 - Yue Chinese (yue_Hant) & English (eng_Latn)
#   49. 0.617522 - Japanese (jpn_Jpan) & Russian (rus_Cyrl)
#   50. 0.617246 - Hebrew (heb_Hebr) & MSA (Arabic) (arb_Arab)
#
# Layer 33:
#   1. 0.745427 - Slovak (slk_Latn) & German (deu_Latn)
#   2. 0.739558 - Chinese (Simplified) (zho_Hans) & Yue Chinese (yue_Hant)
#   3. 0.736607 - Russian (rus_Cyrl) & German (deu_Latn)
#   4. 0.732882 - French (fra_Latn) & Spanish (spa_Latn)
#   5. 0.732184 - French (fra_Latn) & German (deu_Latn)
#   6. 0.730878 - Russian (rus_Cyrl) & Spanish (spa_Latn)
#   7. 0.730842 - Russian (rus_Cyrl) & French (fra_Latn)
#   8. 0.717268 - Spanish (spa_Latn) & German (deu_Latn)
#   9. 0.699937 - Slovak (slk_Latn) & Russian (rus_Cyrl)
#   10. 0.688492 - French (fra_Latn) & English (eng_Latn)
#   11. 0.684524 - Spanish (spa_Latn) & English (eng_Latn)
#   12. 0.683281 - Chinese (Simplified) (zho_Hans) & Russian (rus_Cyrl)
#   13. 0.682559 - Russian (rus_Cyrl) & MSA (Arabic) (arb_Arab)
#   14. 0.678486 - German (deu_Latn) & English (eng_Latn)
#   15. 0.664042 - Russian (rus_Cyrl) & English (eng_Latn)
#   16. 0.661208 - Tagalog (tgl_Latn) & French (fra_Latn)
#   17. 0.660983 - Tagalog (tgl_Latn) & Russian (rus_Cyrl)
#   18. 0.655420 - Tagalog (tgl_Latn) & German (deu_Latn)
#   19. 0.654084 - Slovak (slk_Latn) & French (fra_Latn)
#   20. 0.650926 - Tagalog (tgl_Latn) & Slovak (slk_Latn)
#   21. 0.649821 - Yue Chinese (yue_Hant) & Russian (rus_Cyrl)
#   22. 0.649003 - Vietnamese (vie_Latn) & German (deu_Latn)
#   23. 0.648539 - Vietnamese (vie_Latn) & Russian (rus_Cyrl)
#   24. 0.648028 - MSA (Arabic) (arb_Arab) & German (deu_Latn)
#   25. 0.646783 - Indonesian (ind_Latn) & Russian (rus_Cyrl)
#   26. 0.646222 - Indonesian (ind_Latn) & German (deu_Latn)
#   27. 0.642005 - Slovak (slk_Latn) & Spanish (spa_Latn)
#   28. 0.638840 - Hebrew (heb_Hebr) & French (fra_Latn)
#   29. 0.638508 - MSA (Arabic) (arb_Arab) & French (fra_Latn)
#   30. 0.637657 - Vietnamese (vie_Latn) & French (fra_Latn)
#   31. 0.636217 - Hebrew (heb_Hebr) & MSA (Arabic) (arb_Arab)
#   32. 0.634902 - MSA (Arabic) (arb_Arab) & Spanish (spa_Latn)
#   33. 0.632225 - Chinese (Simplified) (zho_Hans) & French (fra_Latn)
#   34. 0.627764 - Chinese (Simplified) (zho_Hans) & Spanish (spa_Latn)
#   35. 0.627219 - Indonesian (ind_Latn) & Vietnamese (vie_Latn)
#   36. 0.626811 - Tagalog (tgl_Latn) & Spanish (spa_Latn)
#   37. 0.626189 - Hebrew (heb_Hebr) & Spanish (spa_Latn)
#   38. 0.625711 - Chinese (Simplified) (zho_Hans) & German (deu_Latn)
#   39. 0.621720 - Hebrew (heb_Hebr) & German (deu_Latn)
#   40. 0.616820 - Indonesian (ind_Latn) & Slovak (slk_Latn)
#   41. 0.616668 - Vietnamese (vie_Latn) & Spanish (spa_Latn)
#   42. 0.616065 - Yue Chinese (yue_Hant) & Japanese (jpn_Jpan)
#   43. 0.612172 - Turkish (tur_Latn) & Japanese (jpn_Jpan)
#   44. 0.611505 - Russian (rus_Cyrl) & Hebrew (heb_Hebr)
#   45. 0.607924 - Chinese (Simplified) (zho_Hans) & Thai (tha_Thai)
#   46. 0.607914 - Vietnamese (vie_Latn) & Thai (tha_Thai)
#   47. 0.605141 - Chinese (Simplified) (zho_Hans) & English (eng_Latn)
#   48. 0.604723 - Indonesian (ind_Latn) & Spanish (spa_Latn)
#   49. 0.604695 - Japanese (jpn_Jpan) & German (deu_Latn)
#   50. 0.603552 - Indonesian (ind_Latn) & Hebrew (heb_Hebr)

# %%
# Calculate mean and std deviation of the distances for each layer
layer_means = cka_matrix.mean(dim=(1, 2)).cpu().numpy()
layer_stds = cka_matrix.std(dim=(1, 2)).cpu().numpy()

# Create a DataFrame to display the statistics
layer_stats_df = pd.DataFrame({
	'Layer': range(-1, num_layers),
	'Mean_Distance': layer_means,
	'Std_Distance': layer_stds
})

print("Layer-wise Distance Statistics:")
print(layer_stats_df.to_string(index=False))
# Out:
# Layer-wise Distance Statistics:
#  Layer  Mean_Distance  Std_Distance
#     -1       0.004583      0.000754
#      0       0.512486      0.135642
#      1       0.454054      0.118735
#      2       0.247477      0.109502
#      3       0.277518      0.104709
#      4       0.363834      0.117647
#      5       0.449188      0.110776
#      6       0.553071      0.146932
#      7       0.559505      0.143927
#      8       0.604105      0.150326
#      9       0.603123      0.158799
#     10       0.582137      0.157613
#     11       0.539116      0.156634
#     12       0.503287      0.161996
#     13       0.470749      0.158534
#     14       0.458775      0.156725
#     15       0.469961      0.164584
#     16       0.449368      0.171718
#     17       0.455619      0.176292
#     18       0.432363      0.179169
#     19       0.427790      0.192119
#     20       0.412117      0.197841
#     21       0.403720      0.204201
#     22       0.387681      0.200641
#     23       0.379895      0.201768
#     24       0.374747      0.204635
#     25       0.340820      0.202308
#     26       0.330829      0.201250
#     27       0.319923      0.198622
#     28       0.316340      0.198409
#     29       0.314759      0.197799
#     30       0.316711      0.197524
#     31       0.317081      0.197861
#     32       0.317934      0.197455
#     33       0.311889      0.192610

# %%
lengths_per_family = {}
for family, langs in EXP2_CONFIG['languages'].items():
    lengths_per_family[family] = len(langs)

# %%
# Heatmap per layer of the silhouette scores between languages, make a subplot for each layer with 4 columns
import seaborn as sns
import matplotlib.pyplot as plt

# Find global min and max across all layers for consistent scale
global_min = float('inf')
global_max = float('-inf')
for layer_id in range(-1, num_layers):
	layer_distances = cka_matrix[layer_id + 1]
	global_min = min(global_min, layer_distances.min().item())
	global_max = max(global_max, layer_distances.max().item())

fig, axes = plt.subplots(nrows=(num_layers + 1) // 4 + 1, ncols=4, figsize=(20, 5 * ((num_layers + 1) // 4 + 1)))
axes = axes.flatten()
for layer_id in tqdm(range(0, num_layers)):
	layer_distances = cka_matrix[layer_id + 1]
	sns.heatmap(layer_distances.cpu().numpy(), 
		xticklabels=[LANGCODE2LANGNAME[lang] for lang in languages], 
		yticklabels=[LANGCODE2LANGNAME[lang] for lang in languages], 
		ax=axes[layer_id], 
		cmap='viridis',
		vmin=global_min,
		vmax=global_max,
		# annot=True,
		# fmt='.2f',
	)
	axes[layer_id].set_title(f'Layer {layer_id} Silhouette Scores')
	plt.setp(axes[layer_id].get_xticklabels(), rotation=90, ha='right', rotation_mode='anchor')

	# Setup fontsize of the x and y label
	axes[layer_id].tick_params(axis='x', labelsize=5)
	axes[layer_id].tick_params(axis='y', labelsize=5)
	
	# Add bolded grid lines to separate language families
	# Calculate cumulative positions for family boundaries
	cumulative_langs = 0
	for family, num_langs in lengths_per_family.items():
		cumulative_langs += num_langs
		# Draw horizontal and vertical lines at family boundaries
		axes[layer_id].axhline(cumulative_langs, color='black', linewidth=1.5)
		axes[layer_id].axvline(cumulative_langs, color='black', linewidth=1.5)

	# if layer_id + 1 == 3:
	# 	break
	
plt.tight_layout()
plt.savefig(f'cka_heatmap_{model_name}.png', dpi=300, bbox_inches='tight')
plt.close()
# Out:
# 100%|██████████| 34/34 [01:22<00:00,  2.41s/it]

# %%
import seaborn as sns

# Make 5 bins of the silhouette scores and color the heatmap accordingly
import matplotlib.pyplot as plt

# Find global min and max across all layers for consistent scale
global_min = float('inf')
global_max = float('-inf')
for layer_id in range(-1, num_layers):
	layer_distances = cka_matrix[layer_id + 1]
	# Exclude diagonal elements (which are 0)
	mask_no_diag = ~torch.eye(len(languages), dtype=torch.bool, device='cuda')
	non_diag_values = layer_distances[mask_no_diag]
	global_min = min(global_min, non_diag_values.min().item())
	global_max = max(global_max, non_diag_values.max().item())

# Create 3 bins
n_bins = 3
bin_edges = np.linspace(global_min, global_max, n_bins + 1)

# Create subplots
fig, axes = plt.subplots(nrows=(num_layers + 1) // 4 + 1, ncols=4, figsize=(20, 5 * ((num_layers + 1) // 4 + 1)))
axes = axes.flatten()

for layer_id in tqdm(range(0, num_layers)):
	layer_distances = cka_matrix[layer_id + 1].cpu().numpy()
	
	# Discretize the distances into bins
	binned_distances = np.digitize(layer_distances, bin_edges) - 1
	binned_distances = np.clip(binned_distances, 0, n_bins - 1)
	
	sns.heatmap(binned_distances, 
		xticklabels=[LANGCODE2LANGNAME[lang] for lang in languages], 
		yticklabels=[LANGCODE2LANGNAME[lang] for lang in languages], 
		ax=axes[layer_id], 
		cmap='viridis',
		vmin=0,
		vmax=n_bins - 1,
		cbar_kws={'label': 'Bin', 'ticks': range(n_bins)}
	)
	axes[layer_id].set_title(f'Layer {layer_id} Binned Silhouette Scores')
	plt.setp(axes[layer_id].get_xticklabels(), rotation=90, ha='right', rotation_mode='anchor')

	# Setup fontsize of the x and y label
	axes[layer_id].tick_params(axis='x', labelsize=5)
	axes[layer_id].tick_params(axis='y', labelsize=5)
	
	# Add bolded grid lines to separate language families
	cumulative_langs = 0
	for family, num_langs in lengths_per_family.items():
		cumulative_langs += num_langs
		axes[layer_id].axhline(cumulative_langs, color='black', linewidth=1.5)
		axes[layer_id].axvline(cumulative_langs, color='black', linewidth=1.5)
	
plt.tight_layout()
plt.savefig(f'silhouette_scores_binned{n_bins}_heatmap_{model_name}.png', dpi=300, bbox_inches='tight')
plt.close()

print(f"Bin edges: {bin_edges}")

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# Create subplots for dendrograms across all layers
fig, axes = plt.subplots(nrows=9, ncols=5, figsize=(25, 80))
fig.suptitle('Hierarchical Clustering Dendrograms Across All Layers', fontsize=16)

# Flatten axes for easier indexing
axes = axes.flatten()

# First pass: find the maximum distance across all layers
max_distance = 0
linkage_results = []
for layer_id in range(-1, num_layers):
	linked = linkage(silhouette_score_matrix[layer_id + 1].cpu().numpy(), 'complete')
	linkage_results.append(linked)
	max_distance = max(max_distance, linked[:, 2].max())

# Second pass: create dendrograms with consistent scale
for layer_id in range(-1, num_layers):
	ax_idx = layer_id + 1
	
	# Create dendrogram in the corresponding subplot
	dendrogram(linkage_results[ax_idx], 
			   labels=[LANGCODE2LANGNAME[lang] for lang in languages], 
			   orientation='right',
			   ax=axes[ax_idx])
	
	axes[ax_idx].set_title(f"Layer {layer_id}", fontsize=12)
	axes[ax_idx].tick_params(axis='y', labelsize=8)
	axes[ax_idx].tick_params(axis='x', labelsize=8)
	axes[ax_idx].set_xlim([0, max_distance])  # Set consistent x-axis limits

plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
# Create subplots for dendrograms across all layers
fig, axes = plt.subplots(nrows=9, ncols=5, figsize=(25, 80))
fig.suptitle('Hierarchical Clustering Dendrograms Across All Layers', fontsize=16)

# Flatten axes for easier indexing
axes = axes.flatten()

for layer_id in range(-1, num_layers):
	ax_idx = layer_id + 1
	
	# Perform clustering for this layer
	linked = linkage(silhouette_score_matrix[layer_id + 1].cpu().numpy(), 'complete')
	
	# Create dendrogram in the corresponding subplot
	dendrogram(linked, 
			   labels=[LANGCODE2LANGNAME[lang] for lang in languages], 
			   orientation='right',
			   ax=axes[ax_idx])
	
	axes[ax_idx].set_title(f"Layer {layer_id}", fontsize=12)
	axes[ax_idx].tick_params(axis='y', labelsize=8)
	axes[ax_idx].tick_params(axis='x', labelsize=8)

plt.tight_layout()
plt.show()
